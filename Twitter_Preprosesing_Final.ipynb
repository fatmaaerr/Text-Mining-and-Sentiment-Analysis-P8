# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (1.5.13)
# Requirement already satisfied: tqdm in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-slugify in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (1.26.14)
# Requirement already satisfied: requests in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (2.28.1)
# Requirement already satisfied: python-dateutil in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: certifi in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: six>=1.10 in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from requests->kaggle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: colorama in c:\users\fatma.er\appdata\local\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
#Libraries 

import re
import os
from tqdm import tqdm
import csv
import nltk
import string
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re
from nltk.stem import WordNetLemmatizer

#stopword removing
import nltk
# download all 
nltk.download('all')

import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\fatma.er\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Kaggle API to download the dataset
import os
kaggle_api = {"username":"fatmaer","key":"02db3447e0d87603a7e4cb10816fe1b7"}
os.environ['KAGGLE_USERNAME'] = kaggle_api['username']
os.environ['KAGGLE_KEY'] = kaggle_api['key']

# %%
#Kaggle authentication and download
import kaggle 
kaggle.api.authenticate() 
! kaggle datasets download -d pashupatigupta/emotion-detection-from-text
# Out:
# 401 - Unauthorized

# %%
#! unzip emotion-detection-from-text

# %%
#read Data 
df = pd.read_csv("https://raw.githubusercontent.com/fatmaaerr/Text-Mining-and-Sentiment-Analysis-P8/main/Data/tweet_emotions.csv")

# %%
df.head(5)
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
df.shape
# Out:
# (40000, 3)

# %%
df.isnull().sum()
# Out:
# tweet_id     0
# sentiment    0
# content      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["sentiment"].value_counts()
# Out:
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: sentiment, dtype: int64

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='sentiment', data=df);

# %%
#check if the data is balanced or not
df.sentiment.value_counts() / df.shape[0] *100
# Out:
# neutral       21.5950
# worry         21.1475
# happiness     13.0225
# sadness       12.9125
# love           9.6050
# surprise       5.4675
# fun            4.4400
# relief         3.8150
# hate           3.3075
# empty          2.0675
# enthusiasm     1.8975
# boredom        0.4475
# anger          0.2750
# Name: sentiment, dtype: float64

# %% [markdown]
# The data is imbalanced so, we may try to balance it but also, the emotions that we interested in are the most repeated emotion so, till now we can keep the data as it is

# %%
df["content"][1:10]
# Out:
# 1    Layin n bed with a headache  ughhhh...waitin o...
# 2                  Funeral ceremony...gloomy friday...
# 3                 wants to hang out with friends SOON!
# 4    @dannycastillo We want to trade with someone w...
# 5    Re-pinging @ghostridah14: why didn't you go to...
# 6    I should be sleep, but im not! thinking about ...
# 7                 Hmmm. http://www.djhero.com/ is down
# 8              @charviray Charlene my love. I miss you
# 9           @kelcouch I'm sorry  at least it's Friday?
# Name: content, dtype: object

# %%
#Case Folding & Cleaning Data

# %%
# function to clean the tweets 
import re
def cleanTxt(text):
    text = re.sub(r'@\w+|#\w+', '', text) #Removing @mentions
    text = re.sub('#', '', text) # Removing '#' hash tag
    text = re.sub('RT[\s]+', '', text) # Removing RT
    text = re.sub('\w+:\/\/\S+', '', text) # Removing hyperlink
    #remove punctuation
    text = re.sub('[^a-zA-Z]', ' ', text)
    text.lower()
    return text

# %%
# case folding
temp = df['content'].str.lower()

# %%
temp
# Out:
# 0        @tiffanylue i know  i was listenin to bad habi...
# 1        layin n bed with a headache  ughhhh...waitin o...
# 2                      funeral ceremony...gloomy friday...
# 3                     wants to hang out with friends soon!
# 4        @dannycastillo we want to trade with someone w...
#                                ...
# 39995                                     @johnlloydtaylor
# 39996                       happy mothers day  all my love
# 39997    happy mother's day to all the mommies out ther...
# 39998    @niariley wassup beautiful!!! follow me!!  pee...
# 39999    @mopedronin bullet train from tokyo    the gf ...
# Name: content, Length: 40000, dtype: object

# %%
# remove hashtag and mention using regex

temp = temp.apply(lambda x: re.sub(r'@\w+|#\w+', '', x))

temp
# Out:
# 0         i know  i was listenin to bad habit earlier a...
# 1        layin n bed with a headache  ughhhh...waitin o...
# 2                      funeral ceremony...gloomy friday...
# 3                     wants to hang out with friends soon!
# 4         we want to trade with someone who has houston...
#                                ...
# 39995
# 39996                       happy mothers day  all my love
# 39997    happy mother's day to all the mommies out ther...
# 39998     wassup beautiful!!! follow me!!  peep out my ...
# 39999     bullet train from tokyo    the gf and i have ...
# Name: content, Length: 40000, dtype: object

# %%
# remove url using regex
temp = temp.apply(lambda x: re.sub(r'http\S+', '', x))
temp
# Out:
# 0         i know  i was listenin to bad habit earlier a...
# 1        layin n bed with a headache  ughhhh...waitin o...
# 2                      funeral ceremony...gloomy friday...
# 3                     wants to hang out with friends soon!
# 4         we want to trade with someone who has houston...
#                                ...
# 39995
# 39996                       happy mothers day  all my love
# 39997    happy mother's day to all the mommies out ther...
# 39998     wassup beautiful!!! follow me!!  peep out my ...
# 39999     bullet train from tokyo    the gf and i have ...
# Name: content, Length: 40000, dtype: object

# %%
# remove punctuation
temp = temp.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

temp
# Out:
# 0         i know  i was listenin to bad habit earlier a...
# 1        layin n bed with a headache  ughhhhwaitin on y...
# 2                            funeral ceremonygloomy friday
# 3                      wants to hang out with friends soon
# 4         we want to trade with someone who has houston...
#                                ...
# 39995
# 39996                       happy mothers day  all my love
# 39997    happy mothers day to all the mommies out there...
# 39998     wassup beautiful follow me  peep out my new h...
# 39999     bullet train from tokyo    the gf and i have ...
# Name: content, Length: 40000, dtype: object

# %%
# remove duplicate item
temp = temp.drop_duplicates()

temp
# Out:
# 0         i know  i was listenin to bad habit earlier a...
# 1        layin n bed with a headache  ughhhhwaitin on y...
# 2                            funeral ceremonygloomy friday
# 3                      wants to hang out with friends soon
# 4         we want to trade with someone who has houston...
#                                ...
# 39994                          succesfully following tayla
# 39996                       happy mothers day  all my love
# 39997    happy mothers day to all the mommies out there...
# 39998     wassup beautiful follow me  peep out my new h...
# 39999     bullet train from tokyo    the gf and i have ...
# Name: content, Length: 39172, dtype: object

# %%
# remove number
temp = temp.apply(lambda x: re.sub(r'\d+', '', x))
temp
# Out:
# 0         i know  i was listenin to bad habit earlier a...
# 1        layin n bed with a headache  ughhhhwaitin on y...
# 2                            funeral ceremonygloomy friday
# 3                      wants to hang out with friends soon
# 4         we want to trade with someone who has houston...
#                                ...
# 39994                          succesfully following tayla
# 39996                       happy mothers day  all my love
# 39997    happy mothers day to all the mommies out there...
# 39998     wassup beautiful follow me  peep out my new h...
# 39999     bullet train from tokyo    the gf and i have ...
# Name: content, Length: 39172, dtype: object

# %%
# check null value
temp.isnull().sum()
# Out:
# 0

# %%
# remove whitespace
temp = temp.apply(lambda x: x.strip())

temp
# Out:
# 0        i know  i was listenin to bad habit earlier an...
# 1        layin n bed with a headache  ughhhhwaitin on y...
# 2                            funeral ceremonygloomy friday
# 3                      wants to hang out with friends soon
# 4        we want to trade with someone who has houston ...
#                                ...
# 39994                          succesfully following tayla
# 39996                       happy mothers day  all my love
# 39997    happy mothers day to all the mommies out there...
# 39998    wassup beautiful follow me  peep out my new hi...
# 39999    bullet train from tokyo    the gf and i have b...
# Name: content, Length: 39172, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# get most common words in training dataset
from collections import Counter 
all_words = []
for line in list(temp):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
    
    
a=Counter(all_words).most_common(10)
a
# Out:
# [('i', 18913),
#  ('to', 14245),
#  ('the', 12796),
#  ('a', 9585),
#  ('my', 7956),
#  ('and', 7289),
#  ('you', 6870),
#  ('it', 5790),
#  ('is', 5666),
#  ('in', 5354)]

# %%
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

#stopwords = set(stopwords.words('english'))
stopwords = nltk.corpus.stopwords.words('english')

# %%
newStopWords = ['u','go','got','via','or','ur','us','in','i','let','the','to','is','amp','make','one','day','days','get','a','e','c','1/2']
stopwords.extend(newStopWords)

# %%
#stopwords

# %%
import string 

def process(x):
    # Check characters to see if they are in punctuation
    nopunc = set(char for char in list(x) if char not in string.punctuation)
    # Join the characters to form the string.
    nopunc = " ".join(nopunc)
    # remove any stopwords if present
# remove stopword

stop = stopwords
temp = temp.apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
temp
# Out:
# 0        know listenin bad habit earlier started freaki...
# 1                   layin n bed headache ughhhhwaitin call
# 2                            funeral ceremonygloomy friday
# 3                                  wants hang friends soon
# 4                       want trade someone houston tickets
#                                ...
# 39994                          succesfully following tayla
# 39996                                   happy mothers love
# 39997    happy mothers mommies woman man long youre mom...
# 39998    wassup beautiful follow peep new hit singles w...
# 39999    bullet train tokyo gf visiting japan since thu...
# Name: content, Length: 39172, dtype: object

# %%
# lemmatization
lemmatizer = WordNetLemmatizer()

temp = temp.apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

temp
# Out:
# 0        know listenin bad habit earlier started freaki...
# 1                   layin n bed headache ughhhhwaitin call
# 2                            funeral ceremonygloomy friday
# 3                                    want hang friend soon
# 4                        want trade someone houston ticket
#                                ...
# 39994                          succesfully following tayla
# 39996                                    happy mother love
# 39997    happy mother mommy woman man long youre momma ...
# 39998    wassup beautiful follow peep new hit single ww...
# 39999    bullet train tokyo gf visiting japan since thu...
# Name: content, Length: 39172, dtype: object

# %%
# tokenization
temp = temp.apply(lambda x: word_tokenize(x))

temp
# Out:
# 0        [know, listenin, bad, habit, earlier, started,...
# 1            [layin, n, bed, headache, ughhhhwaitin, call]
# 2                        [funeral, ceremonygloomy, friday]
# 3                               [want, hang, friend, soon]
# 4                  [want, trade, someone, houston, ticket]
#                                ...
# 39994                      [succesfully, following, tayla]
# 39996                                [happy, mother, love]
# 39997    [happy, mother, mommy, woman, man, long, youre...
# 39998    [wassup, beautiful, follow, peep, new, hit, si...
# 39999    [bullet, train, tokyo, gf, visiting, japan, si...
# Name: content, Length: 39172, dtype: object

# %%
# temp to df content_token
df['content_token'] = temp
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content  \
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
#                                            content_token
# 0      [know, listenin, bad, habit, earlier, started,...
# 1          [layin, n, bed, headache, ughhhhwaitin, call]
# 2                      [funeral, ceremonygloomy, friday]
# 3                             [want, hang, friend, soon]
# 4                [want, trade, someone, houston, ticket]
# ...                                                  ...
# 39995                                                NaN
# 39996                              [happy, mother, love]
# 39997  [happy, mother, mommy, woman, man, long, youre...
# 39998  [wassup, beautiful, follow, peep, new, hit, si...
# 39999  [bullet, train, tokyo, gf, visiting, japan, si...
#
# [40000 rows x 4 columns]

# %%
# remove NaN data in content_token
df = df.dropna(subset=['content_token'])
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39994  1753918900   happiness
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content  \
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39994                      Succesfully following Tayla!!
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
#                                            content_token
# 0      [know, listenin, bad, habit, earlier, started,...
# 1          [layin, n, bed, headache, ughhhhwaitin, call]
# 2                      [funeral, ceremonygloomy, friday]
# 3                             [want, hang, friend, soon]
# 4                [want, trade, someone, houston, ticket]
# ...                                                  ...
# 39994                    [succesfully, following, tayla]
# 39996                              [happy, mother, love]
# 39997  [happy, mother, mommy, woman, man, long, youre...
# 39998  [wassup, beautiful, follow, peep, new, hit, si...
# 39999  [bullet, train, tokyo, gf, visiting, japan, si...
#
# [39172 rows x 4 columns]

# %%
df = df[df['sentiment'] == 'happiness']

# %%
x=df.head(10)

# %%
## Save clean_df to csv file.
x.to_csv('x_hapiness.csv', index=False)

# %%
f = df[df['sentiment'] == 'happiness']

# %% [markdown]
# Finding & Removing Duplicate Synonim

# %%
from nltk.corpus import wordnet
def find_synonym(word):
    synonyms = []
    for syn in wordnet.synsets(word):
        for l in syn.lemmas():
            synonyms.append(l.name())
    return synonyms

df['synonym'] = df['content_token'].apply(lambda x: [find_synonym(word) for word in x])
# Out:
# C:\Users\fatma.er\AppData\Local\Temp\ipykernel_14220\4179798072.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synonym'] = df['content_token'].apply(lambda x: [find_synonym(word) for word in x])

# %%
df.head(5)
# Out:
#        tweet_id  sentiment                                            content  \
# 40   1956977084  happiness  mmm much better day... so far! it's still quit...
# 69   1956983874  happiness  So great to see Oin &amp; Cynthia.  So happy. ...
# 77   1956985535  happiness  @havingmysay  dude, that is my favorite sandwi...
# 126  1956996765  happiness  Need to pack for CALI CALI! Cannot waittt! Thi...
# 233  1957017522  happiness  took a math test today. The day before the tes...
#
#                                          content_token  \
# 40   [mmm, much, better, far, still, quite, early, ...
# 69   [great, see, oin, cynthia, happy, dinner, grea...
# 77   [dude, favorite, sandwich, place, ever, ummm, ...
# 126  [need, pack, cali, cali, can, not, waittt, thi...
# 233  [took, math, test, today, test, teacher, say, ...
#
#                                                synonym
# 40   [[], [much, much, much, much, a_lot, lots, a_g...
# 69   [[great, great, great, outstanding, great, ban...
# 77   [[fellow, dude, buster, dandy, dude, fop, gall...
# 126  [[need, demand, need, want, motivation, motive...
# 233  [[take, take, occupy, use_up, lead, take, dire...

# %%
## Dictionary of word index
index_word = {}
for i, word in enumerate(df['content_token'].sum()):
    if word not in index_word:
        index_word[i] = word

# %%
words = [value for key, value in index_word.items()]
words
# Out:
# ['mmm',
#  'much',
#  'better',
#  'far',
#  'still',
#  'quite',
#  'early',
#  'last',
#  'great',
#  'see',
#  'oin',
#  'cynthia',
#  'happy',
#  'dinner',
#  'great',
#  'cute',
#  'little',
#  'place',
#  'bad',
#  'oin',
#  'sick',
#  'afterwards',
#  'dude',
#  'favorite',
#  'sandwich',
#  'place',
#  'ever',
#  'ummm',
#  'take',
#  'picture',
#  'need',
#  'pack',
#  'cali',
#  'cali',
#  'can',
#  'not',
#  'waittt',
#  'thinking',
#  'glass',
#  'wine',
#  'order',
#  'celebrate',
#  'weekend',
#  'vaca',
#  'still',
#  'work',
#  'morrow',
#  'tho',
#  'took',
#  'math',
#  'test',
#  'today',
#  'test',
#  'teacher',
#  'say',
#  'bring',
#  'calculator',
#  'luke',
#  'confident',
#  'teacher',
#  'decided',
#  'calcs',
#  'omg',
#  'concert',
#  'awesome',
#  'madrigal',
#  'gave',
#  'chill',
#  'almost',
#  'every',
#  'piecebrooks',
#  'also',
#  'called',
#  'alumnus',
#  'didnt',
#  'cant',
#  'minute',
#  'treadmill',
#  'done',
#  'minute',
#  'today',
#  'already',
#  'gon',
#  'na',
#  'minute',
#  'chillin',
#  'roomy',
#  'cant',
#  'wait',
#  'zombie',
#  'clwn',
#  'cr',
#  'gon',
#  'na',
#  'week',
#  'kno',
#  'doooo',
#  'yall',
#  'partyin',
#  'spilled',
#  'beer',
#  'leg',
#  'wasted',
#  'half',
#  'beer',
#  'home',
#  'met',
#  'cute',
#  'girl',
#  'good',
#  'conversation',
#  'english',
#  'class',
#  'working',
#  'interactive',
#  'oral',
#  'fb',
#  'boring',
#  'wan',
#  'na',
#  'sing',
#  'right',
#  'must',
#  'new',
#  'music',
#  'wont',
#  'sleep',
#  'give',
#  'chapter',
#  'might',
#  'die',
#  'first',
#  'though',
#  'hurry',
#  'noooooooooooo',
#  'look',
#  'lot',
#  'picture',
#  'lol',
#  'lol',
#  'demi',
#  'say',
#  'hi',
#  'enough',
#  'replay',
#  'please',
#  'love',
#  'much',
#  'big',
#  'vanessa',
#  'going',
#  'september',
#  'going',
#  'fast',
#  'hard',
#  'cuz',
#  'im',
#  'workin',
#  'much',
#  'miss',
#  'alot',
#  'good',
#  'lord',
#  'seen',
#  'agency',
#  'work',
#  'upcoming',
#  'open',
#  'money',
#  'jam',
#  'little',
#  'foster',
#  'kitten',
#  'getting',
#  'bigchubba',
#  'winston',
#  'going',
#  'b',
#  'missed',
#  'amazing',
#  'home',
#  'getting',
#  'ready',
#  'school',
#  'second',
#  'math',
#  'test',
#  'today',
#  'also',
#  'last',
#  'rd',
#  'year',
#  'next',
#  'week',
#  'officially',
#  'th',
#  'year',
#  'friday',
#  'yay',
#  'bonus',
#  'dont',
#  'drive',
#  'wale',
#  'tonight',
#  'athough',
#  'miss',
#  'kitten',
#  'cuddle',
#  'going',
#  'ride',
#  'ok',
#  'shoe',
#  'club',
#  'cool',
#  'fun',
#  'poppin',
#  'except',
#  'ppl',
#  'tryna',
#  'dance',
#  'wit',
#  'lol',
#  'hi',
#  'emmy',
#  'latin',
#  'would',
#  'help',
#  'study',
#  'aptitude',
#  'test',
#  'grad',
#  'school',
#  'thats',
#  'wan',
#  'na',
#  'take',
#  'awesome',
#  'wish',
#  'could',
#  'fly',
#  'see',
#  'someone',
#  'take',
#  'la',
#  'need',
#  'see',
#  'lemon',
#  'tree',
#  'who',
#  'always',
#  'working',
#  'oh',
#  'yeah',
#  'still',
#  'interesting',
#  'show',
#  'say',
#  'least',
#  'recap',
#  'tomorrow',
#  'first',
#  'must',
#  'sleep',
#  'work',
#  'hahaha',
#  'oh',
#  'man',
#  'please',
#  'come',
#  'pomona',
#  'would',
#  'love',
#  'see',
#  'everyday',
#  'instead',
#  'like',
#  'year',
#  'flight',
#  'already',
#  'booked',
#  'plus',
#  'ggd',
#  'st',
#  'birthday',
#  'cant',
#  'miss',
#  'especially',
#  'missed',
#  'ggd',
#  'missing',
#  'frnds',
#  'hear',
#  'quotmanasellaam',
#  'quot',
#  'kulir',
#  'degree',
#  'movie',
#  'amazing',
#  'nanbargale',
#  'miss',
#  'guy',
#  'oh',
#  'economy',
#  'gotcha',
#  'sorry',
#  'happy',
#  'another',
#  'la',
#  'enjoy',
#  'socal',
#  'ahahaay',
#  'lol',
#  'carlie',
#  'came',
#  'fell',
#  'asleep',
#  'friend',
#  'im',
#  'deeply',
#  'sorry',
#  'im',
#  'moving',
#  'miss',
#  'much',
#  'suuure',
#  'ah',
#  'thats',
#  'better',
#  'snow',
#  'patrol',
#  'stuck',
#  'indoors',
#  'still',
#  'weekend',
#  'coming',
#  'fresh',
#  'air',
#  'excellent',
#  'hope',
#  'sunny',
#  'early',
#  'load',
#  'sun',
#  'hurrah',
#  'babe',
#  'sooo',
#  'much',
#  'fun',
#  'thank',
#  'much',
#  'making',
#  'happen',
#  'fun',
#  'lady',
#  'time',
#  'went',
#  'fast',
#  'little',
#  'family',
#  'party',
#  'tonight',
#  'hope',
#  'rocked',
#  'miss',
#  'concert',
#  'tuesday',
#  'already',
#  'id',
#  'really',
#  'like',
#  'time',
#  'machine',
#  'see',
#  'fun',
#  'hahaha',
#  'yeah',
#  'see',
#  'cant',
#  'twitter',
#  'back',
#  'watching',
#  'jay',
#  'lenos',
#  'nd',
#  'last',
#  'tonight',
#  'show',
#  'havent',
#  'gone',
#  'without',
#  'leno',
#  'like',
#  'four',
#  'years',
#  'ive',
#  'haha',
#  'biggest',
#  'headache',
#  'right',
#  'washed',
#  'hair',
#  'wif',
#  'mum',
#  'shampoo',
#  'gross',
#  'like',
#  'shampoo',
#  'way',
#  'better',
#  'heading',
#  'home',
#  'yay',
#  'going',
#  'buy',
#  'much',
#  'needed',
#  'bottle',
#  'wine',
#  'drink',
#  'dinner',
#  'wallet',
#  'mia',
#  'wine',
#  'tonight',
#  'youre',
#  'faking',
#  'hahahai',
#  'kid',
#  'th',
#  'grade',
#  'spelling',
#  'bee',
#  'went',
#  'trailing',
#  'flame',
#  'st',
#  'word',
#  'county',
#  'spelling',
#  'bee',
#  'believe',
#  'ittomorrow',
#  'night',
#  'jay',
#  'lenos',
#  'last',
#  'episode',
#  'tonight',
#  'show',
#  'encourage',
#  'everyone',
#  'watch',
#  'welcome',
#  'conan',
#  'bought',
#  'new',
#  'combo',
#  'printer',
#  'costco',
#  'today',
#  'officejet',
#  'j',
#  'cause',
#  'cheaper',
#  'ink',
#  'old',
#  'doesnt',
#  'like',
#  'fax',
#  'part',
#  'wake',
#  'early',
#  'goddam',
#  'last',
#  'bummer',
#  'dont',
#  'sad',
#  'glad',
#  'goodmorning',
#  'yall',
#  'woke',
#  'early',
#  'red',
#  'font',
#  'top',
#  'nice',
#  'put',
#  'old',
#  'entry',
#  'useless',
#  'tweet',
#  'lol',
#  'jk',
#  'yay',
#  'youre',
#  'coming',
#  'tmr',
#  'long',
#  'gnna',
#  'phils',
#  'soo',
#  'happy',
#  'frustrated',
#  'time',
#  'ohh',
#  'noo',
#  'britney',
#  'recording',
#  'new',
#  'video',
#  'radar',
#  'sooo',
#  'exxciiteed',
#  'booya',
#  'sup',
#  'tweeps',
#  'happy',
#  'infamous',
#  'soon',
#  'cant',
#  'wait',
#  'play',
#  'need',
#  'find',
#  'time',
#  'though',
#  'im',
#  'wit',
#  'cha',
#  'home',
#  'da',
#  'reggae',
#  'club',
#  'wishin',
#  'sexin',
#  'somebody',
#  'dreading',
#  'going',
#  'work',
#  'butits',
#  'friiiiiday',
#  'whoop',
#  'wan',
#  'na',
#  'dbsk',
#  'oppas',
#  'mirotic',
#  'concert',
#  'thailand',
#  'really',
#  'wan',
#  'na',
#  'muchhhhh',
#  'burst',
#  'tear',
#  'quotmight',
#  'interestedquot',
#  'thanks',
#  'came',
#  'saw',
#  'winced',
#  'much',
#  'like',
#  'flatland',
#  'haha',
#  'wish',
#  'could',
#  'warwick',
#  'castle',
#  'amazing',
#  'devon',
#  'weekno',
#  'internet',
#  'update',
#  'good',
#  'morning',
#  'people',
#  'good',
#  'old',
#  'germany',
#  'soooo',
#  'cold',
#  'like',
#  'n',
#  'tha',
#  'dj',
#  'comp',
#  'hella',
#  'wack',
#  'gud',
#  'dj',
#  'free',
#  'gud',
#  'wish',
#  'would',
#  'call',
#  'hc',
#  'life',
#  'beautiful',
#  'morning',
#  'think',
#  'better',
#  'way',
#  'ruin',
#  'work',
#  'wish',
#  'nicky',
#  'home',
#  'hmmosaka',
#  'last',
#  'show',
#  'todayvery',
#  'sad',
#  'decode',
#  'msg',
#  'haha',
#  'cant',
#  'wait',
#  'till',
#  'sydney',
#  'missed',
#  'ticket',
#  'tho',
#  'xx',
#  'huhuhu',
#  'still',
#  'working',
#  'new',
#  'client',
#  'motion',
#  'graphic',
#  'folder',
#  'instead',
#  'label',
#  'like',
#  'kind',
#  'like',
#  'label',
#  'yeah',
#  'goodermentertainment',
#  'would',
#  'totally',
#  'take',
#  'promif',
#  'hadnt',
#  'already',
#  'gone',
#  'sorry',
#  'lol',
#  'come',
#  'hang',
#  'wif',
#  'meeee',
#  'hmmm',
#  'thinking',
#  'taking',
#  'back',
#  'feel',
#  'better',
#  'morning',
#  'think',
#  'spoke',
#  'early',
#  'know',
#  'wish',
#  'would',
#  'wan',
#  'na',
#  'cuddle',
#  'sleeep',
#  'ga',
#  'world',
#  'coke',
#  'nooo',
#  'hey',
#  'youre',
#  'back',
#  'next',
#  'week',
#  'moving',
#  'back',
#  'good',
#  'yeah',
#  'also',
#  'paper',
#  'final',
#  'left',
#  'algebra',
#  'take',
#  'birthday',
#  'june',
#  'saw',
#  'hamlet',
#  'update',
#  'excellent',
#  'news',
#  'never',
#  'good',
#  'live',
#  'though',
#  'cant',
#  'work',
#  'twitter',
#  'phone',
#  'bed',
#  'thinking',
#  'funny',
#  'stuff',
#  'last',
#  'night',
#  'l',
#  'good',
#  'time',
#  'lucky',
#  'rob',
#  'always',
#  'gettin',
#  't',
#  'emalon',
#  'going',
#  'back',
#  'manila',
#  'evening',
#  'trip',
#  'cebu',
#  'bitin',
#  'cool',
#  'dude',
#  'yeah',
#  'hoping',
#  'rate',
#  'still',
#  'lol',
#  'yeah',
#  'sure',
#  'ill',
#  'mar',
#  'par',
#  'birthday',
#  'dinner',
#  'morning',
#  'twitties',
#  'heading',
#  'college',
#  'back',
#  'doc',
#  'god',
#  'im',
#  'hungry',
#  'streching',
#  'ear',
#  'today',
#  'mm',
#  'payday',
#  'love',
#  'playing',
#  'skate',
#  'two',
#  'hour',
#  'need',
#  'actually',
#  'skate',
#  'late',
#  'adorable',
#  'could',
#  'tell',
#  'pressure',
#  'there',
#  'ding',
#  'tai',
#  'fung',
#  'sydney',
#  'aswell',
#  'making',
#  'want',
#  'dumpling',
#  'alltime',
#  'favorite',
#  'episodesquotes',
#  'officeus',
#  'chilled',
#  'room',
#  'baby',
#  'book',
#  'missed',
#  'bro',
#  'leavin',
#  'really',
#  'cool',
#  'stripper',
#  'shirt',
#  'said',
#  'suppoort',
#  'single',
#  'mom',
#  'funny',
#  'sleeptake',
#  'twothis',
#  'better',
#  'work',
#  'yeahhh',
#  'wasnt',
#  'thereeeeeeeeeee',
#  'poor',
#  'right',
#  'would',
#  'probably',
#  'give',
#  'hug',
#  'wow',
#  'sunny',
#  'recovering',
#  'erased',
#  'file',
#  'wondering',
#  'friend',
#  'went',
#  'idk',
#  'original',
#  'great',
#  'finishing',
#  'homework',
#  'booo',
#  'football',
#  'session',
#  'thisfun',
#  'job',
#  'centre',
#  'bound',
#  'oh',
#  'yay',
#  'thanks',
#  'tip',
#  'unfortunately',
#  'major',
#  'crash',
#  'site',
#  'extplorer',
#  'thats',
#  'actually',
#  'fun',
#  'would',
#  'think',
#  'hurting',
#  'week',
#  'similar',
#  'experience',
#  'send',
#  'please',
#  'txtd',
#  'new',
#  'phone',
#  'thx',
#  'conf',
#  'thurs',
#  'aww',
#  'heard',
#  'missed',
#  'two',
#  'writing',
#  'report',
#  'card',
#  'soooo',
#  'tired',
#  'amazing',
#  'check',
#  'fb',
#  'soon',
#  'laughed',
#  'much',
#  'today',
#  'picture',
#  'lauren',
#  'chest',
#  'hurt',
#  'lobbying',
#  'twitter',
#  'yuk',
#  'gettin',
#  'rid',
#  'groupie',
#  'goodnight',
#  'trending',
#  'topic',
#  'lol',
#  'nevermind',
#  'beyonce',
#  'doesnt',
#  'twitter',
#  'haha',
#  'yeh',
#  'skyfire',
#  'firts',
#  'impression',
#  'look',
#  'good',
#  'little',
#  'memory',
#  'hungry',
#  'ageing',
#  'htc',
#  'tytn',
#  'hereby',
#  'proclaim',
#  'officially',
#  'summer',
#  'awesome',
#  'today',
#  'im',
#  'stuck',
#  'inside',
#  'chilly',
#  'office',
#  'lovliest',
#  'night',
#  'last',
#  'night',
#  'ruined',
#  'doctor',
#  'inability',
#  'warn',
#  'side',
#  'effect',
#  'back',
#  'test',
#  'bumping',
#  'air',
#  'supply',
#  'greastest',
#  'hit',
#  'flying',
#  'ontario',
#  'hourswill',
#  'probably',
#  'stay',
#  'awakei',
#  'dayscamping',
#  'first',
#  'time',
#  'yayi',
#  'sleepy',
#  'going',
#  'back',
#  'home',
#  'love',
#  'ya',
#  'zagrebe',
#  'lt',
#  'staring',
#  'sunshine',
#  'office',
#  'window',
#  'mooorning',
#  'friday',
#  'thats',
#  'terrific',
#  'smile',
#  'sadly',
#  'awake',
#  'wondering',
#  'contact',
#  'info',
#  'fun',
#  'folk',
#  'hung',
#  'shop',
#  'yay',
#  'b',
#  'miss',
#  'guy',
#  'well',
#  'back',
#  'sunday',
#  'play',
#  'horse',
#  'last',
#  'night',
#  'mex',
#  'miss',
#  'nice',
#  'action',
#  'shot',
#  'miss',
#  'working',
#  'pole',
#  'dont',
#  'see',
#  'client',
#  'everyday',
#  'lol',
#  'good',
#  'morning',
#  'every',
#  'gorgeous',
#  'n',
#  'im',
#  'stuck',
#  'work',
#  'wish',
#  'home',
#  ...]

# %%
# set synonym dictionary using find_synonym function 
synonym_dict = {}
for word in words:
    synonym_dict.update({word : tuple([w.lower() for w in find_synonym(word)])})

# %%
synonym_dict
# Out:
# {'mmm': (),
#  'much': ('much',
#   'much',
#   'much',
#   'much',
#   'a_lot',
#   'lots',
#   'a_good_deal',
#   'a_great_deal',
#   'much',
#   'very_much',
#   'much',
#   'practically',
#   'much',
#   'a_great_deal',
#   'often'),
#  'better': ('better',
#   'bettor',
#   'better',
#   'wagerer',
#   'punter',
#   'better',
#   'better',
#   'better',
#   'break',
#   'better',
#   'improve',
#   'amend',
#   'ameliorate',
#   'meliorate',
#   'better',
#   'improve',
#   'ameliorate',
#   'meliorate',
#   'better',
#   'better',
#   'better',
#   'best',
#   'better',
#   'good',
#   'full',
#   'good',
#   'good',
#   'estimable',
#   'good',
#   'honorable',
#   'respectable',
#   'beneficial',
#   'good',
#   'good',
#   'good',
#   'just',
#   'upright',
#   'adept',
#   'expert',
#   'good',
#   'practiced',
#   'proficient',
#   'skillful',
#   'skilful',
#   'good',
#   'dear',
#   'good',
#   'near',
#   'dependable',
#   'good',
#   'safe',
#   'secure',
#   'good',
#   'right',
#   'ripe',
#   'good',
#   'well',
#   'effective',
#   'good',
#   'in_effect',
#   'in_force',
#   'good',
#   'good',
#   'serious',
#   'good',
#   'sound',
#   'good',
#   'salutary',
#   'good',
#   'honest',
#   'good',
#   'undecomposed',
#   'unspoiled',
#   'unspoilt',
#   'good',
#   'well',
#   'good',
#   'well',
#   'well',
#   'better',
#   'better',
#   'best',
#   'well',
#   'good',
#   'well',
#   'well',
#   'easily',
#   'well',
#   'well',
#   'well',
#   'well',
#   'considerably',
#   'substantially',
#   'well',
#   'intimately',
#   'well',
#   'well',
#   'well',
#   'advantageously',
#   'well',
#   'comfortably',
#   'well'),
#  'far': ('army_for_the_liberation_of_rwanda',
#   'alir',
#   'former_armed_forces',
#   'far',
#   'interahamwe',
#   'far',
#   'far',
#   'far',
#   'far',
#   'far',
#   'far',
#   'far',
#   'far',
#   'far'),
#  'still': ('still',
#   'hush',
#   'stillness',
#   'still',
#   'still',
#   'distillery',
#   'still',
#   'calm',
#   'calm_down',
#   'quiet',
#   'tranquilize',
#   'tranquillize',
#   'tranquillise',
#   'quieten',
#   'lull',
#   'still',
#   'hush',
#   'quieten',
#   'silence',
#   'still',
#   'shut_up',
#   'hush_up',
#   'still',
#   'allay',
#   'relieve',
#   'ease',
#   'still',
#   'inactive',
#   'motionless',
#   'static',
#   'still',
#   'silent',
#   'soundless',
#   'still',
#   'placid',
#   'quiet',
#   'still',
#   'tranquil',
#   'smooth',
#   'unruffled',
#   'still',
#   'still',
#   'noneffervescent',
#   'still',
#   'still',
#   'however',
#   'nevertheless',
#   'withal',
#   'still',
#   'yet',
#   'all_the_same',
#   'even_so',
#   'nonetheless',
#   'notwithstanding',
#   'even',
#   'yet',
#   'still',
#   'still',
#   'stock-still'),
#  'quite': ('quite',
#   'rather',
#   'quite',
#   'quite',
#   'quite_a',
#   'quite_an',
#   'quite'),
#  'early': ('early',
#   'early',
#   'early',
#   'former',
#   'other',
#   'early',
#   'early',
#   'early',
#   'early_on',
#   'early',
#   'early',
#   'ahead_of_time',
#   'too_soon',
#   'early',
#   'betimes'),
#  'last': ('stopping_point',
#   'finale',
#   'finis',
#   'finish',
#   'last',
#   'conclusion',
#   'close',
#   'last',
#   'last',
#   'death',
#   'last',
#   'last',
#   'last',
#   'end',
#   'last',
#   'final_stage',
#   'last',
#   "shoemaker's_last",
#   "cobbler's_last",
#   'last',
#   'endure',
#   'survive',
#   'last',
#   'live',
#   'live_on',
#   'go',
#   'endure',
#   'hold_up',
#   'hold_out',
#   'last',
#   'last',
#   'concluding',
#   'final',
#   'last',
#   'terminal',
#   'last',
#   'last',
#   'final',
#   'last',
#   'net',
#   'last',
#   'utmost',
#   'final',
#   'last',
#   'last',
#   'last-place',
#   'lowest',
#   'last',
#   'last',
#   'lastly',
#   'in_conclusion',
#   'finally'),
#  'great': ('great',
#   'great',
#   'great',
#   'outstanding',
#   'great',
#   'bang-up',
#   'bully',
#   'corking',
#   'cracking',
#   'dandy',
#   'great',
#   'groovy',
#   'keen',
#   'neat',
#   'nifty',
#   'not_bad',
#   'peachy',
#   'slap-up',
#   'swell',
#   'smashing',
#   'capital',
#   'great',
#   'majuscule',
#   'big',
#   'enceinte',
#   'expectant',
#   'gravid',
#   'great',
#   'large',
#   'heavy',
#   'with_child'),
#  'see': ('see',
#   'see',
#   'understand',
#   'realize',
#   'realise',
#   'see',
#   'witness',
#   'find',
#   'see',
#   'visualize',
#   'visualise',
#   'envision',
#   'project',
#   'fancy',
#   'see',
#   'figure',
#   'picture',
#   'image',
#   'see',
#   'consider',
#   'reckon',
#   'view',
#   'regard',
#   'learn',
#   'hear',
#   'get_word',
#   'get_wind',
#   'pick_up',
#   'find_out',
#   'get_a_line',
#   'discover',
#   'see',
#   'watch',
#   'view',
#   'see',
#   'catch',
#   'take_in',
#   'meet',
#   'run_into',
#   'encounter',
#   'run_across',
#   'come_across',
#   'see',
#   'determine',
#   'check',
#   'find_out',
#   'see',
#   'ascertain',
#   'watch',
#   'learn',
#   'see',
#   'check',
#   'insure',
#   'see_to_it',
#   'ensure',
#   'control',
#   'ascertain',
#   'assure',
#   'see',
#   'see',
#   'visit',
#   'see',
#   'attend',
#   'take_care',
#   'look',
#   'see',
#   'see',
#   'go_steady',
#   'go_out',
#   'date',
#   'see',
#   'see',
#   'see',
#   'see',
#   'examine',
#   'see',
#   'experience',
#   'see',
#   'go_through',
#   'see',
#   'escort',
#   'see',
#   'interpret',
#   'construe',
#   'see'),
#  'oin': (),
#  'cynthia': ('artemis', 'cynthia'),
#  'happy': ('happy',
#   'felicitous',
#   'happy',
#   'glad',
#   'happy',
#   'happy',
#   'well-chosen'),
#  'dinner': ('dinner', 'dinner', 'dinner_party'),
#  'cute': ('cunning', 'cute', 'cute', 'precious'),
#  'little': ('little',
#   'small',
#   'little',
#   'little',
#   'slight',
#   'little',
#   'small',
#   'fiddling',
#   'footling',
#   'lilliputian',
#   'little',
#   'niggling',
#   'piddling',
#   'piffling',
#   'petty',
#   'picayune',
#   'trivial',
#   'little',
#   'small',
#   'short',
#   'little',
#   'little',
#   'minuscule',
#   'small',
#   'little',
#   'little'),
#  'place': ('topographic_point',
#   'place',
#   'spot',
#   'place',
#   'property',
#   'place',
#   'place',
#   'stead',
#   'position',
#   'place',
#   'lieu',
#   'place',
#   'shoes',
#   'home',
#   'place',
#   'position',
#   'post',
#   'berth',
#   'office',
#   'spot',
#   'billet',
#   'place',
#   'situation',
#   'position',
#   'place',
#   'place',
#   'station',
#   'seat',
#   'place',
#   'place',
#   'place',
#   'plaza',
#   'place',
#   'piazza',
#   'place',
#   'position',
#   'space',
#   'blank_space',
#   'place',
#   'put',
#   'set',
#   'place',
#   'pose',
#   'position',
#   'lay',
#   'place',
#   'rate',
#   'rank',
#   'range',
#   'order',
#   'grade',
#   'place',
#   'locate',
#   'place',
#   'site',
#   'place',
#   'place',
#   'come_in',
#   'come_out',
#   'target',
#   'aim',
#   'place',
#   'direct',
#   'point',
#   'identify',
#   'place',
#   'place',
#   'set',
#   'localize',
#   'localise',
#   'place',
#   'place',
#   'put',
#   'set',
#   'place',
#   'localize',
#   'localise',
#   'invest',
#   'put',
#   'commit',
#   'place',
#   'station',
#   'post',
#   'send',
#   'place',
#   'place',
#   'place'),
#  'bad': ('bad',
#   'badness',
#   'bad',
#   'bad',
#   'big',
#   'bad',
#   'tough',
#   'bad',
#   'spoiled',
#   'spoilt',
#   'regretful',
#   'sorry',
#   'bad',
#   'bad',
#   'uncollectible',
#   'bad',
#   'bad',
#   'bad',
#   'risky',
#   'high-risk',
#   'speculative',
#   'bad',
#   'unfit',
#   'unsound',
#   'bad',
#   'bad',
#   'bad',
#   'forged',
#   'bad',
#   'defective',
#   'badly',
#   'bad',
#   'badly',
#   'bad'),
#  'sick': ('sick',
#   'vomit',
#   'vomit_up',
#   'purge',
#   'cast',
#   'sick',
#   'cat',
#   'be_sick',
#   'disgorge',
#   'regorge',
#   'retch',
#   'puke',
#   'barf',
#   'spew',
#   'spue',
#   'chuck',
#   'upchuck',
#   'honk',
#   'regurgitate',
#   'throw_up',
#   'ill',
#   'sick',
#   'nauseated',
#   'nauseous',
#   'queasy',
#   'sick',
#   'sickish',
#   'brainsick',
#   'crazy',
#   'demented',
#   'disturbed',
#   'mad',
#   'sick',
#   'unbalanced',
#   'unhinged',
#   'disgusted',
#   'fed_up',
#   'sick',
#   'sick_of',
#   'tired_of',
#   'pale',
#   'pallid',
#   'wan',
#   'sick',
#   'sick',
#   'ghastly',
#   'grim',
#   'grisly',
#   'gruesome',
#   'macabre',
#   'sick'),
#  'afterwards': ('subsequently',
#   'later',
#   'afterwards',
#   'afterward',
#   'after',
#   'later_on'),
#  'dude': ('fellow',
#   'dude',
#   'buster',
#   'dandy',
#   'dude',
#   'fop',
#   'gallant',
#   'sheik',
#   'beau',
#   'swell',
#   'fashion_plate',
#   'clotheshorse'),
#  'favorite': ('favorite',
#   'favourite',
#   'darling',
#   'favorite',
#   'favourite',
#   'pet',
#   'dearie',
#   'deary',
#   'ducky',
#   'front-runner',
#   'favorite',
#   'favourite',
#   'favorite',
#   'favourite',
#   'favored',
#   'favorite',
#   'favourite',
#   'best-loved',
#   'pet',
#   'preferred',
#   'preferent'),
#  'sandwich': ('sandwich', 'sandwich', 'sandwich'),
#  'ever': ('ever', 'of_all_time', 'always', 'ever', "e'er", 'ever', 'ever_so'),
#  'ummm': (),
#  'take': ('return',
#   'issue',
#   'take',
#   'takings',
#   'proceeds',
#   'yield',
#   'payoff',
#   'take',
#   'take',
#   'take',
#   'occupy',
#   'use_up',
#   'lead',
#   'take',
#   'direct',
#   'conduct',
#   'guide',
#   'take',
#   'get_hold_of',
#   'assume',
#   'acquire',
#   'adopt',
#   'take_on',
#   'take',
#   'take',
#   'read',
#   'bring',
#   'convey',
#   'take',
#   'take',
#   'take',
#   'choose',
#   'take',
#   'select',
#   'pick_out',
#   'accept',
#   'take',
#   'have',
#   'fill',
#   'take',
#   'occupy',
#   'consider',
#   'take',
#   'deal',
#   'look_at',
#   'necessitate',
#   'ask',
#   'postulate',
#   'need',
#   'require',
#   'take',
#   'involve',
#   'call_for',
#   'demand',
#   'take',
#   'film',
#   'shoot',
#   'take',
#   'remove',
#   'take',
#   'take_away',
#   'withdraw',
#   'consume',
#   'ingest',
#   'take_in',
#   'take',
#   'have',
#   'take',
#   'submit',
#   'take',
#   'accept',
#   'take',
#   'assume',
#   'take',
#   'strike',
#   'take_up',
#   'accept',
#   'admit',
#   'take',
#   'take_on',
#   'take',
#   'learn',
#   'study',
#   'read',
#   'take',
#   'claim',
#   'take',
#   'exact',
#   'take',
#   'make',
#   'aim',
#   'take',
#   'train',
#   'take_aim',
#   'direct',
#   'take',
#   'carry',
#   'pack',
#   'take',
#   'lease',
#   'rent',
#   'hire',
#   'charter',
#   'engage',
#   'take',
#   'subscribe',
#   'subscribe_to',
#   'take',
#   'take',
#   'take',
#   'take',
#   'have',
#   'claim',
#   'take',
#   'accept',
#   'take',
#   'contain',
#   'take',
#   'hold',
#   'take',
#   'drive',
#   'take',
#   'take',
#   'contract',
#   'take',
#   'get'),
#  'picture': ('picture',
#   'image',
#   'icon',
#   'ikon',
#   'painting',
#   'picture',
#   'mental_picture',
#   'picture',
#   'impression',
#   'picture',
#   'scene',
#   'picture',
#   'pictorial_matter',
#   'movie',
#   'film',
#   'picture',
#   'moving_picture',
#   'moving-picture_show',
#   'motion_picture',
#   'motion-picture_show',
#   'picture_show',
#   'pic',
#   'flick',
#   'video',
#   'picture',
#   'word_picture',
#   'word-painting',
#   'delineation',
#   'depiction',
#   'picture',
#   'characterization',
#   'characterisation',
#   'picture',
#   'photograph',
#   'photo',
#   'exposure',
#   'picture',
#   'pic',
#   'visualize',
#   'visualise',
#   'envision',
#   'project',
#   'fancy',
#   'see',
#   'figure',
#   'picture',
#   'image',
#   'picture',
#   'depict',
#   'render',
#   'show'),
#  'need': ('need',
#   'demand',
#   'need',
#   'want',
#   'motivation',
#   'motive',
#   'need',
#   'indigence',
#   'need',
#   'penury',
#   'pauperism',
#   'pauperization',
#   'necessitate',
#   'ask',
#   'postulate',
#   'need',
#   'require',
#   'take',
#   'involve',
#   'call_for',
#   'demand',
#   'want',
#   'need',
#   'require',
#   'need'),
#  'pack': ('battalion',
#   'large_number',
#   'multitude',
#   'plurality',
#   'pack',
#   'pack',
#   'pack',
#   'gang',
#   'pack',
#   'ring',
#   'mob',
#   'clique',
#   'coterie',
#   'ingroup',
#   'inner_circle',
#   'pack',
#   'camp',
#   'pack',
#   'pack',
#   'face_pack',
#   'pack',
#   'pack',
#   'pack',
#   'pack',
#   'pack',
#   'bundle',
#   'wad',
#   'compact',
#   'pack',
#   'pack',
#   'carry',
#   'pack',
#   'take',
#   'throng',
#   'mob',
#   'pack',
#   'pile',
#   'jam',
#   'backpack',
#   'pack',
#   'tamp_down',
#   'tamp',
#   'pack',
#   'pack',
#   'compact',
#   'pack',
#   'pack',
#   'load_down',
#   'pack'),
#  'cali': ('cali',),
#  'can': ('can',
#   'tin',
#   'tin_can',
#   'can',
#   'canful',
#   'can',
#   'can_buoy',
#   'buttocks',
#   'nates',
#   'arse',
#   'butt',
#   'backside',
#   'bum',
#   'buns',
#   'can',
#   'fundament',
#   'hindquarters',
#   'hind_end',
#   'keister',
#   'posterior',
#   'prat',
#   'rear',
#   'rear_end',
#   'rump',
#   'stern',
#   'seat',
#   'tail',
#   'tail_end',
#   'tooshie',
#   'tush',
#   'bottom',
#   'behind',
#   'derriere',
#   'fanny',
#   'ass',
#   'toilet',
#   'can',
#   'commode',
#   'crapper',
#   'pot',
#   'potty',
#   'stool',
#   'throne',
#   'toilet',
#   'lavatory',
#   'lav',
#   'can',
#   'john',
#   'privy',
#   'bathroom',
#   'can',
#   'tin',
#   'put_up',
#   'displace',
#   'fire',
#   'give_notice',
#   'can',
#   'dismiss',
#   'give_the_axe',
#   'send_away',
#   'sack',
#   'force_out',
#   'give_the_sack',
#   'terminate'),
#  'not': ('not', 'non'),
#  'waittt': (),
#  'thinking': ('thinking',
#   'thought',
#   'thought_process',
#   'cerebration',
#   'intellection',
#   'mentation',
#   'think',
#   'believe',
#   'consider',
#   'conceive',
#   'think',
#   'opine',
#   'suppose',
#   'imagine',
#   'reckon',
#   'guess',
#   'think',
#   'cogitate',
#   'cerebrate',
#   'remember',
#   'retrieve',
#   'recall',
#   'call_back',
#   'call_up',
#   'recollect',
#   'think',
#   'think',
#   'think',
#   'intend',
#   'mean',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'think',
#   'intelligent',
#   'reasoning',
#   'thinking'),
#  'glass': ('glass',
#   'glass',
#   'drinking_glass',
#   'glass',
#   'glassful',
#   'field_glass',
#   'glass',
#   'spyglass',
#   'methamphetamine',
#   'methamphetamine_hydrochloride',
#   'methedrine',
#   'meth',
#   'deoxyephedrine',
#   'chalk',
#   'chicken_feed',
#   'crank',
#   'glass',
#   'ice',
#   'shabu',
#   'trash',
#   'looking_glass',
#   'glass',
#   'glass',
#   'glass',
#   'glaze',
#   'glass',
#   'glass',
#   'glass_in',
#   'glass',
#   'glaze',
#   'glass',
#   'glass_over',
#   'glaze_over'),
#  'wine': ('wine',
#   'vino',
#   'wine',
#   'wine-colored',
#   'wine-coloured',
#   'wine',
#   'wine'),
#  'order': ('order',
#   'order',
#   'order_of_magnitude',
#   'order',
#   'ordering',
#   'order',
#   'ordination',
#   'orderliness',
#   'order',
#   'decree',
#   'edict',
#   'fiat',
#   'order',
#   'rescript',
#   'order',
#   'purchase_order',
#   'club',
#   'social_club',
#   'society',
#   'guild',
#   'gild',
#   'lodge',
#   'order',
#   'order',
#   'rules_of_order',
#   'parliamentary_law',
#   'parliamentary_procedure',
#   'holy_order',
#   'order',
#   'order',
#   'monastic_order',
#   'order',
#   'order',
#   'order',
#   'order',
#   'ordering',
#   'order',
#   'tell',
#   'enjoin',
#   'say',
#   'order',
#   'order',
#   'prescribe',
#   'dictate',
#   'regulate',
#   'regularize',
#   'regularise',
#   'order',
#   'govern',
#   'order',
#   'order',
#   'ordain',
#   'consecrate',
#   'ordinate',
#   'order',
#   'arrange',
#   'set_up',
#   'put',
#   'order',
#   'rate',
#   'rank',
#   'range',
#   'order',
#   'grade',
#   'place'),
#  'celebrate': ('observe',
#   'celebrate',
#   'keep',
#   'celebrate',
#   'fete',
#   'lionize',
#   'lionise',
#   'celebrate'),
#  'weekend': ('weekend', 'weekend'),
#  'vaca': (),
#  'work': ('work',
#   'work',
#   'piece_of_work',
#   'employment',
#   'work',
#   'study',
#   'work',
#   'work',
#   'workplace',
#   'work',
#   'oeuvre',
#   'work',
#   'body_of_work',
#   'work',
#   'work',
#   'do_work',
#   'work',
#   'act',
#   'function',
#   'work',
#   'operate',
#   'go',
#   'run',
#   'work',
#   'work_on',
#   'process',
#   'exercise',
#   'work',
#   'work_out',
#   'make',
#   'work',
#   'work',
#   'work',
#   'work',
#   'bring',
#   'work',
#   'play',
#   'wreak',
#   'make_for',
#   'work',
#   'put_to_work',
#   'cultivate',
#   'crop',
#   'work',
#   'work',
#   'influence',
#   'act_upon',
#   'work',
#   'work',
#   'work',
#   'work',
#   'work',
#   'shape',
#   'form',
#   'work',
#   'mold',
#   'mould',
#   'forge',
#   'work',
#   'knead',
#   'work',
#   'exploit',
#   'work',
#   'solve',
#   'work_out',
#   'figure_out',
#   'puzzle_out',
#   'lick',
#   'work',
#   'ferment',
#   'work',
#   'sour',
#   'turn',
#   'ferment',
#   'work',
#   'work'),
#  'morrow': ('morrow',),
#  'tho': ('tho',),
#  'took': ('take',
#   'take',
#   'occupy',
#   'use_up',
#   'lead',
#   'take',
#   'direct',
#   'conduct',
#   'guide',
#   'take',
#   'get_hold_of',
#   'assume',
#   'acquire',
#   'adopt',
#   'take_on',
#   'take',
#   'take',
#   'read',
#   'bring',
#   'convey',
#   'take',
#   'take',
#   'take',
#   'choose',
#   'take',
#   'select',
#   'pick_out',
#   'accept',
#   'take',
#   'have',
#   'fill',
#   'take',
#   'occupy',
#   'consider',
#   'take',
#   'deal',
#   'look_at',
#   'necessitate',
#   'ask',
#   'postulate',
#   'need',
#   'require',
#   'take',
#   'involve',
#   'call_for',
#   'demand',
#   'take',
#   'film',
#   'shoot',
#   'take',
#   'remove',
#   'take',
#   'take_away',
#   'withdraw',
#   'consume',
#   'ingest',
#   'take_in',
#   'take',
#   'have',
#   'take',
#   'submit',
#   'take',
#   'accept',
#   'take',
#   'assume',
#   'take',
#   'strike',
#   'take_up',
#   'accept',
#   'admit',
#   'take',
#   'take_on',
#   'take',
#   'learn',
#   'study',
#   'read',
#   'take',
#   'claim',
#   'take',
#   'exact',
#   'take',
#   'make',
#   'aim',
#   'take',
#   'train',
#   'take_aim',
#   'direct',
#   'take',
#   'carry',
#   'pack',
#   'take',
#   'lease',
#   'rent',
#   'hire',
#   'charter',
#   'engage',
#   'take',
#   'subscribe',
#   'subscribe_to',
#   'take',
#   'take',
#   'take',
#   'take',
#   'have',
#   'claim',
#   'take',
#   'accept',
#   'take',
#   'contain',
#   'take',
#   'hold',
#   'take',
#   'drive',
#   'take',
#   'take',
#   'contract',
#   'take',
#   'get'),
#  'math': ('mathematics', 'math', 'maths'),
#  'test': ('trial',
#   'trial_run',
#   'test',
#   'tryout',
#   'test',
#   'mental_test',
#   'mental_testing',
#   'psychometric_test',
#   'examination',
#   'exam',
#   'test',
#   'test',
#   'trial',
#   'test',
#   'trial',
#   'run',
#   'test',
#   'test',
#   'prove',
#   'try',
#   'try_out',
#   'examine',
#   'essay',
#   'screen',
#   'test',
#   'quiz',
#   'test',
#   'test',
#   'test',
#   'test',
#   'test'),
#  'today': ('today', 'today', 'nowadays', 'now', 'today', 'today'),
#  'teacher': ('teacher', 'instructor', 'teacher'),
#  'say': ('say',
#   'state',
#   'say',
#   'tell',
#   'allege',
#   'aver',
#   'say',
#   'suppose',
#   'say',
#   'read',
#   'say',
#   'order',
#   'tell',
#   'enjoin',
#   'say',
#   'pronounce',
#   'articulate',
#   'enounce',
#   'sound_out',
#   'enunciate',
#   'say',
#   'say',
#   'say',
#   'say',
#   'say',
#   'say'),
#  'bring': ('bring',
#   'convey',
#   'take',
#   'bring',
#   'bring',
#   'work',
#   'play',
#   'wreak',
#   'make_for',
#   'bring',
#   'get',
#   'convey',
#   'fetch',
#   'bring',
#   'land',
#   'bring',
#   'institute',
#   'bring',
#   'lend',
#   'impart',
#   'bestow',
#   'contribute',
#   'add',
#   'bring',
#   'fetch',
#   'bring_in',
#   'bring',
#   'bring',
#   'bring'),
#  'calculator': ('calculator',
#   'reckoner',
#   'figurer',
#   'estimator',
#   'computer',
#   'calculator',
#   'calculating_machine'),
#  'luke': ('luke',
#   'saint_luke',
#   'st._luke',
#   'luke',
#   'gospel_of_luke',
#   'gospel_according_to_luke'),
#  'confident': ('confident',
#   'convinced',
#   'positive',
#   'confident',
#   'confident',
#   'surefooted',
#   'sure-footed'),
#  'decided': ('decide',
#   "make_up_one's_mind",
#   'determine',
#   'decide',
#   'settle',
#   'resolve',
#   'adjudicate',
#   'decide',
#   'decide',
#   'distinct',
#   'decided'),
#  'calcs': (),
#  'omg': (),
#  'concert': ('concert', 'concert', 'concert'),
#  'awesome': ('amazing', 'awe-inspiring', 'awesome', 'awful', 'awing'),
#  'madrigal': ('madrigal', 'madrigal'),
#  'gave': ('give',
#   'yield',
#   'give',
#   'afford',
#   'give',
#   'give',
#   'give',
#   'pay',
#   'hold',
#   'throw',
#   'have',
#   'make',
#   'give',
#   'give',
#   'throw',
#   'give',
#   'gift',
#   'present',
#   'give',
#   'yield',
#   'give',
#   'pay',
#   'devote',
#   'render',
#   'yield',
#   'return',
#   'give',
#   'generate',
#   'impart',
#   'leave',
#   'give',
#   'pass_on',
#   'establish',
#   'give',
#   'give',
#   'give',
#   'sacrifice',
#   'give',
#   'pass',
#   'hand',
#   'reach',
#   'pass_on',
#   'turn_over',
#   'give',
#   'give',
#   'dedicate',
#   'consecrate',
#   'commit',
#   'devote',
#   'give',
#   'give',
#   'apply',
#   'give',
#   'render',
#   'grant',
#   'give',
#   'move_over',
#   'give_way',
#   'give',
#   'ease_up',
#   'yield',
#   'feed',
#   'give',
#   'contribute',
#   'give',
#   'chip_in',
#   'kick_in',
#   'collapse',
#   'fall_in',
#   'cave_in',
#   'give',
#   'give_way',
#   'break',
#   'founder',
#   'give',
#   'give',
#   'give',
#   'afford',
#   'open',
#   'give',
#   'give',
#   'give',
#   'give',
#   'yield',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give'),
#  'chill': ('chill',
#   'iciness',
#   'gelidity',
#   'frisson',
#   'shiver',
#   'chill',
#   'quiver',
#   'shudder',
#   'thrill',
#   'tingle',
#   'chill',
#   'shivering',
#   'chill',
#   'pall',
#   'chill',
#   'cool',
#   'chill',
#   'cool_down',
#   'cool',
#   'chill',
#   'cool_down'),
#  'almost': ('about',
#   'almost',
#   'most',
#   'nearly',
#   'near',
#   'nigh',
#   'virtually',
#   'well-nigh'),
#  'every': ('every', 'every'),
#  'piecebrooks': (),
#  'also': ('besides', 'too', 'also', 'likewise', 'as_well'),
#  'called': ('name',
#   'call',
#   'call',
#   'call',
#   'telephone',
#   'call_up',
#   'phone',
#   'ring',
#   'shout',
#   'shout_out',
#   'cry',
#   'call',
#   'yell',
#   'scream',
#   'holler',
#   'hollo',
#   'squall',
#   'call',
#   'send_for',
#   'visit',
#   'call_in',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'address',
#   'call',
#   'call',
#   'call',
#   'call_in',
#   'bid',
#   'call',
#   'call',
#   'call_off',
#   'call',
#   'predict',
#   'foretell',
#   'prognosticate',
#   'call',
#   'forebode',
#   'anticipate',
#   'promise',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call',
#   'call'),
#  'alumnus': ('alumnus', 'alumna', 'alum', 'graduate', 'grad'),
#  'didnt': (),
#  'cant': ('buzzword',
#   'cant',
#   'bank',
#   'cant',
#   'camber',
#   'slang',
#   'cant',
#   'jargon',
#   'lingo',
#   'argot',
#   'patois',
#   'vernacular',
#   'cant',
#   'pious_platitude',
#   'bevel',
#   'cant',
#   'chamfer',
#   'cant',
#   'cant_over',
#   'tilt',
#   'slant',
#   'pitch'),
#  'minute': ('minute',
#   'min',
#   'moment',
#   'mo',
#   'minute',
#   'second',
#   'bit',
#   'moment',
#   'minute',
#   'second',
#   'instant',
#   'minute',
#   'arcminute',
#   'minute_of_arc',
#   'minute',
#   'hour',
#   'minute',
#   'infinitesimal',
#   'minute',
#   'minute',
#   'narrow'),
#  'treadmill': ('treadmill',
#   'treadmill',
#   'treadwheel',
#   'tread-wheel',
#   'treadmill',
#   'salt_mine'),
#  'done': ('make',
#   'do',
#   'perform',
#   'execute',
#   'do',
#   'do',
#   'perform',
#   'do',
#   'fare',
#   'make_out',
#   'come',
#   'get_along',
#   'cause',
#   'do',
#   'make',
#   'practice',
#   'practise',
#   'exercise',
#   'do',
#   'suffice',
#   'do',
#   'answer',
#   'serve',
#   'do',
#   'make',
#   'act',
#   'behave',
#   'do',
#   'serve',
#   'do',
#   'do',
#   'manage',
#   'dress',
#   'arrange',
#   'set',
#   'do',
#   'coif',
#   'coiffe',
#   'coiffure',
#   'do',
#   'done',
#   'through',
#   'through_with',
#   'done'),
#  'already': ('already',),
#  'gon': (),
#  'na': ('sodium', 'na', 'atomic_number_11'),
#  'chillin': (),
#  'roomy': ('roommate', 'roomie', 'roomy', 'roomy', 'spacious'),
#  'wait': ('delay',
#   'hold',
#   'time_lag',
#   'postponement',
#   'wait',
#   'wait',
#   'waiting',
#   'wait',
#   'wait',
#   'hold_off',
#   'hold_back',
#   'expect',
#   'look',
#   'await',
#   'wait',
#   'wait',
#   'waitress'),
#  'zombie': ('zombi',
#   'zombie',
#   'living_dead',
#   'zombi',
#   'zombie',
#   'zombi_spirit',
#   'zombie_spirit',
#   'zombi',
#   'zombie',
#   'snake_god',
#   'automaton',
#   'zombi',
#   'zombie',
#   'zombie',
#   'zombi'),
#  'clwn': (),
#  'cr': ('chromium', 'cr', 'atomic_number_24'),
#  'week': ('week', 'hebdomad', 'workweek', 'week', 'week', 'calendar_week'),
#  'kno': (),
#  'doooo': (),
#  'yall': (),
#  'partyin': (),
#  'spilled': ('spill',
#   'slop',
#   'splatter',
#   'spill',
#   'run_out',
#   'spill',
#   'shed',
#   'disgorge',
#   'spill',
#   'shed',
#   'pour_forth',
#   'spill',
#   'talk',
#   'spill'),
#  'beer': ('beer',),
#  'leg': ('leg',
#   'leg',
#   'leg',
#   'branch',
#   'leg',
#   'ramification',
#   'leg',
#   'peg',
#   'wooden_leg',
#   'leg',
#   'pegleg',
#   'leg',
#   'leg',
#   'stage',
#   'leg'),
#  'wasted': ('waste',
#   'blow',
#   'squander',
#   'waste',
#   'waste',
#   'waste',
#   'run_off',
#   'neutralize',
#   'neutralise',
#   'liquidate',
#   'waste',
#   'knock_off',
#   'do_in',
#   'consume',
#   'squander',
#   'waste',
#   'ware',
#   'pine_away',
#   'waste',
#   'languish',
#   'waste',
#   'emaciate',
#   'macerate',
#   'lay_waste_to',
#   'waste',
#   'devastate',
#   'desolate',
#   'ravage',
#   'scourge',
#   'waste',
#   'rot',
#   'otiose',
#   'pointless',
#   'purposeless',
#   'senseless',
#   'superfluous',
#   'wasted',
#   'squandered',
#   'wasted',
#   'atrophied',
#   'wasted',
#   'diminished',
#   'bony',
#   'cadaverous',
#   'emaciated',
#   'gaunt',
#   'haggard',
#   'pinched',
#   'skeletal',
#   'wasted'),
#  'half': ('one-half', 'half', 'half', 'half', 'half', 'half', 'half'),
#  'home': ('home',
#   'place',
#   'dwelling',
#   'home',
#   'domicile',
#   'abode',
#   'habitation',
#   'dwelling_house',
#   'home',
#   'home_plate',
#   'home_base',
#   'home',
#   'plate',
#   'base',
#   'home',
#   'home',
#   'home',
#   'family',
#   'household',
#   'house',
#   'home',
#   'menage',
#   'home',
#   'nursing_home',
#   'rest_home',
#   'home',
#   'home',
#   'home',
#   'home',
#   'home',
#   'interior',
#   'internal',
#   'national',
#   'home',
#   'home',
#   'home'),
#  'met': ('meet',
#   'run_into',
#   'encounter',
#   'run_across',
#   'come_across',
#   'see',
#   'meet',
#   'get_together',
#   'converge',
#   'meet',
#   'meet',
#   'satisfy',
#   'fill',
#   'fulfill',
#   'fulfil',
#   'meet',
#   'fit',
#   'conform_to',
#   'meet',
#   'match',
#   'cope_with',
#   'meet',
#   'gather',
#   'assemble',
#   'forgather',
#   'foregather',
#   'meet',
#   'meet',
#   'meet',
#   'encounter',
#   'play',
#   'take_on',
#   'meet',
#   'encounter',
#   'receive',
#   'suffer',
#   'meet',
#   'touch',
#   'adjoin',
#   'meet',
#   'contact'),
#  'girl': ('girl',
#   'miss',
#   'missy',
#   'young_lady',
#   'young_woman',
#   'fille',
#   'female_child',
#   'girl',
#   'little_girl',
#   'daughter',
#   'girl',
#   'girlfriend',
#   'girl',
#   'lady_friend',
#   'girl'),
#  'good': ('good',
#   'good',
#   'goodness',
#   'good',
#   'goodness',
#   'commodity',
#   'trade_good',
#   'good',
#   'good',
#   'full',
#   'good',
#   'good',
#   'estimable',
#   'good',
#   'honorable',
#   'respectable',
#   'beneficial',
#   'good',
#   'good',
#   'good',
#   'just',
#   'upright',
#   'adept',
#   'expert',
#   'good',
#   'practiced',
#   'proficient',
#   'skillful',
#   'skilful',
#   'good',
#   'dear',
#   'good',
#   'near',
#   'dependable',
#   'good',
#   'safe',
#   'secure',
#   'good',
#   'right',
#   'ripe',
#   'good',
#   'well',
#   'effective',
#   'good',
#   'in_effect',
#   'in_force',
#   'good',
#   'good',
#   'serious',
#   'good',
#   'sound',
#   'good',
#   'salutary',
#   'good',
#   'honest',
#   'good',
#   'undecomposed',
#   'unspoiled',
#   'unspoilt',
#   'good',
#   'well',
#   'good',
#   'thoroughly',
#   'soundly',
#   'good'),
#  'conversation': ('conversation',),
#  'english': ('english',
#   'english_language',
#   'english',
#   'english_people',
#   'english',
#   'english',
#   'side',
#   'english',
#   'english'),
#  'class': ('class',
#   'category',
#   'family',
#   'class',
#   'form',
#   'grade',
#   'course',
#   'class',
#   'stratum',
#   'social_class',
#   'socio-economic_class',
#   'course',
#   'course_of_study',
#   'course_of_instruction',
#   'class',
#   'class',
#   'division',
#   'class',
#   'year',
#   'class',
#   'class',
#   'classify',
#   'class',
#   'sort',
#   'assort',
#   'sort_out',
#   'separate'),
#  'working': ('working',
#   'workings',
#   'work',
#   'work',
#   'do_work',
#   'work',
#   'act',
#   'function',
#   'work',
#   'operate',
#   'go',
#   'run',
#   'work',
#   'work_on',
#   'process',
#   'exercise',
#   'work',
#   'work_out',
#   'make',
#   'work',
#   'work',
#   'work',
#   'work',
#   'bring',
#   'work',
#   'play',
#   'wreak',
#   'make_for',
#   'work',
#   'put_to_work',
#   'cultivate',
#   'crop',
#   'work',
#   'work',
#   'influence',
#   'act_upon',
#   'work',
#   'work',
#   'work',
#   'work',
#   'work',
#   'shape',
#   'form',
#   'work',
#   'mold',
#   'mould',
#   'forge',
#   'work',
#   'knead',
#   'work',
#   'exploit',
#   'work',
#   'solve',
#   'work_out',
#   'figure_out',
#   'puzzle_out',
#   'lick',
#   'work',
#   'ferment',
#   'work',
#   'sour',
#   'turn',
#   'ferment',
#   'work',
#   'work',
#   'working',
#   'on_the_job',
#   'working',
#   'working',
#   'running',
#   'operative',
#   'functional',
#   'working',
#   'working'),
#  'interactive': ('synergistic', 'interactive', 'interactional', 'interactive'),
#  'oral': ('oral',
#   'oral_exam',
#   'oral_examination',
#   'viva_voce',
#   'viva',
#   'oral',
#   'unwritten',
#   'oral',
#   'oral',
#   'oral'),
#  'fb': (),
#  'boring': ('drilling',
#   'boring',
#   'boring',
#   'drilling',
#   'oil_production',
#   'bore',
#   'tire',
#   'bore',
#   'drill',
#   'boring',
#   'deadening',
#   'dull',
#   'ho-hum',
#   'irksome',
#   'slow',
#   'tedious',
#   'tiresome',
#   'wearisome'),
#  'wan': ('wide_area_network',
#   'wan',
#   'wan',
#   'pale',
#   'pallid',
#   'wan',
#   'sick',
#   'pale',
#   'pallid',
#   'wan',
#   'wan'),
#  'sing': ('sing',
#   'sing',
#   'sing',
#   'whistle',
#   'sing',
#   'spill_the_beans',
#   'let_the_cat_out_of_the_bag',
#   'talk',
#   'tattle',
#   'blab',
#   'peach',
#   'babble',
#   'sing',
#   'babble_out',
#   'blab_out'),
#  'right': ('right',
#   'right',
#   'right_field',
#   'rightfield',
#   'right',
#   'right',
#   'right_wing',
#   'right',
#   'right_hand',
#   'right',
#   'right',
#   'rightfulness',
#   'right',
#   'right',
#   'compensate',
#   'redress',
#   'correct',
#   'right',
#   'right',
#   'correct',
#   'rectify',
#   'right',
#   'right',
#   'correct',
#   'right',
#   'correct',
#   'right',
#   'right',
#   'right',
#   'correct',
#   'proper',
#   'right',
#   'right',
#   'right',
#   'right',
#   'right-hand',
#   'correct',
#   'right',
#   'right',
#   'right',
#   'good',
#   'right',
#   'ripe',
#   'veracious',
#   'right',
#   'right',
#   'right',
#   'right',
#   'flop',
#   'right',
#   'properly',
#   'decently',
#   'decent',
#   'in_good_order',
#   'right',
#   'the_right_way',
#   'right',
#   'right_on',
#   'right',
#   'mighty',
#   'mightily',
#   'powerful',
#   'right',
#   'justly',
#   'right',
#   'correctly',
#   'right',
#   'aright'),
#  'must': ('must', 'must', 'mustiness', 'must', 'moldiness', 'must'),
#  'new': ('new',
#   'fresh',
#   'new',
#   'novel',
#   'raw',
#   'new',
#   'new',
#   'unexampled',
#   'new',
#   'new',
#   'newfangled',
#   'new',
#   'new',
#   'modern',
#   'new',
#   'new',
#   'young',
#   'new',
#   'newly',
#   'freshly',
#   'fresh',
#   'new'),
#  'music': ('music', 'music', 'euphony', 'music', 'music', 'music', 'medicine'),
#  'wont': ('habit', 'wont'),
#  'sleep': ('sleep',
#   'slumber',
#   'sleep',
#   'sopor',
#   'sleep',
#   'nap',
#   'rest',
#   'eternal_rest',
#   'sleep',
#   'eternal_sleep',
#   'quietus',
#   'sleep',
#   'kip',
#   'slumber',
#   "log_z's",
#   "catch_some_z's",
#   'sleep'),
#  'give': ('give',
#   'spring',
#   'springiness',
#   'give',
#   'yield',
#   'give',
#   'afford',
#   'give',
#   'give',
#   'give',
#   'pay',
#   'hold',
#   'throw',
#   'have',
#   'make',
#   'give',
#   'give',
#   'throw',
#   'give',
#   'gift',
#   'present',
#   'give',
#   'yield',
#   'give',
#   'pay',
#   'devote',
#   'render',
#   'yield',
#   'return',
#   'give',
#   'generate',
#   'impart',
#   'leave',
#   'give',
#   'pass_on',
#   'establish',
#   'give',
#   'give',
#   'give',
#   'sacrifice',
#   'give',
#   'pass',
#   'hand',
#   'reach',
#   'pass_on',
#   'turn_over',
#   'give',
#   'give',
#   'dedicate',
#   'consecrate',
#   'commit',
#   'devote',
#   'give',
#   'give',
#   'apply',
#   'give',
#   'render',
#   'grant',
#   'give',
#   'move_over',
#   'give_way',
#   'give',
#   'ease_up',
#   'yield',
#   'feed',
#   'give',
#   'contribute',
#   'give',
#   'chip_in',
#   'kick_in',
#   'collapse',
#   'fall_in',
#   'cave_in',
#   'give',
#   'give_way',
#   'break',
#   'founder',
#   'give',
#   'give',
#   'give',
#   'afford',
#   'open',
#   'give',
#   'give',
#   'give',
#   'give',
#   'yield',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give',
#   'give'),
#  'chapter': ('chapter', 'chapter', 'chapter', 'chapter', 'chapter'),
#  'might': ('might', 'mightiness', 'power'),
#  'die': ('die',
#   'dice',
#   'die',
#   'die',
#   'die',
#   'decease',
#   'perish',
#   'go',
#   'exit',
#   'pass_away',
#   'expire',
#   'pass',
#   'kick_the_bucket',
#   "cash_in_one's_chips",
#   'buy_the_farm',
#   'conk',
#   'give-up_the_ghost',
#   'drop_dead',
#   'pop_off',
#   'choke',
#   'croak',
#   'snuff_it',
#   'die',
#   'die',
#   'fail',
#   'go_bad',
#   'give_way',
#   'die',
#   'give_out',
#   'conk_out',
#   'go',
#   'break',
#   'break_down',
#   'die',
#   'die',
#   'die',
#   'die_out',
#   'die',
#   'die',
#   'pall',
#   'become_flat',
#   'die',
#   'die'),
#  'first': ('first',
#   'number_one',
#   'first',
#   'number_one',
#   'number_1',
#   'beginning',
#   'commencement',
#   'first',
#   'outset',
#   'get-go',
#   'start',
#   'kickoff',
#   'starting_time',
#   'showtime',
#   'offset',
#   'first_base',
#   'first',
#   'first',
#   'first-class_honours_degree',
#   'first_gear',
#   'first',
#   'low_gear',
#   'low',
#   'first',
#   'first',
#   '1st',
#   'inaugural',
#   'initiative',
#   'initiatory',
#   'first',
#   'maiden',
#   'beginning',
#   'first',
#   'first',
#   'foremost',
#   'world-class',
#   'first',
#   'first',
#   'firstly',
#   'foremost',
#   'first_of_all',
#   'first_off',
#   'first',
#   'for_the_first_time',
#   'first',
#   'foremost',
#   'first'),
#  'though': ('though',),
#  'hurry': ('hurry',
#   'haste',
#   'haste',
#   'hastiness',
#   'hurry',
#   'hurriedness',
#   'precipitation',
#   'haste',
#   'hurry',
#   'rush',
#   'rushing',
#   'travel_rapidly',
#   'speed',
#   'hurry',
#   'zip',
#   'rush',
#   'hasten',
#   'hurry',
#   'look_sharp',
#   'festinate',
#   'rush',
#   'hurry'),
#  'noooooooooooo': (),
#  'look': ('expression',
#   'look',
#   'aspect',
#   'facial_expression',
#   'face',
#   'look',
#   'looking',
#   'looking_at',
#   'look',
#   'spirit',
#   'tone',
#   'feel',
#   'feeling',
#   'flavor',
#   'flavour',
#   'look',
#   'smell',
#   'look',
#   'look',
#   'appear',
#   'seem',
#   'look',
#   'search',
#   'look',
#   'front',
#   'look',
#   'face',
#   'attend',
#   'take_care',
#   'look',
#   'see',
#   'look',
#   'expect',
#   'look',
#   'await',
#   'wait',
#   'look',
#   'count',
#   'bet',
#   'depend',
#   'look',
#   'calculate',
#   'reckon'),
#  'lot': ('batch',
#   'deal',
#   'flock',
#   'good_deal',
#   'great_deal',
#   'hatful',
#   'heap',
#   'lot',
#   'mass',
#   'mess',
#   'mickle',
#   'mint',
#   'mountain',
#   'muckle',
#   'passel',
#   'peck',
#   'pile',
#   'plenty',
#   'pot',
#   'quite_a_little',
#   'raft',
#   'sight',
#   'slew',
#   'spate',
#   'stack',
#   'tidy_sum',
#   'wad',
#   'lot',
#   'set',
#   'circle',
#   'band',
#   'lot',
#   'fortune',
#   'destiny',
#   'fate',
#   'luck',
#   'lot',
#   'circumstances',
#   'portion',
#   'draw',
#   'lot',
#   'bunch',
#   'lot',
#   'caboodle',
#   'lot',
#   'lot',
#   'distribute',
#   'administer',
#   'mete_out',
#   'deal',
#   'parcel_out',
#   'lot',
#   'dispense',
#   'shell_out',
#   'deal_out',
#   'dish_out',
#   'allot',
#   'dole_out'),
#  'lol': (),
#  'demi': (),
#  'hi': ('hello',
#   'hullo',
#   'hi',
#   'howdy',
#   'how-do-you-do',
#   'hawaii',
#   "hawai'i",
#   'aloha_state',
#   'hi'),
#  'enough': ('enough',
#   'sufficiency',
#   'adequate',
#   'decent',
#   'enough',
#   'enough',
#   'plenty'),
#  'replay': ('replay',
#   'rematch',
#   'replay',
#   'instant_replay',
#   'action_replay',
#   'play_back',
#   'replay',
#   'replay',
#   'replay',
#   'replay'),
#  'please': ('please', 'delight', 'please', 'please', 'please'),
#  'love': ('love',
#   'love',
#   'passion',
#   'beloved',
#   'dear',
#   'dearest',
#   'honey',
#   'love',
#   'love',
#   'sexual_love',
#   'erotic_love',
#   'love',
#   'sexual_love',
#   'lovemaking',
#   'making_love',
#   'love',
#   'love_life',
#   'love',
#   'love',
#   'enjoy',
#   'love',
#   'sleep_together',
#   'roll_in_the_hay',
#   'love',
#   'make_out',
#   'make_love',
#   'sleep_with',
#   'get_laid',
#   'have_sex',
#   'know',
#   'do_it',
#   'be_intimate',
#   'have_intercourse',
#   'have_it_away',
#   'have_it_off',
#   'screw',
#   'fuck',
#   'jazz',
#   'eff',
#   'hump',
#   'lie_with',
#   'bed',
#   'have_a_go_at_it',
#   'bang',
#   'get_it_on',
#   'bonk'),
#  'big': ('large',
#   'big',
#   'big',
#   'bad',
#   'big',
#   'big',
#   'big',
#   'large',
#   'prominent',
#   'big',
#   'heavy',
#   'boastful',
#   'braggart',
#   'bragging',
#   'braggy',
#   'big',
#   'cock-a-hoop',
#   'crowing',
#   'self-aggrandizing',
#   'self-aggrandising',
#   'big',
#   'swelled',
#   'vainglorious',
#   'adult',
#   'big',
#   'full-grown',
#   'fully_grown',
#   'grown',
#   'grownup',
#   'big',
#   'big',
#   'large',
#   'magnanimous',
#   'big',
#   'bighearted',
#   'bounteous',
#   'bountiful',
#   'freehanded',
#   'handsome',
#   'giving',
#   'liberal',
#   'openhanded',
#   'big',
#   'enceinte',
#   'expectant',
#   'gravid',
#   'great',
#   'large',
#   'heavy',
#   'with_child',
#   'big',
#   'boastfully',
#   'vauntingly',
#   'big',
#   'large',
#   'big',
#   'big'),
#  'vanessa': ('vanessa', 'genus_vanessa'),
#  'going': ('departure',
#   'going',
#   'going_away',
#   'leaving',
#   'passing',
#   'loss',
#   'departure',
#   'exit',
#   'expiration',
#   'going',
#   'release',
#   'going',
#   'sledding',
#   'travel',
#   'go',
#   'move',
#   'locomote',
#   'go',
#   'proceed',
#   'move',
#   'go',
#   'go_away',
#   'depart',
#   'become',
#   'go',
#   'get',
#   'go',
#   'run',
#   'go',
#   'run',
#   'go',
#   'pass',
#   'lead',
#   'extend',
#   'proceed',
#   'go',
#   'go',
#   'go',
#   'sound',
#   'go',
#   'function',
#   'work',
#   'operate',
#   'go',
#   'run',
#   'run_low',
#   'run_short',
#   'go',
#   'move',
#   'go',
#   'run',
#   'survive',
#   'last',
#   'live',
#   'live_on',
#   'go',
#   'endure',
#   'hold_up',
#   'hold_out',
#   'go',
#   'die',
#   'decease',
#   'perish',
#   'go',
#   'exit',
#   'pass_away',
#   'expire',
#   'pass',
#   'kick_the_bucket',
#   "cash_in_one's_chips",
#   'buy_the_farm',
#   'conk',
#   'give-up_the_ghost',
#   'drop_dead',
#   'pop_off',
#   'choke',
#   'croak',
#   'snuff_it',
#   'belong',
#   'go',
#   'go',
#   'start',
#   'go',
#   'get_going',
#   'move',
#   'go',
#   'go',
#   'go',
#   'blend',
#   'go',
#   'blend_in',
#   'go',
#   'lead',
#   'fit',
#   'go',
#   'rifle',
#   'go',
#   'go',
#   'plump',
#   'go',
#   'fail',
#   'go_bad',
#   'give_way',
#   'die',
#   'give_out',
#   'conk_out',
#   'go',
#   'break',
#   'break_down',
#   'going'),
#  'september': ('september', 'sep', 'sept'),
#  'fast': ('fast',
#   'fasting',
#   'fast',
#   'fast',
#   'fast',
#   'fast',
#   'fast',
#   'fast',
#   'fast',
#   'debauched',
#   'degenerate',
#   'degraded',
#   'dissipated',
#   'dissolute',
#   'libertine',
#   'profligate',
#   'riotous',
#   'fast',
#   'flying',
#   'quick',
#   'fast',
#   'fast',
#   'firm',
#   'immobile',
#   'firm',
#   'loyal',
#   'truehearted',
#   'fast',
#   'fast',
#   'fast',
#   'fast',
#   'tight'),
#  'hard': ('difficult',
#   'hard',
#   'hard',
#   'hard',
#   'hard',
#   'knockout',
#   'severe',
#   'arduous',
#   'backbreaking',
#   'grueling',
#   'gruelling',
#   'hard',
#   'heavy',
#   'laborious',
#   'operose',
#   'punishing',
#   'toilsome',
#   'unvoiced',
#   'voiceless',
#   'surd',
#   'hard',
#   'hard',
#   'concentrated',
#   'hard',
#   'intemperate',
#   'hard',
#   'heavy',
#   'hard',
#   'strong',
#   'hard',
#   'tough',
#   'hard',
#   'hard',
#   'hard',
#   'firmly',
#   'hard',
#   'hard',
#   'severely',
#   'hard',
#   'heavily',
#   'intemperately',
#   'hard',
#   'hard',
#   'hard',
#   'hard',
#   'hard'),
#  'cuz': (),
#  'im': (),
#  'workin': (),
#  'miss': ('girl',
#   'miss',
#   'missy',
#   'young_lady',
#   'young_woman',
#   'fille',
#   'miss',
#   'misfire',
#   'miss',
#   'miss',
#   'lose',
#   'miss',
#   'miss',
#   'neglect',
#   'pretermit',
#   'omit',
#   'drop',
#   'miss',
#   'leave_out',
#   'overlook',
#   'overleap',
#   'miss',
#   'miss',
#   'lack',
#   'miss',
#   'miss',
#   'miss',
#   'escape'),
#  'alot': (),
#  'lord': ('godhead',
#   'lord',
#   'creator',
#   'maker',
#   'divine',
#   'god_almighty',
#   'almighty',
#   'jehovah',
#   'overlord',
#   'master',
#   'lord',
#   'lord',
#   'noble',
#   'nobleman',
#   'lord'),
#  'seen': ('see',
#   'understand',
#   'realize',
#   'realise',
#   'see',
#   'witness',
#   'find',
#   'see',
#   'visualize',
#   'visualise',
#   'envision',
#   'project',
#   'fancy',
#   'see',
#   'figure',
#   'picture',
#   'image',
#   'see',
#   'consider',
#   'reckon',
#   'view',
#   'regard',
#   'learn',
#   'hear',
#   'get_word',
#   'get_wind',
#   'pick_up',
#   'find_out',
#   'get_a_line',
#   'discover',
#   'see',
#   'watch',
#   'view',
#   'see',
#   'catch',
#   'take_in',
#   'meet',
#   'run_into',
#   'encounter',
#   'run_across',
#   'come_across',
#   'see',
#   'determine',
#   'check',
#   'find_out',
#   'see',
#   'ascertain',
#   'watch',
#   'learn',
#   'see',
#   'check',
#   'insure',
#   'see_to_it',
#   'ensure',
#   'control',
#   'ascertain',
#   'assure',
#   'see',
#   'see',
#   'visit',
#   'see',
#   'attend',
#   'take_care',
#   'look',
#   'see',
#   'see',
#   'go_steady',
#   'go_out',
#   'date',
#   'see',
#   'see',
#   'see',
#   'see',
#   'examine',
#   'see',
#   'experience',
#   'see',
#   'go_through',
#   'see',
#   'escort',
#   'see',
#   'interpret',
#   'construe',
#   'see'),
#  'agency': ('agency',
#   'federal_agency',
#   'government_agency',
#   'bureau',
#   'office',
#   'authority',
#   'agency',
#   'agency',
#   'representation',
#   'delegacy',
#   'agency',
#   'means',
#   'agency',
#   'way'),
#  'upcoming': ('approaching', 'coming', 'forthcoming', 'upcoming'),
#  'open': ('open',
#   'clear',
#   'outdoors',
#   'out-of-doors',
#   'open_air',
#   'open',
#   'open',
#   'open',
#   'surface',
#   'open',
#   'open_up',
#   'open',
#   'open_up',
#   'open',
#   'open_up',
#   'open',
#   'unfold',
#   'spread',
#   'spread_out',
#   'open',
#   'open',
#   'open_up',
#   'open',
#   'open_up',
#   'open',
#   'open',
#   'afford',
#   'open',
#   'give',
#   'open',
#   'open',
#   'unfastened',
#   'open',
#   'exposed',
#   'open',
#   'open',
#   'open',
#   'opened',
#   'open',
#   'open',
#   'assailable',
#   'undefendable',
#   'undefended',
#   'open',
#   'loose',
#   'open',
#   'open',
#   'open',
#   'open',
#   'undecided',
#   'undetermined',
#   'unresolved',
#   'open',
#   'opened',
#   'open',
#   'receptive',
#   'open',
#   'overt',
#   'open',
#   'open',
#   'capable',
#   'open',
#   'subject',
#   'clear',
#   'open',
#   'candid',
#   'open',
#   'heart-to-heart',
#   'open'),
#  'money': ('money', 'money', 'money'),
#  'jam': ('jam',
#   'fix',
#   'hole',
#   'jam',
#   'mess',
#   'muddle',
#   'pickle',
#   'kettle_of_fish',
#   'crush',
#   'jam',
#   'press',
#   'jamming',
#   'electronic_jamming',
#   'jam',
#   'throng',
#   'mob',
#   'pack',
#   'pile',
#   'jam',
#   'jam',
#   'jam',
#   'crush',
#   'jam',
#   'block',
#   'jam',
#   'jam',
#   'jampack',
#   'ram',
#   'chock_up',
#   'cram',
#   'wad',
#   'obstruct',
#   'obturate',
#   'impede',
#   'occlude',
#   'jam',
#   'block',
#   'close_up'),
#  'foster': ('foster',
#   'stephen_foster',
#   'stephen_collins_foster',
#   'foster',
#   'further',
#   'foster',
#   'foster',
#   'nurture',
#   'foster',
#   'surrogate'),
#  'kitten': ('kitten', 'kitty', 'kitten'),
#  'getting': ('acquiring',
#   'getting',
#   'get',
#   'acquire',
#   'become',
#   'go',
#   'get',
#   'get',
#   'let',
#   'have',
#   'receive',
#   'get',
#   'find',
#   'obtain',
#   'incur',
#   'arrive',
#   'get',
#   'come',
#   'bring',
#   'get',
#   'convey',
#   'fetch',
#   'experience',
#   'receive',
#   'have',
#   'get',
#   'pay_back',
#   'pay_off',
#   'get',
#   'fix',
#   'have',
#   'get',
#   'make',
#   'induce',
#   'stimulate',
#   'cause',
#   'have',
#   'get',
#   'make',
#   'get',
#   'catch',
#   'capture',
#   'grow',
#   'develop',
#   'produce',
#   'get',
#   'acquire',
#   'contract',
#   'take',
#   'get',
#   'get',
#   'make',
#   'get',
#   'drive',
#   'get',
#   'aim',
#   'catch',
#   'get',
#   'catch',
#   'arrest',
#   'get',
#   'get',
#   'catch',
#   'get',
#   'get',
#   'get',
#   'catch',
#   'get',
#   'catch',
#   'get',
#   'get',
#   'receive',
#   'scram',
#   'buzz_off',
#   'fuck_off',
#   'get',
#   'bugger_off',
#   'get',
#   'get',
#   "get_under_one's_skin",
#   'get',
#   'catch',
#   'get',
#   'draw',
#   'get',
#   'get',
#   'perplex',
#   'vex',
#   'stick',
#   'get',
#   'puzzle',
#   'mystify',
#   'baffle',
#   'beat',
#   'pose',
#   'bewilder',
#   'flummox',
#   'stupefy',
#   'nonplus',
#   'gravel',
#   'amaze',
#   'dumbfound',
#   'get_down',
#   'begin',
#   'get',
#   'start_out',
#   'start',
#   'set_about',
#   'set_out',
#   'commence',
#   'suffer',
#   'sustain',
#   'have',
#   'get',
#   'beget',
#   'get',
#   'engender',
#   'father',
#   'mother',
#   'sire',
#   'generate',
#   'bring_forth'),
#  'bigchubba': (),
#  'winston': (),
#  'b': ('bacillus',
#   'b',
#   'b-complex_vitamin',
#   'b_complex',
#   'vitamin_b_complex',
#   'vitamin_b',
#   'b_vitamin',
#   'b',
#   'boron',
#   'b',
#   'atomic_number_5',
#   'bel',
#   'b',
#   'barn',
#   'b',
#   'b',
#   'b',
#   'b',
#   'type_b',
#   'group_b'),
#  'missed': ('miss',
#   'lose',
#   'miss',
#   'miss',
#   'neglect',
#   'pretermit',
#   'omit',
#   'drop',
#   'miss',
#   'leave_out',
#   'overlook',
#   'overleap',
#   'miss',
#   'miss',
#   'lack',
#   'miss',
#   'miss',
#   'miss',
#   'escape',
#   'lost',
#   'missed'),
#  'amazing': ('amaze',
#   'astonish',
#   'astound',
#   'perplex',
#   'vex',
#   'stick',
#   'get',
#   'puzzle',
#   'mystify',
#   'baffle',
#   'beat',
#   'pose',
#   'bewilder',
#   'flummox',
#   'stupefy',
#   'nonplus',
#   'gravel',
#   'amaze',
#   'dumbfound',
#   'amazing',
#   'astonishing',
#   'amazing',
#   'awe-inspiring',
#   'awesome',
#   'awful',
#   'awing'),
#  'ready': ('ready',
#   'cook',
#   'fix',
#   'ready',
#   'make',
#   'prepare',
#   'fix',
#   'prepare',
#   'set_up',
#   'ready',
#   'gear_up',
#   'set',
#   'ready',
#   'ready',
#   'ready',
#   'ready',
#   'quick',
#   'ready'),
#  'school': ('school',
#   'school',
#   'schoolhouse',
#   'school',
#   'schooling',
#   'school',
#   'school',
#   'schooltime',
#   'school_day',
#   'school',
#   'school',
#   'shoal',
#   'school',
#   'educate',
#   'school',
#   'train',
#   'cultivate',
#   'civilize',
#   'civilise',
#   'school'),
#  'second': ('second',
#   'sec',
#   's',
#   'moment',
#   'mo',
#   'minute',
#   'second',
#   'bit',
#   'second_base',
#   'second',
#   'moment',
#   'minute',
#   'second',
#   'instant',
#   'second',
#   'second',
#   'arcsecond',
#   'second',
#   'second',
#   'secondment',
#   'endorsement',
#   'indorsement',
#   'second_gear',
#   'second',
#   'irregular',
#   'second',
#   'second',
#   'back',
#   'endorse',
#   'indorse',
#   'second',
#   'second',
#   '2nd',
#   '2d',
#   'second',
#   'second',
#   'secondly'),
#  'rd': (),
#  'year': ('year', 'twelvemonth', 'yr', 'year', 'year', 'class', 'year'),
#  'next': ('following',
#   'next',
#   'adjacent',
#   'next',
#   'side_by_side',
#   'future',
#   'next',
#   'succeeding',
#   'next'),
#  'officially': ('officially', 'formally', 'officially'),
#  'th': ('thursday', 'th', 'thorium', 'th', 'atomic_number_90'),
#  'friday': ('friday', 'fri'),
#  'yay': ('yay',),
#  'bonus': ('bonus', 'fillip', 'bonus', 'incentive'),
#  'dont': (),
#  'drive': ('drive',
#   'thrust',
#   'driving_force',
#   'drive',
#   'campaign',
#   'cause',
#   'crusade',
#   'drive',
#   'movement',
#   'effort',
#   'driveway',
#   'drive',
#   'private_road',
#   'drive',
#   'drive',
#   'driving',
#   'drive',
#   'drive',
#   'ride',
#   'drive',
#   'drive',
#   'drive',
#   'parkway',
#   'drive',
#   'drive',
#   'drive',
#   'motor',
#   'drive',
#   'force',
#   'drive',
#   'ram',
#   'drive',
#   'repel',
#   'drive',
#   'repulse',
#   'force_back',
#   'push_back',
#   'beat_back',
#   'drive',
#   'drive',
#   'drive',
#   'tug',
#   'labor',
#   'labour',
#   'push',
#   'drive',
#   'drive',
#   'get',
#   'aim',
#   'drive',
#   'ride',
#   'drive',
#   'drive',
#   'drive',
#   'drive',
#   'take',
#   'drive',
#   'drive',
#   'drive',
#   'drive',
#   'drive',
#   'drive'),
#  'wale': ('wale', 'welt', 'weal', 'wheal', 'wale', 'strake'),
#  'tonight': ('tonight', 'tonight', 'this_evening', 'this_night'),
#  'athough': (),
#  'cuddle': ('cuddle',
#   'nestle',
#   'snuggle',
#   'cuddle',
#   'snuggle',
#   'nestle',
#   'nest',
#   'nuzzle',
#   'draw_close',
#   'cuddle'),
#  'ride': ('drive',
#   'ride',
#   'ride',
#   'ride',
#   'sit',
#   'ride',
#   'ride',
#   'ride',
#   'tease',
#   'razz',
#   'rag',
#   'cod',
#   'tantalize',
#   'tantalise',
#   'bait',
#   'taunt',
#   'twit',
#   'rally',
#   'ride',
#   'ride',
#   'drive',
#   'ride',
#   'depend_on',
#   'devolve_on',
#   'depend_upon',
#   'ride',
#   'turn_on',
#   'hinge_on',
#   'hinge_upon',
#   'ride',
#   'ride',
#   'ride',
#   'ride',
#   'ride',
#   'ride',
#   'mount'),
#  'ok': ('oklahoma',
#   'sooner_state',
#   'ok',
#   'o.k.',
#   'ok',
#   'okay',
#   'okey',
#   'okeh',
#   'all_right',
#   'fine',
#   'o.k.',
#   'ok',
#   'okay',
#   'hunky-dory',
#   'very_well',
#   'fine',
#   'alright',
#   'all_right',
#   'ok'),
#  'shoe': ('shoe',
#   'shoe',
#   'horseshoe',
#   'shoe',
#   'brake_shoe',
#   'shoe',
#   'skid',
#   'shoe'),
#  'club': ('baseball_club',
#   'ball_club',
#   'club',
#   'nine',
#   'club',
#   'social_club',
#   'society',
#   'guild',
#   'gild',
#   'lodge',
#   'order',
#   'club',
#   'clubhouse',
#   'club',
#   'golf_club',
#   'golf-club',
#   'club',
#   'club',
#   'cabaret',
#   'nightclub',
#   'night_club',
#   'club',
#   'nightspot',
#   'club',
#   'club',
#   'club',
#   'bludgeon',
#   'club'),
#  'cool': ('cool',
#   'aplomb',
#   'assuredness',
#   'cool',
#   'poise',
#   'sang-froid',
#   'cool',
#   'chill',
#   'cool_down',
#   'cool',
#   'chill',
#   'cool_down',
#   'cool',
#   'cool_off',
#   'cool_down',
#   'cool',
#   'cool',
#   'coolheaded',
#   'nerveless',
#   'cool',
#   'cool',
#   'cool',
#   'cool'),
#  'fun': ('fun',
#   'merriment',
#   'playfulness',
#   'fun',
#   'play',
#   'sport',
#   'fun',
#   'playfulness',
#   'fun'),
#  'poppin': (),
#  'except': ('demur',
#   'except',
#   'exclude',
#   'except',
#   'leave_out',
#   'leave_off',
#   'omit',
#   'take_out'),
#  'ppl': (),
#  'tryna': (),
#  'dance': ('dance',
#   'dance',
#   'dancing',
#   'dance',
#   'terpsichore',
#   'saltation',
#   'dance',
#   'dance',
#   'dance',
#   'trip_the_light_fantastic',
#   'trip_the_light_fantastic_toe',
#   'dance'),
#  'wit': ('wit',
#   'humor',
#   'humour',
#   'witticism',
#   'wittiness',
#   'brain',
#   'brainpower',
#   'learning_ability',
#   'mental_capacity',
#   'mentality',
#   'wit',
#   'wag',
#   'wit',
#   'card'),
#  'emmy': ('emmy',),
#  'latin': ('latin',
#   'latin',
#   'latin',
#   'latin',
#   'latin',
#   'romance',
#   'latin',
#   'latin'),
#  'would': (),
#  'help': ('aid',
#   'assist',
#   'assistance',
#   'help',
#   'assistant',
#   'helper',
#   'help',
#   'supporter',
#   'aid',
#   'assistance',
#   'help',
#   'avail',
#   'help',
#   'service',
#   'help',
#   'assist',
#   'aid',
#   'help',
#   'aid',
#   'help',
#   'facilitate',
#   'help_oneself',
#   'help',
#   'serve',
#   'help',
#   'help',
#   'avail',
#   'help',
#   'help'),
#  'study': ('survey',
#   'study',
#   'study',
#   'work',
#   'report',
#   'study',
#   'written_report',
#   'study',
#   'study',
#   'discipline',
#   'subject',
#   'subject_area',
#   'subject_field',
#   'field',
#   'field_of_study',
#   'study',
#   'bailiwick',
#   'sketch',
#   'study',
#   'cogitation',
#   'study',
#   'study',
#   'study',
#   'analyze',
#   'analyse',
#   'study',
#   'examine',
#   'canvass',
#   'canvas',
#   'study',
#   'study',
#   'consider',
#   'learn',
#   'study',
#   'read',
#   'take',
# ...
#   'fin',
#   'phoebe',
#   'little_phoebe',
#   'basketball_team',
#   'five',
#   'five-spot',
#   'five',
#   'five',
#   '5',
#   'v'),
#  'exploring': ('research',
#   'search',
#   'explore',
#   'explore',
#   'explore',
#   'explore'),
#  'ur': ('ur',),
#  'chance': ('opportunity',
#   'chance',
#   'luck',
#   'fortune',
#   'chance',
#   'hazard',
#   'chance',
#   'probability',
#   'chance',
#   'prospect',
#   'chance',
#   'chance',
#   'gamble',
#   'chance',
#   'risk',
#   'hazard',
#   'take_chances',
#   'adventure',
#   'run_a_risk',
#   'take_a_chance',
#   'find',
#   'happen',
#   'chance',
#   'bump',
#   'encounter',
#   'casual',
#   'chance'),
#  'else': (),
#  'name': ('name',
#   'name',
#   'name',
#   'gens',
#   'name',
#   'figure',
#   'public_figure',
#   'name',
#   'name',
#   'epithet',
#   'name',
#   'call',
#   'name',
#   'identify',
#   'name',
#   'nominate',
#   'make',
#   'appoint',
#   'name',
#   'nominate',
#   'constitute',
#   'name',
#   'mention',
#   'advert',
#   'bring_up',
#   'cite',
#   'name',
#   'refer',
#   'identify',
#   'discover',
#   'key',
#   'key_out',
#   'distinguish',
#   'describe',
#   'name',
#   'list',
#   'name',
#   'diagnose',
#   'name'),
#  'nite': (),
#  'youtube': (),
#  'yippeewish': (),
#  'keep': ('support',
#   'keep',
#   'livelihood',
#   'living',
#   'bread_and_butter',
#   'sustenance',
#   'keep',
#   'donjon',
#   'dungeon',
#   'hold',
#   'keep',
#   'keep',
#   'maintain',
#   'hold',
#   'continue',
#   'go_on',
#   'proceed',
#   'go_along',
#   'keep',
#   'keep',
#   'hold_on',
#   'prevent',
#   'keep',
#   'observe',
#   'keep',
#   'observe',
#   'keep',
#   'maintain',
#   'keep',
#   'keep',
#   'maintain',
#   'keep',
#   'retain',
#   'continue',
#   'keep',
#   'keep_on',
#   'sustain',
#   'keep',
#   'maintain',
#   'keep',
#   'stay_fresh',
#   'observe',
#   'celebrate',
#   'keep',
#   'restrain',
#   'keep',
#   'keep_back',
#   'hold_back',
#   'keep',
#   'preserve',
#   'keep',
#   'keep_open',
#   'hold_open',
#   'keep',
#   'save',
#   'keep',
#   'keep',
#   'keep',
#   'maintain',
#   'keep',
#   'preserve',
#   'keep'),
#  'company': ('company',
#   'company',
#   'company',
#   'companionship',
#   'fellowship',
#   'society',
#   'company',
#   'troupe',
#   'caller',
#   'company',
#   'company',
#   'party',
#   'company',
#   "ship's_company",
#   'company',
#   'company',
#   'company',
#   'companion',
#   'accompany',
#   'keep_company'),
#  'hahah': (),
#  'geez': (),
#  'ago': ('ago', 'agone', 'ago'),
#  'lack': ('lack', 'deficiency', 'want', 'miss', 'lack'),
#  'many': ('many',),
#  'hot': ('hot',
#   'hot',
#   'raging',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'blistering',
#   'hot',
#   'red-hot',
#   'hot',
#   'hot',
#   'spicy',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'red-hot',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'hot',
#   'live',
#   'hot'),
#  'town': ('town',
#   'town',
#   'townspeople',
#   'townsfolk',
#   'township',
#   'town',
#   'town',
#   'ithiel_town'),
#  'candy': ('candy', 'confect', 'sugarcoat', 'glaze', 'candy'),
#  'store': ('shop',
#   'store',
#   'store',
#   'stock',
#   'fund',
#   'memory',
#   'computer_memory',
#   'storage',
#   'computer_storage',
#   'store',
#   'memory_board',
#   'storehouse',
#   'depot',
#   'entrepot',
#   'storage',
#   'store',
#   'store',
#   'hive_away',
#   'lay_in',
#   'put_in',
#   'salt_away',
#   'stack_away',
#   'stash_away',
#   'store'),
#  'straight': ('heterosexual',
#   'heterosexual_person',
#   'straight_person',
#   'straight',
#   'straight',
#   'straightaway',
#   'straight',
#   'straight',
#   'consecutive',
#   'straight',
#   'straight',
#   'straight',
#   'unbent',
#   'unbowed',
#   'straight',
#   'straight',
#   'square',
#   'uncoiled',
#   'straight',
#   'straight',
#   'straight',
#   'straight',
#   'true',
#   'straight',
#   'square',
#   'straightforward',
#   'straight',
#   'neat',
#   'straight',
#   'full-strength',
#   'straight',
#   'square',
#   'straight',
#   'directly',
#   'straight',
#   'direct',
#   'directly',
#   'flat',
#   'straight',
#   'straight'),
#  'sweet': ('sweet',
#   'henry_sweet',
#   'dessert',
#   'sweet',
#   'afters',
#   'sweet',
#   'confection',
#   'sweet',
#   'sweetness',
#   'sugariness',
#   'sweetness',
#   'sweet',
#   'sweet',
#   'angelic',
#   'angelical',
#   'cherubic',
#   'seraphic',
#   'sweet',
#   'dulcet',
#   'honeyed',
#   'mellifluous',
#   'mellisonant',
#   'sweet',
#   'sweet',
#   'gratifying',
#   'sweet',
#   'odoriferous',
#   'odorous',
#   'perfumed',
#   'scented',
#   'sweet',
#   'sweet-scented',
#   'sweet-smelling',
#   'sweet',
#   'fresh',
#   'sweet',
#   'fresh',
#   'sweet',
#   'unfermented',
#   'sugared',
#   'sweetened',
#   'sweet',
#   'sweet-flavored',
#   'sweetly',
#   'sweet'),
#  'hotel': ('hotel',),
#  'note': ('note',
#   'note',
#   'short_letter',
#   'line',
#   'billet',
#   'note',
#   'musical_note',
#   'tone',
#   'note',
#   'note',
#   'bill',
#   'note',
#   'government_note',
#   'bank_bill',
#   "banker's_bill",
#   'bank_note',
#   'banknote',
#   'federal_reserve_note',
#   'greenback',
#   'note',
#   'annotation',
#   'notation',
#   'eminence',
#   'distinction',
#   'preeminence',
#   'note',
#   'note',
#   'promissory_note',
#   'note_of_hand',
#   'note',
#   'observe',
#   'mention',
#   'remark',
#   'notice',
#   'mark',
#   'note',
#   'note',
#   'take_note',
#   'observe',
#   'note',
#   'take_down'),
#  'game': ('game',
#   'game',
#   'game',
#   'game',
#   'game',
#   'game',
#   'game',
#   'plot',
#   'secret_plan',
#   'game',
#   'game',
#   'game',
#   'biz',
#   'game',
#   'bet_on',
#   'back',
#   'gage',
#   'stake',
#   'game',
#   'punt',
#   'crippled',
#   'halt',
#   'halting',
#   'lame',
#   'gimpy',
#   'game',
#   'game',
#   'gamy',
#   'gamey',
#   'gritty',
#   'mettlesome',
#   'spirited',
#   'spunky'),
#  'storm': ('storm',
#   'violent_storm',
#   'storm',
#   'tempest',
#   'storm',
#   'ramp',
#   'rage',
#   'storm',
#   'storm',
#   'force',
#   'storm',
#   'storm',
#   'storm',
#   'surprise'),
#  'acting': ('acting',
#   'playing',
#   'playacting',
#   'performing',
#   'act',
#   'move',
#   'act',
#   'behave',
#   'do',
#   'act',
#   'play',
#   'represent',
#   'act',
#   'act',
#   'play',
#   'act_as',
#   'act',
#   'work',
#   'act',
#   'act',
#   'dissemble',
#   'pretend',
#   'act',
#   'act',
#   'play',
#   'roleplay',
#   'playact',
#   'acting'),
#  'discussion': ('discussion',
#   'treatment',
#   'discourse',
#   'discussion',
#   'give-and-take',
#   'word'),
#  'regarding': ('see',
#   'consider',
#   'reckon',
#   'view',
#   'regard',
#   'regard',
#   'consider',
#   'involve',
#   'affect',
#   'regard'),
#  'social': ('sociable',
#   'social',
#   'mixer',
#   'social',
#   'societal',
#   'social',
#   'social',
#   'social',
#   'social',
#   'social'),
#  'medium': ('medium',
#   'medium',
#   'medium',
#   'culture_medium',
#   'medium',
#   'medium',
#   'medium',
#   'medium',
#   'medium',
#   'medium',
#   'spiritualist',
#   'sensitive',
#   'medium',
#   'mass_medium',
#   'metier',
#   'medium',
#   'average',
#   'intermediate',
#   'medium',
#   'medium'),
#  'scott': ('scott',
#   'george_c._scott',
#   'scott',
#   'robert_scott',
#   'robert_falcon_scott',
#   'scott',
#   'winfield_scott',
#   'scott',
#   'walter_scott',
#   'sir_walter_scott',
#   'scott',
#   'dred_scott'),
#  'lake': ('lake', 'lake', 'lake'),
#  'ceo': ('chief_executive_officer', 'ceo', 'chief_operating_officer'),
#  'thinksm': (),
#  'attending': ('attention',
#   'attending',
#   'attendance',
#   'attending',
#   'attend',
#   'go_to',
#   'attend',
#   'take_care',
#   'look',
#   'see',
#   'attend',
#   'serve',
#   'attend_to',
#   'wait_on',
#   'attend',
#   'assist',
#   'attend',
#   'hang',
#   'advert',
#   'pay_heed',
#   'give_ear'),
#  'answer': ('answer',
#   'reply',
#   'response',
#   'solution',
#   'answer',
#   'result',
#   'resolution',
#   'solvent',
#   'answer',
#   'answer',
#   'answer',
#   'answer',
#   'reply',
#   'respond',
#   'answer',
#   'answer',
#   'answer',
#   'resolve',
#   'answer',
#   'answer',
#   'suffice',
#   'do',
#   'answer',
#   'serve',
#   'answer',
#   'answer',
#   'answer'),
#  'riddle': ('riddle',
#   'conundrum',
#   'enigma',
#   'brain-teaser',
#   'riddle',
#   'riddle',
#   'riddle',
#   'riddle',
#   'screen',
#   'permeate',
#   'pervade',
#   'penetrate',
#   'interpenetrate',
#   'diffuse',
#   'imbue',
#   'riddle',
#   'riddle',
#   'riddle'),
#  'pooper': (),
#  'joke': ('joke',
#   'gag',
#   'laugh',
#   'jest',
#   'jape',
#   'jest',
#   'joke',
#   'jocularity',
#   'antic',
#   'joke',
#   'prank',
#   'trick',
#   'caper',
#   'put-on',
#   'joke',
#   'joke',
#   'jest',
#   'joke',
#   'jest'),
#  'joyce': ('joyce', 'james_joyce', 'james_augustine_aloysius_joyce'),
#  'hav': (),
#  'gr': (),
#  'taco': ('greaser', 'wetback', 'taco', 'taco'),
#  'garden': ('garden', 'garden', 'garden', 'garden'),
#  'itd': (),
#  'cash': ('cash',
#   'hard_cash',
#   'hard_currency',
#   'cash',
#   'immediate_payment',
#   'cash',
#   'johnny_cash',
#   'john_cash',
#   'cash',
#   'cash_in'),
#  'aaah': (),
#  'bye': ('bye',
#   'pass',
#   'adieu',
#   'adios',
#   'arrivederci',
#   'auf_wiedersehen',
#   'au_revoir',
#   'bye',
#   'bye-bye',
#   'cheerio',
#   'good-by',
#   'goodby',
#   'good-bye',
#   'goodbye',
#   'good_day',
#   'sayonara',
#   'so_long'),
#  'mikee': (),
#  'smoked': ('smoke', 'fume', 'smoke', 'smoked', 'smoke-cured', 'smoke-dried'),
#  'crab': ('crab',
#   'crab',
#   'crabby_person',
#   'cancer',
#   'crab',
#   'cancer',
#   'cancer_the_crab',
#   'crab',
#   'crab',
#   'crabmeat',
#   'crab_louse',
#   'pubic_louse',
#   'crab',
#   'phthirius_pubis',
#   'crab',
#   'crab',
#   'crab',
#   'crab',
#   'gripe',
#   'bitch',
#   'grouse',
#   'crab',
#   'beef',
#   'squawk',
#   'bellyache',
#   'holler'),
#  'copyright': ('copyright', 'right_of_first_publication', 'copyright'),
#  'exemption': ('exemption',
#   'freedom',
#   'exemption',
#   'exemption',
#   'immunity',
#   'granting_immunity'),
#  'apparently': ('apparently',
#   'seemingly',
#   'ostensibly',
#   'on_the_face_of_it',
#   'obviously',
#   'evidently',
#   'manifestly',
#   'patently',
#   'apparently',
#   'plainly',
#   'plain'),
#  'trying': ('try',
#   'seek',
#   'attempt',
#   'essay',
#   'assay',
#   'test',
#   'prove',
#   'try',
#   'try_out',
#   'examine',
#   'essay',
#   'judge',
#   'adjudicate',
#   'try',
#   'sample',
#   'try',
#   'try_out',
#   'taste',
#   'hear',
#   'try',
#   'try',
#   'try',
#   'strain',
#   'stress',
#   'try',
#   'render',
#   'try_on',
#   'try',
#   'trying',
#   'nerve-racking',
#   'nerve-wracking',
#   'stressful',
#   'trying'),
#  'ensure': ('guarantee',
#   'ensure',
#   'insure',
#   'assure',
#   'secure',
#   'see',
#   'check',
#   'insure',
#   'see_to_it',
#   'ensure',
#   'control',
#   'ascertain',
#   'assure'),
#  'rest': ('remainder',
#   'balance',
#   'residual',
#   'residue',
#   'residuum',
#   'rest',
#   'rest',
#   'ease',
#   'repose',
#   'relaxation',
#   'respite',
#   'rest',
#   'relief',
#   'rest_period',
#   'rest',
#   'rest',
#   'eternal_rest',
#   'sleep',
#   'eternal_sleep',
#   'quietus',
#   'rest',
#   'rest',
#   'rest',
#   'rest',
#   'breathe',
#   "catch_one's_breath",
#   'take_a_breather',
#   'rest',
#   'lie',
#   'rest',
#   'rest',
#   'stay',
#   'remain',
#   'rest',
#   'rest',
#   'reside',
#   'repose',
#   'rest',
#   'perch',
#   'roost',
#   'rest',
#   'pillow',
#   'rest',
#   'rest'),
#  'lightening': ('lightening',
#   'whitening',
#   'lightening',
#   'lighten',
#   'lighten_up',
#   'buoy_up',
#   'lighten',
#   'lighten',
#   'lighten_up',
#   'buoy_up',
#   'brighten',
#   'lighten_up',
#   'lighten',
#   'lighten',
#   'lighten_up',
#   'relieve',
#   'lighten'),
#  'thunder': ('boom',
#   'roar',
#   'roaring',
#   'thunder',
#   'thunder',
#   'big_h',
#   'hell_dust',
#   'nose_drops',
#   'smack',
#   'thunder',
#   'skag',
#   'scag',
#   'thunder',
#   'thunder',
#   'roar',
#   'thunder',
#   'boom',
#   'thunder'),
#  'pm': ('autopsy',
#   'necropsy',
#   'postmortem',
#   'post-mortem',
#   'pm',
#   'postmortem_examination',
#   'post-mortem_examination',
#   'promethium',
#   'pm',
#   'atomic_number_61',
#   'prime_minister',
#   'pm',
#   'premier',
#   'phase_modulation',
#   'pm'),
#  'sweldo': (),
#  'dork': ('jerk', 'dork'),
#  'promoting': ('promote',
#   'advance',
#   'boost',
#   'further',
#   'encourage',
#   'promote',
#   'upgrade',
#   'advance',
#   'kick_upstairs',
#   'raise',
#   'elevate',
#   'advertise',
#   'advertize',
#   'promote',
#   'push',
#   'promote',
#   'promote'),
#  'muziknot': (),
#  'eating': ('eating',
#   'feeding',
#   'eat',
#   'eat',
#   'feed',
#   'eat',
#   'eat',
#   'eat_on',
#   'consume',
#   'eat_up',
#   'use_up',
#   'eat',
#   'deplete',
#   'exhaust',
#   'run_through',
#   'wipe_out',
#   'corrode',
#   'eat',
#   'rust'),
#  'lmaao': (),
#  'iced': ('frost', 'ice', 'ice', 'ice'),
#  'coffee': ('coffee',
#   'java',
#   'coffee',
#   'coffee_tree',
#   'coffee_bean',
#   'coffee_berry',
#   'coffee',
#   'chocolate',
#   'coffee',
#   'deep_brown',
#   'umber',
#   'burnt_umber'),
#  'christ': ('jesus',
#   'jesus_of_nazareth',
#   'the_nazarene',
#   'jesus_christ',
#   'christ',
#   'savior',
#   'saviour',
#   'good_shepherd',
#   'redeemer',
#   'deliverer',
#   'messiah',
#   'christ'),
#  'tasted': ('taste',
#   'savor',
#   'savour',
#   'taste',
#   'sample',
#   'try',
#   'try_out',
#   'taste',
#   'smack',
#   'taste',
#   'taste',
#   'taste'),
#  'nasty': ('nasty',
#   'awful',
#   'nasty',
#   'tight',
#   'cruddy',
#   'filthy',
#   'foul',
#   'nasty',
#   'smutty',
#   'filthy',
#   'foul',
#   'nasty'),
#  'pair': ('pair',
#   'brace',
#   'couple',
#   'pair',
#   'twosome',
#   'twain',
#   'brace',
#   'span',
#   'yoke',
#   'couplet',
#   'distich',
#   'duo',
#   'duet',
#   'dyad',
#   'duad',
#   'pair',
#   'pair',
#   'pair',
#   'pair_off',
#   'partner_off',
#   'couple',
#   'match',
#   'mate',
#   'couple',
#   'pair',
#   'twin',
#   'pair',
#   'geminate',
#   'pair',
#   'geminate',
#   'copulate',
#   'mate',
#   'pair',
#   'couple'),
#  'git': ('rotter',
#   'dirty_dog',
#   'rat',
#   'skunk',
#   'stinker',
#   'stinkpot',
#   'bum',
#   'puke',
#   'crumb',
#   'lowlife',
#   'scum_bag',
#   'so-and-so',
#   'git'),
#  'mega': (),
#  'bus': ('bus',
#   'autobus',
#   'coach',
#   'charabanc',
#   'double-decker',
#   'jitney',
#   'motorbus',
#   'motorcoach',
#   'omnibus',
#   'passenger_vehicle',
#   'bus_topology',
#   'bus',
#   'busbar',
#   'bus',
#   'bus',
#   'jalopy',
#   'heap',
#   'bus',
#   'bus',
#   'bus'),
#  'lovely': ('cover_girl',
#   'pin-up',
#   'lovely',
#   'lovely',
#   'adorable',
#   'endearing',
#   'lovely'),
#  'stupid': ('stupid',
#   'stupid_person',
#   'stupe',
#   'dullard',
#   'dolt',
#   'pudding_head',
#   'pudden-head',
#   'poor_fish',
#   'pillock',
#   'stupid',
#   'dazed',
#   'stunned',
#   'stupefied',
#   'stupid',
#   'unintelligent',
#   'stupid'),
#  'slapton': (),
#  'ians': (),
#  'congrats': (),
#  'mollie': ('mollie', 'molly'),
#  'conti': (),
#  'boooooooo': (),
#  'chivalry': ('chivalry',
#   'gallantry',
#   'politesse',
#   'chivalry',
#   'knightliness'),
#  'dead': ('dead',
#   'dead',
#   'dead',
#   'dead',
#   'all_in',
#   'beat',
#   'bushed',
#   'dead',
#   'dead',
#   'dead',
#   'dead',
#   'numb',
#   'dead',
#   'deadened',
#   'dead',
#   'dead',
#   'idle',
#   'dead',
#   'stagnant',
#   'dead',
#   'dead',
#   'dead',
#   'dead',
#   'dead',
#   'utter',
#   'dead',
#   'drained',
#   'dead',
#   'abruptly',
#   'suddenly',
#   'short',
#   'dead',
#   'absolutely',
#   'perfectly',
#   'utterly',
#   'dead'),
#  'rare': ('rare',
#   'rare',
#   'rare',
#   'rare',
#   'rarefied',
#   'rarified',
#   'rare',
#   'uncommon',
#   'rare'),
#  'breakfast': ('breakfast', 'breakfast', 'breakfast'),
#  'maintenance': ('care',
#   'maintenance',
#   'upkeep',
#   'maintenance',
#   'alimony',
#   'maintenance',
#   'sustenance',
#   'sustentation',
#   'sustainment',
#   'maintenance',
#   'upkeep',
#   'maintenance',
#   'criminal_maintenance'),
#  'dnt': (),
#  'even': ('evening',
#   'eve',
#   'even',
#   'eventide',
#   'flush',
#   'level',
#   'even_out',
#   'even',
#   'even',
#   'even_out',
#   'even',
#   'even_out',
#   'even',
#   'even',
#   'fifty-fifty',
#   'even',
#   'even',
#   'regular',
#   'even',
#   'regular',
#   'tied',
#   'even',
#   'level',
#   'even',
#   'even',
#   'even',
#   'yet',
#   'still',
#   'even'),
#  'wearing': ('erosion',
#   'eroding',
#   'eating_away',
#   'wearing',
#   'wearing_away',
#   'wear',
#   'wearing',
#   'wear',
#   'have_on',
#   'wear',
#   'bear',
#   'wear',
#   'wear',
#   'wear_off',
#   'wear_out',
#   'wear_down',
#   'wear_thin',
#   'wear',
#   'wear',
#   'hold_out',
#   'endure',
#   'break',
#   'wear',
#   'wear_out',
#   'bust',
#   'fall_apart',
#   'tire',
#   'wear_upon',
#   'tire_out',
#   'wear',
#   'weary',
#   'jade',
#   'wear_out',
#   'outwear',
#   'wear_down',
#   'fag_out',
#   'fag',
#   'fatigue',
#   'wear',
#   'put_on',
#   'get_into',
#   'don',
#   'assume',
#   'exhausting',
#   'tiring',
#   'wearing',
#   'wearying'),
#  'skinny': ('skinny',
#   'scraggy',
#   'boney',
#   'scrawny',
#   'skinny',
#   'underweight',
#   'weedy',
#   'skinny',
#   'tight-fitting',
#   'tightfitting',
#   'tight_fitting',
#   'tightly_fitting',
#   'skinny',
#   'cheeseparing',
#   'close',
#   'near',
#   'penny-pinching',
#   'skinny'),
#  'jean': ('jean', 'blue_jean', 'denim', 'denim', 'dungaree', 'jean'),
#  'bitch': ('bitch',
#   'cunt',
#   'bitch',
#   'gripe',
#   'kick',
#   'beef',
#   'bitch',
#   'squawk',
#   'bitch',
#   'gripe',
#   'bitch',
#   'grouse',
#   'crab',
#   'beef',
#   'squawk',
#   'bellyache',
#   'holler',
#   'backbite',
#   'bitch'),
#  ...}

# %%
# remove duplicate synonym
for key, value in synonym_dict.items():
    synonym_dict[key] = tuple(set(value))

synonym_dict
# Out:
# {'mmm': (),
#  'much': ('a_lot',
#   'much',
#   'often',
#   'lots',
#   'a_great_deal',
#   'very_much',
#   'a_good_deal',
#   'practically'),
#  'better': ('honest',
#   'advantageously',
#   'break',
#   'well',
#   'improve',
#   'secure',
#   'good',
#   'adept',
#   'considerably',
#   'dear',
#   'amend',
#   'practiced',
#   'intimately',
#   'near',
#   'ameliorate',
#   'in_effect',
#   'wagerer',
#   'right',
#   'best',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'meliorate',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'substantially',
#   'easily',
#   'skilful',
#   'safe',
#   'skillful',
#   'bettor',
#   'beneficial',
#   'better',
#   'effective',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'comfortably',
#   'dependable',
#   'undecomposed',
#   'ripe',
#   'punter'),
#  'far': ('far',
#   'alir',
#   'interahamwe',
#   'former_armed_forces',
#   'army_for_the_liberation_of_rwanda'),
#  'still': ('nonetheless',
#   'tranquillise',
#   'relieve',
#   'soundless',
#   'placid',
#   'even',
#   'yet',
#   'allay',
#   'quiet',
#   'ease',
#   'hush',
#   'hush_up',
#   'distillery',
#   'static',
#   'inactive',
#   'quieten',
#   'withal',
#   'silent',
#   'silence',
#   'motionless',
#   'tranquil',
#   'tranquilize',
#   'shut_up',
#   'noneffervescent',
#   'still',
#   'all_the_same',
#   'even_so',
#   'stock-still',
#   'tranquillize',
#   'calm_down',
#   'notwithstanding',
#   'unruffled',
#   'smooth',
#   'stillness',
#   'lull',
#   'nevertheless',
#   'calm',
#   'however'),
#  'quite': ('quite_a', 'rather', 'quite', 'quite_an'),
#  'early': ('betimes',
#   'too_soon',
#   'early_on',
#   'ahead_of_time',
#   'early',
#   'former',
#   'other'),
#  'last': ('utmost',
#   'lowest',
#   'end',
#   'live',
#   'net',
#   'stopping_point',
#   'terminal',
#   'go',
#   'hold_out',
#   'last',
#   'death',
#   'final_stage',
#   'live_on',
#   'close',
#   'finis',
#   'finish',
#   'concluding',
#   'lastly',
#   'hold_up',
#   'last-place',
#   'endure',
#   'final',
#   'finale',
#   'finally',
#   "cobbler's_last",
#   'survive',
#   "shoemaker's_last",
#   'conclusion',
#   'in_conclusion'),
#  'great': ('keen',
#   'expectant',
#   'majuscule',
#   'bang-up',
#   'corking',
#   'slap-up',
#   'nifty',
#   'swell',
#   'groovy',
#   'not_bad',
#   'bully',
#   'great',
#   'with_child',
#   'big',
#   'capital',
#   'gravid',
#   'peachy',
#   'cracking',
#   'neat',
#   'enceinte',
#   'large',
#   'outstanding',
#   'dandy',
#   'smashing',
#   'heavy'),
#  'see': ('visualise',
#   'consider',
#   'encounter',
#   'ensure',
#   'attend',
#   'get_a_line',
#   'understand',
#   'regard',
#   'ascertain',
#   'get_word',
#   'go_through',
#   'escort',
#   'check',
#   'see_to_it',
#   'watch',
#   'find_out',
#   'control',
#   'pick_up',
#   'take_in',
#   'project',
#   'come_across',
#   'visualize',
#   'look',
#   'examine',
#   'find',
#   'run_across',
#   'picture',
#   'catch',
#   'reckon',
#   'envision',
#   'insure',
#   'see',
#   'meet',
#   'run_into',
#   'determine',
#   'visit',
#   'assure',
#   'date',
#   'image',
#   'get_wind',
#   'realize',
#   'go_steady',
#   'witness',
#   'view',
#   'construe',
#   'figure',
#   'take_care',
#   'interpret',
#   'go_out',
#   'hear',
#   'discover',
#   'realise',
#   'fancy',
#   'learn',
#   'experience'),
#  'oin': (),
#  'cynthia': ('artemis', 'cynthia'),
#  'happy': ('felicitous', 'well-chosen', 'happy', 'glad'),
#  'dinner': ('dinner', 'dinner_party'),
#  'cute': ('cunning', 'precious', 'cute'),
#  'little': ('little',
#   'lilliputian',
#   'piddling',
#   'niggling',
#   'picayune',
#   'trivial',
#   'short',
#   'minuscule',
#   'slight',
#   'piffling',
#   'small',
#   'fiddling',
#   'petty',
#   'footling'),
#  'place': ('rank',
#   'send',
#   'place',
#   'office',
#   'billet',
#   'shoes',
#   'plaza',
#   'stead',
#   'put',
#   'set',
#   'grade',
#   'localise',
#   'identify',
#   'locate',
#   'localize',
#   'lieu',
#   'order',
#   'come_out',
#   'home',
#   'rate',
#   'range',
#   'piazza',
#   'space',
#   'site',
#   'spot',
#   'come_in',
#   'direct',
#   'post',
#   'property',
#   'topographic_point',
#   'invest',
#   'target',
#   'seat',
#   'position',
#   'commit',
#   'berth',
#   'situation',
#   'pose',
#   'lay',
#   'blank_space',
#   'point',
#   'aim',
#   'station'),
#  'bad': ('badly',
#   'unsound',
#   'big',
#   'risky',
#   'unfit',
#   'regretful',
#   'high-risk',
#   'uncollectible',
#   'tough',
#   'badness',
#   'sorry',
#   'speculative',
#   'spoiled',
#   'bad',
#   'defective',
#   'spoilt',
#   'forged'),
#  'sick': ('fed_up',
#   'queasy',
#   'spew',
#   'nauseous',
#   'tired_of',
#   'unhinged',
#   'pallid',
#   'upchuck',
#   'macabre',
#   'cast',
#   'barf',
#   'vomit',
#   'ghastly',
#   'demented',
#   'crazy',
#   'retch',
#   'purge',
#   'cat',
#   'spue',
#   'sick_of',
#   'mad',
#   'throw_up',
#   'disgorge',
#   'disturbed',
#   'chuck',
#   'sick',
#   'wan',
#   'honk',
#   'gruesome',
#   'pale',
#   'grim',
#   'brainsick',
#   'ill',
#   'vomit_up',
#   'regorge',
#   'grisly',
#   'disgusted',
#   'be_sick',
#   'nauseated',
#   'sickish',
#   'unbalanced',
#   'regurgitate',
#   'puke'),
#  'afterwards': ('subsequently',
#   'afterwards',
#   'after',
#   'afterward',
#   'later',
#   'later_on'),
#  'dude': ('dude',
#   'fashion_plate',
#   'swell',
#   'clotheshorse',
#   'dandy',
#   'buster',
#   'fop',
#   'fellow',
#   'sheik',
#   'gallant',
#   'beau'),
#  'favorite': ('deary',
#   'favourite',
#   'dearie',
#   'ducky',
#   'preferent',
#   'best-loved',
#   'favored',
#   'preferred',
#   'favorite',
#   'darling',
#   'pet',
#   'front-runner'),
#  'sandwich': ('sandwich',),
#  'ever': ('ever_so', 'always', "e'er", 'of_all_time', 'ever'),
#  'ummm': (),
#  'take': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'yield',
#   'require',
#   'issue',
#   'lease',
#   'strike',
#   'proceeds',
#   'take_in',
#   'use_up',
#   'call_for',
#   'payoff',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'return',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'takings',
#   'learn'),
#  'picture': ('video',
#   'visualise',
#   'film',
#   'motion-picture_show',
#   'ikon',
#   'scene',
#   'depict',
#   'render',
#   'project',
#   'impression',
#   'pictorial_matter',
#   'visualize',
#   'movie',
#   'delineation',
#   'mental_picture',
#   'picture',
#   'word-painting',
#   'picture_show',
#   'characterisation',
#   'word_picture',
#   'exposure',
#   'envision',
#   'see',
#   'pic',
#   'show',
#   'moving_picture',
#   'icon',
#   'motion_picture',
#   'painting',
#   'photograph',
#   'image',
#   'characterization',
#   'flick',
#   'photo',
#   'figure',
#   'moving-picture_show',
#   'fancy',
#   'depiction'),
#  'need': ('require',
#   'call_for',
#   'pauperization',
#   'pauperism',
#   'involve',
#   'postulate',
#   'demand',
#   'penury',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'motive',
#   'need',
#   'indigence',
#   'motivation'),
#  'pack': ('ring',
#   'multitude',
#   'clique',
#   'ingroup',
#   'mob',
#   'tamp_down',
#   'large_number',
#   'coterie',
#   'load_down',
#   'inner_circle',
#   'jam',
#   'plurality',
#   'gang',
#   'battalion',
#   'pack',
#   'wad',
#   'pile',
#   'camp',
#   'backpack',
#   'bundle',
#   'compact',
#   'tamp',
#   'throng',
#   'carry',
#   'take',
#   'face_pack'),
#  'cali': ('cali',),
#  'can': ('displace',
#   'rump',
#   'buttocks',
#   'hind_end',
#   'bathroom',
#   'john',
#   'behind',
#   'bottom',
#   'lav',
#   'prat',
#   'tooshie',
#   'nates',
#   'throne',
#   'fundament',
#   'send_away',
#   'butt',
#   'ass',
#   'canful',
#   'stern',
#   'tush',
#   'privy',
#   'can',
#   'force_out',
#   'fire',
#   'fanny',
#   'arse',
#   'buns',
#   'sack',
#   'crapper',
#   'dismiss',
#   'derriere',
#   'stool',
#   'potty',
#   'bum',
#   'rear_end',
#   'seat',
#   'terminate',
#   'posterior',
#   'give_notice',
#   'keister',
#   'tin_can',
#   'backside',
#   'toilet',
#   'lavatory',
#   'give_the_sack',
#   'give_the_axe',
#   'tail_end',
#   'hindquarters',
#   'tin',
#   'can_buoy',
#   'pot',
#   'commode',
#   'put_up',
#   'tail',
#   'rear'),
#  'not': ('not', 'non'),
#  'waittt': (),
#  'thinking': ('consider',
#   'recollect',
#   'believe',
#   'guess',
#   'imagine',
#   'thought',
#   'intelligent',
#   'call_back',
#   'opine',
#   'cerebrate',
#   'mentation',
#   'reckon',
#   'recall',
#   'call_up',
#   'intend',
#   'reasoning',
#   'remember',
#   'cogitate',
#   'think',
#   'mean',
#   'intellection',
#   'retrieve',
#   'conceive',
#   'thought_process',
#   'cerebration',
#   'thinking',
#   'suppose'),
#  'glass': ('crank',
#   'field_glass',
#   'glass',
#   'chicken_feed',
#   'ice',
#   'deoxyephedrine',
#   'spyglass',
#   'methedrine',
#   'drinking_glass',
#   'glass_over',
#   'glaze_over',
#   'glassful',
#   'methamphetamine_hydrochloride',
#   'trash',
#   'shabu',
#   'chalk',
#   'looking_glass',
#   'meth',
#   'glaze',
#   'methamphetamine',
#   'glass_in'),
#  'wine': ('wine-coloured', 'wine', 'wine-colored', 'vino'),
#  'order': ('ordination',
#   'dictate',
#   'rank',
#   'place',
#   'ordinate',
#   'regularize',
#   'edict',
#   'ordain',
#   'put',
#   'grade',
#   'tell',
#   'guild',
#   'holy_order',
#   'say',
#   'order',
#   'prescribe',
#   'lodge',
#   'rate',
#   'range',
#   'ordering',
#   'gild',
#   'parliamentary_procedure',
#   'monastic_order',
#   'set_up',
#   'parliamentary_law',
#   'orderliness',
#   'enjoin',
#   'club',
#   'rescript',
#   'arrange',
#   'society',
#   'govern',
#   'social_club',
#   'regulate',
#   'rules_of_order',
#   'consecrate',
#   'purchase_order',
#   'order_of_magnitude',
#   'fiat',
#   'regularise',
#   'decree'),
#  'celebrate': ('lionise', 'celebrate', 'observe', 'keep', 'lionize', 'fete'),
#  'weekend': ('weekend',),
#  'vaca': (),
#  'work': ('act',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'employment',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'oeuvre',
#   'operate',
#   'ferment',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'piece_of_work',
#   'workplace',
#   'process',
#   'lick',
#   'mould',
#   'run',
#   'study',
#   'make_for',
#   'body_of_work',
#   'exercise',
#   'knead'),
#  'morrow': ('morrow',),
#  'tho': ('tho',),
#  'took': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'require',
#   'lease',
#   'strike',
#   'take_in',
#   'use_up',
#   'call_for',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'learn'),
#  'math': ('maths', 'math', 'mathematics'),
#  'test': ('test',
#   'screen',
#   'quiz',
#   'essay',
#   'trial_run',
#   'mental_test',
#   'mental_testing',
#   'examination',
#   'psychometric_test',
#   'trial',
#   'examine',
#   'try_out',
#   'tryout',
#   'run',
#   'exam',
#   'prove',
#   'try'),
#  'today': ('today', 'now', 'nowadays'),
#  'teacher': ('instructor', 'teacher'),
#  'say': ('order',
#   'enjoin',
#   'allege',
#   'pronounce',
#   'aver',
#   'enounce',
#   'read',
#   'tell',
#   'enunciate',
#   'articulate',
#   'sound_out',
#   'say',
#   'state',
#   'suppose'),
#  'bring': ('wreak',
#   'lend',
#   'fetch',
#   'add',
#   'land',
#   'convey',
#   'bring',
#   'impart',
#   'play',
#   'take',
#   'get',
#   'institute',
#   'bestow',
#   'bring_in',
#   'contribute',
#   'make_for',
#   'work'),
#  'calculator': ('figurer',
#   'calculator',
#   'calculating_machine',
#   'estimator',
#   'computer',
#   'reckoner'),
#  'luke': ('luke',
#   'st._luke',
#   'saint_luke',
#   'gospel_according_to_luke',
#   'gospel_of_luke'),
#  'confident': ('sure-footed',
#   'convinced',
#   'positive',
#   'surefooted',
#   'confident'),
#  'decided': ('decide',
#   'determine',
#   'settle',
#   'adjudicate',
#   "make_up_one's_mind",
#   'distinct',
#   'decided',
#   'resolve'),
#  'calcs': (),
#  'omg': (),
#  'concert': ('concert',),
#  'awesome': ('awful', 'amazing', 'awe-inspiring', 'awesome', 'awing'),
#  'madrigal': ('madrigal',),
#  'gave': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'contribute',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chill': ('frisson',
#   'shivering',
#   'quiver',
#   'thrill',
#   'iciness',
#   'shiver',
#   'pall',
#   'cool',
#   'chill',
#   'tingle',
#   'gelidity',
#   'cool_down',
#   'shudder'),
#  'almost': ('about',
#   'near',
#   'nigh',
#   'almost',
#   'virtually',
#   'well-nigh',
#   'nearly',
#   'most'),
#  'every': ('every',),
#  'piecebrooks': (),
#  'also': ('as_well', 'too', 'likewise', 'besides', 'also'),
#  'called': ('ring',
#   'foretell',
#   'shout',
#   'forebode',
#   'name',
#   'squall',
#   'address',
#   'promise',
#   'prognosticate',
#   'anticipate',
#   'holler',
#   'hollo',
#   'scream',
#   'send_for',
#   'call_up',
#   'call_in',
#   'visit',
#   'call_off',
#   'cry',
#   'predict',
#   'phone',
#   'bid',
#   'call',
#   'shout_out',
#   'telephone',
#   'yell'),
#  'alumnus': ('graduate', 'alumna', 'alumnus', 'grad', 'alum'),
#  'didnt': (),
#  'cant': ('chamfer',
#   'slant',
#   'tilt',
#   'cant_over',
#   'bank',
#   'lingo',
#   'cant',
#   'vernacular',
#   'buzzword',
#   'patois',
#   'slang',
#   'pious_platitude',
#   'jargon',
#   'argot',
#   'camber',
#   'bevel',
#   'pitch'),
#  'minute': ('moment',
#   'min',
#   'instant',
#   'bit',
#   'minute_of_arc',
#   'hour',
#   'narrow',
#   'minute',
#   'arcminute',
#   'mo',
#   'second',
#   'infinitesimal'),
#  'treadmill': ('tread-wheel', 'salt_mine', 'treadwheel', 'treadmill'),
#  'done': ('act',
#   'fare',
#   'cause',
#   'set',
#   'perform',
#   'serve',
#   'execute',
#   'practice',
#   'coiffe',
#   'do',
#   'practise',
#   'behave',
#   'done',
#   'make_out',
#   'coif',
#   'get_along',
#   'coiffure',
#   'make',
#   'dress',
#   'arrange',
#   'suffice',
#   'through_with',
#   'manage',
#   'through',
#   'answer',
#   'come',
#   'exercise'),
#  'already': ('already',),
#  'gon': (),
#  'na': ('sodium', 'atomic_number_11', 'na'),
#  'chillin': (),
#  'roomy': ('roommate', 'spacious', 'roomie', 'roomy'),
#  'wait': ('postponement',
#   'look',
#   'hold',
#   'time_lag',
#   'wait',
#   'hold_off',
#   'waitress',
#   'waiting',
#   'delay',
#   'hold_back',
#   'expect',
#   'await'),
#  'zombie': ('living_dead',
#   'zombie',
#   'automaton',
#   'zombi',
#   'snake_god',
#   'zombie_spirit',
#   'zombi_spirit'),
#  'clwn': (),
#  'cr': ('cr', 'chromium', 'atomic_number_24'),
#  'week': ('calendar_week', 'week', 'workweek', 'hebdomad'),
#  'kno': (),
#  'doooo': (),
#  'yall': (),
#  'partyin': (),
#  'spilled': ('spill',
#   'slop',
#   'run_out',
#   'talk',
#   'splatter',
#   'shed',
#   'disgorge',
#   'pour_forth'),
#  'beer': ('beer',),
#  'leg': ('branch',
#   'pegleg',
#   'peg',
#   'wooden_leg',
#   'stage',
#   'ramification',
#   'leg'),
#  'wasted': ('cadaverous',
#   'wasted',
#   'scourge',
#   'superfluous',
#   'rot',
#   'blow',
#   'emaciated',
#   'run_off',
#   'squandered',
#   'emaciate',
#   'pointless',
#   'ware',
#   'neutralise',
#   'otiose',
#   'macerate',
#   'liquidate',
#   'bony',
#   'squander',
#   'knock_off',
#   'senseless',
#   'atrophied',
#   'neutralize',
#   'haggard',
#   'do_in',
#   'pine_away',
#   'diminished',
#   'desolate',
#   'skeletal',
#   'waste',
#   'ravage',
#   'pinched',
#   'gaunt',
#   'lay_waste_to',
#   'consume',
#   'devastate',
#   'languish',
#   'purposeless'),
#  'half': ('one-half', 'half'),
#  'home': ('place',
#   'home_plate',
#   'house',
#   'home_base',
#   'menage',
#   'interior',
#   'plate',
#   'abode',
#   'home',
#   'base',
#   'national',
#   'dwelling_house',
#   'household',
#   'internal',
#   'dwelling',
#   'domicile',
#   'habitation',
#   'rest_home',
#   'nursing_home',
#   'family'),
#  'met': ('encounter',
#   'play',
#   'conform_to',
#   'gather',
#   'touch',
#   'adjoin',
#   'come_across',
#   'fulfill',
#   'suffer',
#   'satisfy',
#   'run_across',
#   'contact',
#   'run_into',
#   'meet',
#   'see',
#   'take_on',
#   'fulfil',
#   'forgather',
#   'get_together',
#   'fit',
#   'cope_with',
#   'receive',
#   'match',
#   'converge',
#   'fill',
#   'assemble',
#   'foregather'),
#  'girl': ('miss',
#   'female_child',
#   'young_woman',
#   'daughter',
#   'little_girl',
#   'girl',
#   'missy',
#   'lady_friend',
#   'fille',
#   'girlfriend',
#   'young_lady'),
#  'good': ('honest',
#   'well',
#   'secure',
#   'good',
#   'adept',
#   'dear',
#   'practiced',
#   'soundly',
#   'near',
#   'in_effect',
#   'right',
#   'goodness',
#   'trade_good',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'skilful',
#   'thoroughly',
#   'safe',
#   'skillful',
#   'beneficial',
#   'effective',
#   'commodity',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'dependable',
#   'undecomposed',
#   'ripe'),
#  'conversation': ('conversation',),
#  'english': ('english_language', 'english', 'english_people', 'side'),
#  'class': ('sort',
#   'sort_out',
#   'socio-economic_class',
#   'course_of_instruction',
#   'form',
#   'category',
#   'grade',
#   'course',
#   'class',
#   'stratum',
#   'year',
#   'separate',
#   'family',
#   'course_of_study',
#   'assort',
#   'classify',
#   'social_class',
#   'division'),
#  'working': ('working',
#   'act',
#   'workings',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'ferment',
#   'operate',
#   'functional',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'on_the_job',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'running',
#   'process',
#   'lick',
#   'mould',
#   'operative',
#   'run',
#   'make_for',
#   'exercise',
#   'knead'),
#  'interactive': ('interactional', 'synergistic', 'interactive'),
#  'oral': ('oral_exam',
#   'viva_voce',
#   'oral',
#   'viva',
#   'oral_examination',
#   'unwritten'),
#  'fb': (),
#  'boring': ('tire',
#   'dull',
#   'wearisome',
#   'tiresome',
#   'bore',
#   'irksome',
#   'oil_production',
#   'ho-hum',
#   'slow',
#   'drilling',
#   'drill',
#   'boring',
#   'tedious',
#   'deadening'),
#  'wan': ('sick', 'wan', 'pallid', 'wide_area_network', 'pale'),
#  'sing': ('whistle',
#   'babble',
#   'babble_out',
#   'spill_the_beans',
#   'let_the_cat_out_of_the_bag',
#   'sing',
#   'talk',
#   'peach',
#   'blab',
#   'blab_out',
#   'tattle'),
#  'right': ('rectify',
#   'rightfulness',
#   'compensate',
#   'decent',
#   'in_good_order',
#   'good',
#   'properly',
#   'the_right_way',
#   'right_hand',
#   'flop',
#   'justly',
#   'correctly',
#   'right-hand',
#   'aright',
#   'right',
#   'redress',
#   'mighty',
#   'correct',
#   'proper',
#   'veracious',
#   'right_field',
#   'powerful',
#   'right_wing',
#   'right_on',
#   'rightfield',
#   'mightily',
#   'decently',
#   'ripe'),
#  'must': ('moldiness', 'must', 'mustiness'),
#  'new': ('fresh',
#   'raw',
#   'novel',
#   'unexampled',
#   'freshly',
#   'new',
#   'modern',
#   'newfangled',
#   'newly',
#   'young'),
#  'music': ('euphony', 'medicine', 'music'),
#  'wont': ('habit', 'wont'),
#  'sleep': ('kip',
#   "log_z's",
#   "catch_some_z's",
#   'nap',
#   'sleep',
#   'slumber',
#   'rest',
#   'sopor',
#   'eternal_sleep',
#   'quietus',
#   'eternal_rest'),
#  'give': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'springiness',
#   'contribute',
#   'spring',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chapter': ('chapter',),
#  'might': ('mightiness', 'power', 'might'),
#  'die': ('die',
#   'become_flat',
#   'croak',
#   'break',
#   'give-up_the_ghost',
#   'buy_the_farm',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'conk_out',
#   'go',
#   'conk',
#   'break_down',
#   'decease',
#   'drop_dead',
#   'die_out',
#   'go_bad',
#   'pass',
#   'pop_off',
#   'pall',
#   'choke',
#   'pass_away',
#   'dice',
#   "cash_in_one's_chips",
#   'exit',
#   'fail',
#   'snuff_it',
#   'give_way',
#   'expire'),
#  'first': ('low_gear',
#   'get-go',
#   '1st',
#   'beginning',
#   'number_one',
#   'first-class_honours_degree',
#   'first_gear',
#   'first_of_all',
#   'number_1',
#   'firstly',
#   'start',
#   'first',
#   'first_base',
#   'inaugural',
#   'showtime',
#   'initiatory',
#   'low',
#   'first_off',
#   'world-class',
#   'foremost',
#   'commencement',
#   'maiden',
#   'outset',
#   'initiative',
#   'starting_time',
#   'kickoff',
#   'offset',
#   'for_the_first_time'),
#  'though': ('though',),
#  'hurry': ('speed',
#   'zip',
#   'travel_rapidly',
#   'festinate',
#   'precipitation',
#   'look_sharp',
#   'hastiness',
#   'rush',
#   'hurry',
#   'hurriedness',
#   'haste',
#   'hasten',
#   'rushing'),
#  'noooooooooooo': (),
#  'look': ('tone',
#   'feel',
#   'attend',
#   'facial_expression',
#   'bet',
#   'seem',
#   'front',
#   'await',
#   'depend',
#   'look',
#   'calculate',
#   'reckon',
#   'expect',
#   'looking',
#   'see',
#   'feeling',
#   'search',
#   'appear',
#   'aspect',
#   'smell',
#   'expression',
#   'spirit',
#   'face',
#   'looking_at',
#   'wait',
#   'take_care',
#   'flavour',
#   'flavor',
#   'count'),
#  'lot': ('luck',
#   'circumstances',
#   'mess',
#   'deal',
#   'bunch',
#   'passel',
#   'set',
#   'slew',
#   'stack',
#   'mete_out',
#   'parcel_out',
#   'tidy_sum',
#   'administer',
#   'circle',
#   'band',
#   'portion',
#   'dole_out',
#   'mountain',
#   'hatful',
#   'flock',
#   'great_deal',
#   'batch',
#   'wad',
#   'heap',
#   'deal_out',
#   'allot',
#   'mass',
#   'pile',
#   'distribute',
#   'quite_a_little',
#   'destiny',
#   'shell_out',
#   'sight',
#   'muckle',
#   'caboodle',
#   'draw',
#   'dispense',
#   'mint',
#   'spate',
#   'fortune',
#   'raft',
#   'fate',
#   'peck',
#   'mickle',
#   'good_deal',
#   'pot',
#   'dish_out',
#   'lot',
#   'plenty'),
#  'lol': (),
#  'demi': (),
#  'hi': ('howdy',
#   "hawai'i",
#   'aloha_state',
#   'hullo',
#   'hi',
#   'how-do-you-do',
#   'hawaii',
#   'hello'),
#  'enough': ('decent', 'sufficiency', 'adequate', 'enough', 'plenty'),
#  'replay': ('rematch',
#   'action_replay',
#   'instant_replay',
#   'replay',
#   'play_back'),
#  'please': ('please', 'delight'),
#  'love': ('love_life',
#   'bonk',
#   'roll_in_the_hay',
#   'have_sex',
#   'hump',
#   'get_it_on',
#   'passion',
#   'dear',
#   'dearest',
#   'be_intimate',
#   'love',
#   'screw',
#   'bang',
#   'have_it_away',
#   'sleep_with',
#   'get_laid',
#   'make_out',
#   'jazz',
#   'erotic_love',
#   'bed',
#   'have_it_off',
#   'have_a_go_at_it',
#   'making_love',
#   'lovemaking',
#   'do_it',
#   'honey',
#   'sleep_together',
#   'eff',
#   'sexual_love',
#   'have_intercourse',
#   'make_love',
#   'lie_with',
#   'enjoy',
#   'know',
#   'fuck',
#   'beloved'),
#  'big': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'boastfully',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'vauntingly',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'vanessa': ('genus_vanessa', 'vanessa'),
#  'going': ('release',
#   'die',
#   'loss',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'passing',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'expiration',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'leaving',
#   'departure',
#   'move',
#   'function',
#   'going_away',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'going',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'sledding',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'september': ('september', 'sept', 'sep'),
#  'fast': ('degenerate',
#   'immobile',
#   'tight',
#   'fasting',
#   'quick',
#   'fast',
#   'firm',
#   'profligate',
#   'truehearted',
#   'degraded',
#   'dissolute',
#   'dissipated',
#   'flying',
#   'loyal',
#   'debauched',
#   'libertine',
#   'riotous'),
#  'hard': ('voiceless',
#   'laborious',
#   'operose',
#   'toilsome',
#   'gruelling',
#   'tough',
#   'firmly',
#   'knockout',
#   'intemperate',
#   'severely',
#   'punishing',
#   'severe',
#   'unvoiced',
#   'heavily',
#   'concentrated',
#   'difficult',
#   'intemperately',
#   'strong',
#   'hard',
#   'surd',
#   'backbreaking',
#   'arduous',
#   'heavy',
#   'grueling'),
#  'cuz': (),
#  'im': (),
#  'workin': (),
#  'miss': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'young_woman',
#   'girl',
#   'misfire',
#   'pretermit',
#   'missy',
#   'overleap',
#   'fille',
#   'neglect',
#   'escape',
#   'omit',
#   'young_lady',
#   'lose'),
#  'alot': (),
#  'lord': ('overlord',
#   'noble',
#   'almighty',
#   'nobleman',
#   'maker',
#   'godhead',
#   'master',
#   'lord',
#   'creator',
#   'divine',
#   'jehovah',
#   'god_almighty'),
#  'seen': ('visualise',
#   'consider',
#   'encounter',
#   'ensure',
#   'attend',
#   'get_a_line',
#   'understand',
#   'regard',
#   'ascertain',
#   'get_word',
#   'go_through',
#   'escort',
#   'check',
#   'see_to_it',
#   'watch',
#   'find_out',
#   'control',
#   'pick_up',
#   'take_in',
#   'project',
#   'come_across',
#   'visualize',
#   'look',
#   'examine',
#   'find',
#   'run_across',
#   'picture',
#   'catch',
#   'reckon',
#   'envision',
#   'insure',
#   'see',
#   'meet',
#   'run_into',
#   'determine',
#   'visit',
#   'assure',
#   'date',
#   'image',
#   'get_wind',
#   'realize',
#   'go_steady',
#   'witness',
#   'view',
#   'construe',
#   'figure',
#   'take_care',
#   'interpret',
#   'go_out',
#   'hear',
#   'discover',
#   'realise',
#   'fancy',
#   'learn',
#   'experience'),
#  'agency': ('bureau',
#   'office',
#   'way',
#   'means',
#   'authority',
#   'government_agency',
#   'representation',
#   'federal_agency',
#   'delegacy',
#   'agency'),
#  'upcoming': ('coming', 'forthcoming', 'approaching', 'upcoming'),
#  'open': ('spread_out',
#   'loose',
#   'heart-to-heart',
#   'open_air',
#   'candid',
#   'assailable',
#   'subject',
#   'undefended',
#   'capable',
#   'overt',
#   'out-of-doors',
#   'spread',
#   'give',
#   'receptive',
#   'surface',
#   'open',
#   'unresolved',
#   'clear',
#   'undefendable',
#   'unfold',
#   'outdoors',
#   'undecided',
#   'undetermined',
#   'opened',
#   'exposed',
#   'unfastened',
#   'afford',
#   'open_up'),
#  'money': ('money',),
#  'jam': ('muddle',
#   'crush',
#   'mess',
#   'chock_up',
#   'block',
#   'press',
#   'mob',
#   'jamming',
#   'jampack',
#   'fix',
#   'ram',
#   'jam',
#   'pack',
#   'wad',
#   'hole',
#   'occlude',
#   'electronic_jamming',
#   'pile',
#   'kettle_of_fish',
#   'pickle',
#   'obstruct',
#   'close_up',
#   'throng',
#   'obturate',
#   'cram',
#   'impede'),
#  'foster': ('foster',
#   'surrogate',
#   'nurture',
#   'further',
#   'stephen_foster',
#   'stephen_collins_foster'),
#  'kitten': ('kitten', 'kitty'),
#  'getting': ('stupefy',
#   'have',
#   'begin',
#   'obtain',
#   'getting',
#   'cause',
#   'set_out',
#   'mother',
#   'become',
#   "get_under_one's_skin",
#   'nonplus',
#   'start',
#   'go',
#   'induce',
#   'fetch',
#   'gravel',
#   'start_out',
#   'beget',
#   'arrive',
#   'dumbfound',
#   'acquiring',
#   'sustain',
#   'contract',
#   'fix',
#   'find',
#   'suffer',
#   'arrest',
#   'incur',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'let',
#   'develop',
#   'drive',
#   'get_down',
#   'commence',
#   'puzzle',
#   'beat',
#   'grow',
#   'buzz_off',
#   'stick',
#   'flummox',
#   'bring',
#   'acquire',
#   'make',
#   'baffle',
#   'draw',
#   'stimulate',
#   'engender',
#   'scram',
#   'capture',
#   'produce',
#   'receive',
#   'pay_back',
#   'bugger_off',
#   'bring_forth',
#   'convey',
#   'pay_off',
#   'generate',
#   'fuck_off',
#   'mystify',
#   'take',
#   'get',
#   'come',
#   'vex',
#   'set_about',
#   'father',
#   'sire',
#   'aim',
#   'catch',
#   'pose',
#   'experience'),
#  'bigchubba': (),
#  'winston': (),
#  'b': ('b',
#   'b-complex_vitamin',
#   'boron',
#   'group_b',
#   'b_complex',
#   'atomic_number_5',
#   'vitamin_b',
#   'bel',
#   'b_vitamin',
#   'bacillus',
#   'type_b',
#   'vitamin_b_complex',
#   'barn'),
#  'missed': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'pretermit',
#   'overleap',
#   'missed',
#   'neglect',
#   'escape',
#   'omit',
#   'lost',
#   'lose'),
#  'amazing': ('awful',
#   'stupefy',
#   'awesome',
#   'nonplus',
#   'awing',
#   'gravel',
#   'amazing',
#   'astonish',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'puzzle',
#   'beat',
#   'flummox',
#   'astound',
#   'baffle',
#   'awe-inspiring',
#   'astonishing',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'ready': ('gear_up',
#   'set',
#   'quick',
#   'fix',
#   'cook',
#   'make',
#   'prepare',
#   'set_up',
#   'ready'),
#  'school': ('shoal',
#   'educate',
#   'cultivate',
#   'schooling',
#   'schoolhouse',
#   'school',
#   'civilize',
#   'schooltime',
#   'school_day',
#   'train',
#   'civilise'),
#  'second': ('endorsement',
#   'sec',
#   'bit',
#   'indorse',
#   'mo',
#   'second_gear',
#   'instant',
#   'back',
#   'secondly',
#   'second_base',
#   '2d',
#   'second',
#   's',
#   'indorsement',
#   'irregular',
#   'endorse',
#   '2nd',
#   'moment',
#   'minute',
#   'arcsecond',
#   'secondment'),
#  'rd': (),
#  'year': ('yr', 'twelvemonth', 'class', 'year'),
#  'next': ('side_by_side',
#   'following',
#   'adjacent',
#   'next',
#   'succeeding',
#   'future'),
#  'officially': ('officially', 'formally'),
#  'th': ('atomic_number_90', 'th', 'thorium', 'thursday'),
#  'friday': ('friday', 'fri'),
#  'yay': ('yay',),
#  'bonus': ('fillip', 'bonus', 'incentive'),
#  'dont': (),
#  'drive': ('driving_force',
#   'force_back',
#   'thrust',
#   'cause',
#   'private_road',
#   'beat_back',
#   'repel',
#   'driveway',
#   'tug',
#   'labor',
#   'force',
#   'push',
#   'labour',
#   'ride',
#   'ram',
#   'drive',
#   'effort',
#   'driving',
#   'motor',
#   'push_back',
#   'repulse',
#   'movement',
#   'parkway',
#   'campaign',
#   'crusade',
#   'get',
#   'take',
#   'aim'),
#  'wale': ('wheal', 'strake', 'wale', 'welt', 'weal'),
#  'tonight': ('tonight', 'this_evening', 'this_night'),
#  'athough': (),
#  'cuddle': ('nuzzle', 'draw_close', 'cuddle', 'snuggle', 'nest', 'nestle'),
#  'ride': ('tantalise',
#   'hinge_upon',
#   'depend_upon',
#   'rally',
#   'devolve_on',
#   'tantalize',
#   'ride',
#   'cod',
#   'taunt',
#   'drive',
#   'depend_on',
#   'turn_on',
#   'rag',
#   'hinge_on',
#   'razz',
#   'tease',
#   'twit',
#   'sit',
#   'mount',
#   'bait'),
#  'ok': ('alright',
#   'very_well',
#   'ok',
#   'all_right',
#   'fine',
#   'okeh',
#   'okey',
#   'okay',
#   'oklahoma',
#   'sooner_state',
#   'hunky-dory',
#   'o.k.'),
#  'shoe': ('skid', 'shoe', 'horseshoe', 'brake_shoe'),
#  'club': ('order',
#   'golf_club',
#   'golf-club',
#   'cabaret',
#   'baseball_club',
#   'lodge',
#   'club',
#   'gild',
#   'clubhouse',
#   'bludgeon',
#   'ball_club',
#   'night_club',
#   'nine',
#   'guild',
#   'society',
#   'nightspot',
#   'social_club',
#   'nightclub'),
#  'cool': ('aplomb',
#   'poise',
#   'coolheaded',
#   'cool',
#   'cool_off',
#   'chill',
#   'nerveless',
#   'sang-froid',
#   'cool_down',
#   'assuredness'),
#  'fun': ('merriment', 'playfulness', 'sport', 'play', 'fun'),
#  'poppin': (),
#  'except': ('leave_out',
#   'exclude',
#   'except',
#   'omit',
#   'demur',
#   'leave_off',
#   'take_out'),
#  'ppl': (),
#  'tryna': (),
#  'dance': ('saltation',
#   'terpsichore',
#   'dance',
#   'trip_the_light_fantastic',
#   'dancing',
#   'trip_the_light_fantastic_toe'),
#  'wit': ('mentality',
#   'wit',
#   'humour',
#   'learning_ability',
#   'wittiness',
#   'witticism',
#   'humor',
#   'card',
#   'brain',
#   'brainpower',
#   'mental_capacity',
#   'wag'),
#  'emmy': ('emmy',),
#  'latin': ('romance', 'latin'),
#  'would': (),
#  'help': ('facilitate',
#   'assist',
#   'assistant',
#   'supporter',
#   'service',
#   'help_oneself',
#   'helper',
#   'assistance',
#   'help',
#   'avail',
#   'serve',
#   'aid'),
#  'study': ('canvass',
#   'consider',
#   'hit_the_books',
#   'contemplate',
#   'read',
#   'canvas',
#   'work',
#   'survey',
#   'discipline',
#   'subject',
#   'subject_field',
#   'examine',
#   'written_report',
#   'bailiwick',
#   'study',
#   'report',
#   'sketch',
#   'subject_area',
#   'cogitation',
#   'analyse',
#   'take',
#   'field_of_study',
#   'meditate',
#   'analyze',
#   'learn',
#   'field'),
#  'aptitude': ('aptitude',),
#  'grad': ('graduate', 'alumna', 'grade', 'alumnus', 'grad', 'alum'),
#  'thats': (),
#  'wish': ('wishing',
#   'like',
#   'bid',
#   'wish',
#   'regard',
#   'care',
#   'indirect_request',
#   'want',
#   'compliments',
#   'wish_well'),
#  'could': (),
#  'fly': ('wing',
#   'vaporize',
#   'vanish',
#   'rainfly',
#   'fly_front',
#   'fly_sheet',
#   'tent_flap',
#   'fly_ball',
#   'aviate',
#   'tent-fly',
#   'fell',
#   'flee',
#   'take_flight',
#   'fly',
#   'pilot'),
#  'someone': ('person', 'someone', 'individual', 'soul', 'mortal', 'somebody'),
#  'la': ('lanthanum',
#   'louisiana',
#   'lah',
#   'pelican_state',
#   'la',
#   'atomic_number_57'),
#  'lemon': ('gamboge',
#   'lemon_yellow',
#   'lemon',
#   'citrus_limon',
#   'lemon_tree',
#   'maize',
#   'stinker'),
#  'tree': ('tree',
#   'sir_herbert_beerbohm_tree',
#   'tree_diagram',
#   'shoetree',
#   'corner'),
#  'who': ('who', 'world_health_organization'),
#  'always': ('constantly',
#   'always',
#   "e'er",
#   'perpetually',
#   'forever',
#   'ever',
#   'invariably',
#   'incessantly'),
#  'oh': ('buckeye_state', 'oh', 'ohio'),
#  'yeah': ('yeah', 'yea'),
#  'interesting': ('interest',
#   'concern',
#   'matter_to',
#   'interesting',
#   'occupy',
#   'worry'),
#  'show': ('evidence',
#   'register',
#   'read',
#   'record',
#   'depict',
#   'display',
#   'prove',
#   'demo',
#   'appearance',
#   'render',
#   'testify',
#   'usher',
#   'indicate',
#   'show_up',
#   'picture',
#   'express',
#   'evince',
#   'demonstrate',
#   'shew',
#   'present',
#   'show',
#   'designate',
#   'bear_witness',
#   'exhibit',
#   'point',
#   'establish'),
#  'least': ('to_the_lowest_degree', 'least'),
#  'recap': ('retread', 'review', 'recapitulation', 'recapitulate', 'recap'),
#  'tomorrow': ('tomorrow',),
#  'hahaha': (),
#  'man': ('isle_of_man',
#   'mankind',
#   'military_man',
#   'adult_male',
#   'humanity',
#   'human_beings',
#   'man',
#   'human',
#   'human_being',
#   'valet_de_chambre',
#   'human_race',
#   'humans',
#   'humankind',
#   'valet',
#   'piece',
#   'military_personnel',
#   'gentleman',
#   'homo',
#   'world',
#   'serviceman',
#   "gentleman's_gentleman"),
#  'come': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'ejaculate',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'cum',
#   'amount',
#   'semen',
#   'seed',
#   'total',
#   'follow',
#   'occur',
#   'seminal_fluid',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'pomona': (),
#  'everyday': ('casual',
#   'workaday',
#   'routine',
#   'mundane',
#   'everyday',
#   'unremarkable',
#   'quotidian',
#   'daily'),
#  'instead': ('rather', 'instead', 'alternatively', 'or_else'),
#  'like': ('comparable',
#   'the_likes_of',
#   'like',
#   'corresponding',
#   'wish',
#   'alike',
#   'ilk',
#   'same',
#   'care',
#   'similar',
#   'the_like'),
#  'flight': ('trajectory',
#   'fledge',
#   'flight_of_steps',
#   'flight',
#   'flying',
#   'escape',
#   'flight_of_stairs'),
#  'booked': ('engaged', 'book', 'booked', 'hold', 'reserve', 'set-aside'),
#  'plus': ('plus', 'positive', 'summation', 'asset', 'addition'),
#  'ggd': (),
#  'st': (),
#  'birthday': ('birthday', 'natal_day'),
#  'especially': ('especially', 'particularly', 'specially', 'peculiarly'),
#  'missing': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'lacking',
#   'wanting',
#   'pretermit',
#   'overleap',
#   'absent',
#   'neglect',
#   'escape',
#   'omit',
#   'lose',
#   'missing'),
#  'frnds': (),
#  'hear': ('pick_up',
#   'see',
#   'get_a_line',
#   'get_word',
#   'listen',
#   'take_heed',
#   'try',
#   'hear',
#   'discover',
#   'find_out',
#   'learn',
#   'get_wind'),
#  'quotmanasellaam': (),
#  'quot': (),
#  'kulir': (),
#  'degree': ('academic_degree',
#   'stage',
#   'level',
#   'grade',
#   'degree',
#   'point',
#   'arcdegree'),
#  'movie': ('pic',
#   'film',
#   'moving_picture',
#   'motion_picture',
#   'movie',
#   'flick',
#   'motion-picture_show',
#   'picture',
#   'moving-picture_show',
#   'picture_show'),
#  'nanbargale': (),
#  'guy': ('guy_wire',
#   'make_fun',
#   'guy_cable',
#   'blackguard',
#   'rib',
#   'laugh_at',
#   'cat',
#   'guy_rope',
#   'bozo',
#   'ridicule',
#   'guy',
#   'jest_at',
#   'hombre',
#   'roast',
#   'poke_fun'),
#  'economy': ('saving', 'thriftiness', 'economic_system', 'economy'),
#  'gotcha': (),
#  'sorry': ('deplorable',
#   'distressing',
#   'drab',
#   'meritless',
#   'no-account',
#   'disconsolate',
#   'blue',
#   'lamentable',
#   'gloomy',
#   'no-good',
#   'no-count',
#   'dismal',
#   'sorry',
#   'dark',
#   'grim',
#   'dingy',
#   'drear',
#   'regretful',
#   'good-for-nothing',
#   'pitiful',
#   'dreary',
#   'good-for-naught',
#   'bad',
#   'sad'),
#  'another': ('some_other', 'another'),
#  'enjoy': ('love',
#   'revel',
#   'savor',
#   'relish',
#   'delight',
#   'savour',
#   'enjoy',
#   'bask'),
#  'socal': (),
#  'ahahaay': (),
#  'carlie': (),
#  'came': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'amount',
#   'total',
#   'follow',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'fell': ('drop',
#   'light',
#   'devolve',
#   'decrease',
#   'savage',
#   'descend',
#   'strike_down',
#   'vicious',
#   'strike',
#   'accrue',
#   'come_down',
#   'hang',
#   'shine',
#   'fell',
#   'hide',
#   'barbarous',
#   'brutal',
#   'fall_down',
#   'return',
#   'precipitate',
#   'pass',
#   'settle',
#   'roughshod',
#   'diminish',
#   'go_down',
#   'fly',
#   'lessen',
#   'cruel',
#   'vanish',
#   'felled_seam',
#   'fall',
#   'come',
#   'cut_down',
#   'flow'),
#  'asleep': ('benumbed',
#   'asleep',
#   'numb',
#   'gone',
#   'at_rest',
#   'departed',
#   'at_peace',
#   'deceased'),
#  'friend': ('ally',
#   'admirer',
#   'booster',
#   'protagonist',
#   'supporter',
#   'friend',
#   'quaker',
#   'acquaintance',
#   'champion'),
#  'deeply': ('deep', 'profoundly', 'deeply'),
#  'moving': ('displace',
#   'act',
#   'prompt',
#   'propel',
#   'strike',
#   'go',
#   'move',
#   'actuate',
#   'proceed',
#   'moving',
#   'affect',
#   'motivate',
#   'be_active',
#   'incite',
#   'make_a_motion',
#   'impress',
#   'travel',
#   'run',
#   'locomote'),
#  'suuure': (),
#  'ah': (),
#  'snow': ('coke',
#   'bamboozle',
#   'nose_candy',
#   'snow',
#   'snowfall',
#   'blow',
#   'lead_by_the_nose',
#   'baron_snow_of_leicester',
#   "pull_the_wool_over_someone's_eyes",
#   'charles_percy_snow',
#   'c',
#   'hoodwink',
#   'c._p._snow',
#   'play_false'),
#  'patrol': ('police', 'patrol'),
#  'stuck': ('sting',
#   'stupefy',
#   'stuck',
#   'stay_put',
#   'nonplus',
#   'stick_by',
#   'bind',
#   'lodge',
#   'wedge',
#   'adhere',
#   'gravel',
#   'stick_to',
#   'cohere',
#   'amaze',
#   'hold_fast',
#   'perplex',
#   'cling',
#   'bewilder',
#   'cleave',
#   'puzzle',
#   'stick_around',
#   'beat',
#   'stand_by',
#   'flummox',
#   'baffle',
#   'bond',
#   'stay',
#   'deposit',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'indoors': ('inside', 'indoors'),
#  'coming': ('advent',
#   'fare',
#   'approach',
#   'derive',
#   'add_up',
#   'descend',
#   'climax',
#   'do',
#   'arrive',
#   'make_out',
#   'coming',
#   'issue_forth',
#   'orgasm',
#   'come_in',
#   'hail',
#   'forthcoming',
#   'sexual_climax',
#   'get_along',
#   'amount',
#   'approaching',
#   'follow',
#   'total',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall',
#   'upcoming'),
#  'fresh': ('invigorated',
#   'novel',
#   'smart',
#   'refreshing',
#   'new',
#   'tonic',
#   'clean',
#   'fresh',
#   'impertinent',
#   'overbold',
#   'reinvigorated',
#   'refreshful',
#   'impudent',
#   'sassy',
#   'unused',
#   'freshly',
#   'saucy',
#   'newly',
#   'brisk',
#   'sweet',
#   'unfermented',
#   'wise',
#   'bracing',
#   'refreshed'),
#  'air': ('gentle_wind',
#   'send',
#   'ventilate',
#   'vent',
#   'air',
#   'strain',
#   'air_travel',
#   'tune',
#   'publicise',
#   'transmit',
#   'aura',
#   'broadcast',
#   'line',
#   'breeze',
#   'melodic_phrase',
#   'aerate',
#   'airwave',
#   'bare',
#   'beam',
#   'melody',
#   'air_out',
#   'atmosphere',
#   'publicize',
#   'zephyr',
#   'melodic_line',
#   'aviation'),
#  'excellent': ('excellent', 'first-class', 'fantabulous', 'splendid'),
#  'hope': ('hope',
#   'promise',
#   'bob_hope',
#   'trust',
#   'leslie_townes_hope',
#   'go_for',
#   'desire'),
#  'sunny': ('cheery', 'gay', 'sunny'),
#  'load': ('warhead',
#   'lode',
#   'burden',
#   'stretch',
#   'incumbrance',
#   'loading',
#   'lade',
#   'shipment',
#   'consignment',
#   'dilute',
#   'debase',
#   'cargo',
#   'encumbrance',
#   'payload',
#   'lading',
#   'charge',
#   'onus',
#   'freight',
#   'load_up',
#   'laden',
#   'load',
#   'adulterate'),
#  'sun': ('solarize',
#   'insolate',
#   'sunlight',
#   'solarise',
#   'dominicus',
#   'sunbathe',
#   "lord's_day",
#   'sun',
#   'sunday',
#   'sunshine'),
#  'hurrah': ('hurrah', 'hooray'),
#  'babe': ('baby', 'infant', 'sister', 'babe'),
#  'sooo': (),
#  'thank': ('give_thanks', 'thank'),
#  'making': ('create',
#   'shit',
#   'fashioning',
#   'score',
#   'lay_down',
#   'have',
#   'take_a_shit',
#   'pretend',
#   'cause',
#   'name',
#   'gain',
#   'micturate',
#   'piddle',
#   'pee',
#   'make_water',
#   'wee',
#   'prepare',
#   'qualification',
#   'throw',
#   'work',
#   'wee-wee',
#   'do',
#   'take_in',
#   'induce',
#   'earn',
#   'pass_water',
#   'constitute',
#   'spend_a_penny',
#   'fix',
#   'pee-pee',
#   'piss',
#   'give',
#   'puddle',
#   'ca-ca',
#   'devising',
#   'making',
#   'seduce',
#   'make_up',
#   'take_a_crap',
#   'form',
#   'get_to',
#   'arrive_at',
#   'clear',
#   'hit',
#   'stool',
#   'make_believe',
#   'make',
#   'construct',
#   'draw',
#   'stimulate',
#   'urinate',
#   'progress_to',
#   'build',
#   'realize',
#   'produce',
#   'ready',
#   'relieve_oneself',
#   'take_a_leak',
#   'nominate',
#   'hold',
#   'reach',
#   'attain',
#   'defecate',
#   'bring_in',
#   'cook',
#   'take',
#   'get',
#   'crap',
#   'realise',
#   'pull_in',
#   'establish'),
#  'happen': ('encounter',
#   'occur',
#   'bump',
#   'happen',
#   'go_on',
#   'materialize',
#   'bechance',
#   'find',
#   'befall',
#   'pass',
#   'take_place',
#   'hap',
#   'pass_off',
#   'fall_out',
#   'come_about',
#   'materialise',
#   'chance'),
#  'lady': ('madam',
#   'peeress',
#   'noblewoman',
#   'lady',
#   "ma'am",
#   'gentlewoman',
#   'dame'),
#  'time': ('metre',
#   'clip',
#   'fourth_dimension',
#   'meter',
#   'sentence',
#   'time',
#   'clock',
#   'clock_time',
#   'prison_term'),
#  'went': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'move',
#   'function',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'family': ('kinfolk',
#   'house',
#   'category',
#   'phratry',
#   'menage',
#   'kin',
#   'family_unit',
#   'kinsperson',
#   'family_line',
#   'mob',
#   'home',
#   'folk',
#   'class',
#   'household',
#   'crime_syndicate',
#   'fellowship',
#   'family',
#   'kinsfolk',
#   'sept',
#   'syndicate'),
#  'party': ('political_party', 'company', 'party'),
#  'rocked': ('rock', 'sway', 'shake'),
#  'tuesday': ('tues', 'tuesday'),
#  'id': ('idaho', 'id', 'gem_state', 'i.d.'),
#  'really': ('truly',
#   'genuinely',
#   'in_truth',
#   'rattling',
#   'really',
#   'very',
#   'real',
#   'actually'),
#  'machine': ('motorcar',
#   'machine',
#   'simple_machine',
#   'automobile',
#   'car',
#   'auto',
#   'political_machine'),
#  'twitter': ('chirrup', 'chitter', 'twitter'),
#  'back': ('cover',
#   'vertebral_column',
#   'backbone',
#   'support',
#   'indorse',
#   'binding',
#   'plump_for',
#   'gage',
#   'rachis',
#   'backward',
#   'backrest',
#   'spinal_column',
#   'back',
#   'stake',
#   'second',
#   'rearward',
#   'game',
#   'backwards',
#   'spine',
#   'endorse',
#   'dorsum',
#   'book_binding',
#   'punt',
#   'back_up',
#   'hinder',
#   'rearwards',
#   'plunk_for',
#   'hind',
#   'bet_on',
#   'rear'),
#  'watching': ('observe',
#   'ascertain',
#   'keep_an_eye_on',
#   'observation',
#   'watch',
#   'find_out',
#   'take_in',
#   'look_out',
#   'look_on',
#   'see',
#   'determine',
#   'observance',
#   'follow',
#   'view',
#   'watching',
#   'watch_over',
#   'watch_out',
#   'learn',
#   'check',
#   'catch'),
#  'jay': ('john_jay', 'jay'),
#  'lenos': (),
#  'nd': ('neodymium',
#   'atomic_number_60',
#   'peace_garden_state',
#   'north_dakota',
#   'nd'),
#  'havent': (),
#  'gone': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'at_rest',
#   'departed',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'bypast',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'gone',
#   'move',
#   'function',
#   'run_low',
#   'done_for',
#   'proceed',
#   'break_down',
#   'decease',
#   'at_peace',
#   'sound',
#   'kaput',
#   'drop_dead',
#   'hold_up',
#   'asleep',
#   'belong',
#   'plump',
#   'blend_in',
#   'bygone',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'deceased',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'foregone',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'without': (),
#  'leno': (),
#  'four': ('four',
#   'quadruplet',
#   'foursome',
#   'four-spot',
#   '4',
#   'quatern',
#   'quaternity',
#   'quartet',
#   'iv',
#   'little_joe',
#   'quaternion',
#   'tetrad',
#   'quaternary'),
#  'years': ('age',
#   'years',
#   'geezerhood',
#   'yr',
#   'class',
#   'year',
#   'twelvemonth',
#   'eld',
#   'days',
#   'long_time',
#   'old_age'),
#  'ive': (),
#  'haha': (),
#  'biggest': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'headache': ('head_ache',
#   'headache',
#   'vexation',
#   'concern',
#   'cephalalgia',
#   'worry'),
#  'washed': ('moisten',
#   'wash_off',
#   'lap',
#   'washed',
#   'wash',
#   'rinse',
#   'dampen',
#   'wash_away',
#   'lave',
#   'water-washed',
#   'wash_out',
#   'launder'),
#  'hair': ('whisker',
#   'hair',
#   'tomentum',
#   'pilus',
#   'haircloth',
#   "hair's-breadth",
#   'hairsbreadth',
#   'fuzz'),
#  'wif': (),
#  'mum': ('ma',
#   "florist's_chrysanthemum",
#   'mum',
#   'mom',
#   'mummy',
#   'mamma',
#   "florists'_chrysanthemum",
#   'mammy',
#   'dendranthema_grandifloruom',
#   'chrysanthemum_morifolium',
#   'silent',
#   'momma',
#   'mommy',
#   'mama'),
#  'shampoo': ('shampoo',),
#  'gross': ('vulgar',
#   'rank',
#   'stark',
#   'receipts',
#   'glaring',
#   'sodding',
#   'megascopic',
#   'arrant',
#   '144',
#   'unadulterated',
#   'staring',
#   'complete',
#   'utter',
#   'gross',
#   'revenue',
#   'perfect',
#   'flagrant',
#   'double-dyed',
#   'egregious',
#   'pure',
#   'porcine',
#   'consummate',
#   'crude',
#   'thoroughgoing',
#   'earthy',
#   'crying',
#   'everlasting'),
#  'way': ('fashion',
#   'path',
#   'room',
#   'manner',
#   'way',
#   'style',
#   'way_of_life',
#   'mode',
#   'direction',
#   'right_smart',
#   'elbow_room',
#   'means',
#   'agency'),
#  'heading': ('header',
#   'drift',
#   'bearing',
#   'heading',
#   'head',
#   'maneuver',
#   'lead',
#   'head_up',
#   'manoeuver',
#   'steer',
#   'guide',
#   'channelize',
#   'gallery',
#   'channelise',
#   'point',
#   'aim',
#   'manoeuvre',
#   'direct'),
#  'buy': ('bribe',
#   'bargain',
#   'steal',
#   "grease_one's_palms",
#   'purchase',
#   'buy',
#   'corrupt'),
#  'needed': ('needed',
#   'call_for',
#   'involve',
#   'postulate',
#   'requisite',
#   'demand',
#   'required',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'needful',
#   'need',
#   'require'),
#  'bottle': ('bottleful', 'feeding_bottle', 'bottle', 'nursing_bottle'),
#  'drink': ('boozing',
#   'wassail',
#   'tope',
#   'drinkable',
#   'potable',
#   'imbibe',
#   'swallow',
#   'fuddle',
#   'booze',
#   'drink_in',
#   'pledge',
#   'drunkenness',
#   'crapulence',
#   'drinking',
#   'drink',
#   'deglutition',
#   'toast',
#   'salute',
#   'beverage'),
#  'wallet': ('billfold', 'notecase', 'wallet', 'pocketbook'),
#  'mia': (),
#  'youre': (),
# ...
#   'babble',
#   'babble_out',
#   'verbalise',
#   'lecture',
#   'blab',
#   'let_the_cat_out_of_the_bag',
#   'talk',
#   'verbalize'),
#  'dy': ('dysprosium', 'dy', 'atomic_number_66'),
#  'broke': ('burst',
#   'die',
#   'get_around',
#   'fall_in',
#   'break_away',
#   'demote',
#   'relegate',
#   'weaken',
#   'break_up',
#   'unwrap',
#   'violate',
#   'reveal',
#   'split',
#   'break_dance',
#   'disclose',
#   'come_apart',
#   'intermit',
#   'bump',
#   'breach',
#   'stone-broke',
#   'skint',
#   'discover',
#   'wear',
#   'ruin',
#   'discontinue',
#   'give_out',
#   'break_down',
#   'develop',
#   'cave_in',
#   'broke',
#   'separate',
#   'snap_off',
#   'fall_apart',
#   'offend',
#   'break',
#   'expose',
#   'break_off',
#   'fracture',
#   'smash',
#   'conk_out',
#   'go',
#   'let_on',
#   'bust',
#   'interrupt',
#   'break_out',
#   'soften',
#   'recrudesce',
#   'go_bad',
#   'dampen',
#   'pause',
#   'better',
#   'go_against',
#   'give_way',
#   'stop',
#   'check',
#   'damp',
#   'stony-broke',
#   'bring_out',
#   'bankrupt',
#   'transgress',
#   'divulge',
#   'collapse',
#   'founder',
#   'give_away',
#   'infract',
#   'give',
#   'wear_out',
#   'part',
#   'get_out',
#   'erupt',
#   'let_out',
#   'kick_downstairs',
#   'fail',
#   'break_in',
#   'break-dance',
#   'crack',
#   'split_up'),
#  'carafe': ('decanter', 'carafe'),
#  'starbucks': (),
#  'caffiene': (),
#  'fix': ('muddle',
#   'mess',
#   'gear_up',
#   'touch_on',
#   'set',
#   'secure',
#   'prepare',
#   'specify',
#   'desexualize',
#   'reparation',
#   'desex',
#   'locating',
#   'fix',
#   'repair',
#   'set_up',
#   'bushel',
#   'jam',
#   'posit',
#   'fasten',
#   'determine',
#   'hole',
#   'location',
#   'kettle_of_fish',
#   'unsex',
#   'make',
#   'localization',
#   'mend',
#   'fixing',
#   'define',
#   'fixture',
#   'pickle',
#   'mending',
#   'ready',
#   'fixate',
#   'sterilize',
#   'deposit',
#   'pay_back',
#   'doctor',
#   'furbish_up',
#   'pay_off',
#   'sterilise',
#   'desexualise',
#   'situate',
#   'cook',
#   'restore',
#   'localisation',
#   'limit',
#   'get'),
#  'light': ('light_source',
#   'inner_light',
#   'light',
#   'luminousness',
#   'short',
#   'loose',
#   'abstemious',
#   'wakeful',
#   'weak',
#   'alight',
#   'lite',
#   'scant',
#   'luminance',
#   'low-cal',
#   'clean',
#   'twinkle',
#   'easy',
#   'illume',
#   'lightheaded',
#   'light-headed',
#   'ignitor',
#   'brightness_level',
#   'perch',
#   'christ_within',
#   'sparkle',
#   'unclouded',
#   'dismount',
#   'lightsome',
#   'visible_radiation',
#   'get_off',
#   'luminosity',
#   'wanton',
#   'fire_up',
#   'illumination',
#   'lightness',
#   'light_up',
#   'get_down',
#   'faint',
#   'sluttish',
#   'clear',
#   'lighter',
#   'unaccented',
#   'idle',
#   'calorie-free',
#   'igniter',
#   'ignite',
#   'illuminate',
#   'light-colored',
#   'lightly',
#   'lighting',
#   'illumine',
#   'visible_light',
#   'swooning',
#   'promiscuous',
#   'unhorse',
#   'spark',
#   'light_within',
#   'fall',
#   'tripping',
#   'brightness'),
#  'outjust': (),
#  'sec': ('securities_and_exchange_commission',
#   's',
#   'sec',
#   'secant',
#   'unsweet',
#   'second'),
#  'kidding': ('pull_the_leg_of', 'kid', 'josh', 'chaff', 'banter', 'jolly'),
#  'megot': (),
#  'laugh': ('laugh',
#   'laughter',
#   'express_mirth',
#   'joke',
#   'gag',
#   'express_joy',
#   'jape',
#   'jest'),
#  'ha': ('hour_angle', 'ha'),
#  'guess': ('surmise',
#   'surmisal',
#   'pretend',
#   'speculation',
#   'approximate',
#   'guess',
#   'hazard',
#   'imagine',
#   'shot',
#   'guessing',
#   'opine',
#   'estimate',
#   'judge',
#   'reckon',
#   'gauge',
#   'dead_reckoning',
#   'infer',
#   'supposition',
#   'think',
#   'conjecture',
#   'guesswork',
#   'hypothesis',
#   'venture',
#   'suppose'),
#  'follower': ('follower',),
#  'vacation': ('vacation', 'holiday'),
#  'looking': ('sounding',
#   'bet',
#   'attend',
#   'looking_for',
#   'seem',
#   'front',
#   'await',
#   'depend',
#   'look',
#   'calculate',
#   'reckon',
#   'expect',
#   'looking',
#   'see',
#   'search',
#   'appear',
#   'face',
#   'looking_at',
#   'wait',
#   'take_care',
#   'count'),
#  'forward': ('forrad',
#   'forrader',
#   'fore',
#   'frontwards',
#   'advancing',
#   'ahead',
#   'onwards',
#   'forward',
#   'frontward',
#   'send_on',
#   'forth',
#   'forwards',
#   'forrard',
#   'forward-moving',
#   'onward'),
#  'walk': ('walkway',
#   'take_the_air',
#   'walk_of_life',
#   'walking',
#   'walk',
#   'base_on_balls',
#   'manner_of_walking',
#   'pass',
#   'paseo'),
#  'around': ('about',
#   'close_to',
#   'more_or_less',
#   'approximately',
#   'or_so',
#   'roughly',
#   'just_about',
#   'round',
#   'some',
#   'around'),
#  'outprocess': (),
#  'step': ('tone',
#   'whole_tone',
#   'gradation',
#   'abuse',
#   'stride',
#   'footprint',
#   'footfall',
#   'dance_step',
#   'stair',
#   'ill-use',
#   'mistreat',
#   'maltreat',
#   'footstep',
#   'measure',
#   'ill-treat',
#   'footmark',
#   'pace',
#   "stone's_throw",
#   'whole_step',
#   'tread',
#   'step'),
#  'closer': ('faithful',
#   'closer',
#   'airless',
#   'cheeseparing',
#   'near',
#   'nigh',
#   'unaired',
#   'close',
#   'nigher',
#   'closelipped',
#   'close-fitting',
#   'tightlipped',
#   'nearer',
#   'stuffy',
#   'secretive',
#   'tight',
#   'finisher',
#   'closemouthed',
#   'confining',
#   'penny-pinching',
#   'snug',
#   'skinny'),
#  'weather': ('brave_out',
#   'upwind',
#   'brave',
#   'atmospheric_condition',
#   'endure',
#   'weather',
#   'conditions',
#   'weather_condition'),
#  'rained': ('rain', 'rain_down'),
#  'five': ('fivesome',
#   'five',
#   'quintuplet',
#   'cinque',
#   'quint',
#   'quintet',
#   'little_phoebe',
#   'fin',
#   'basketball_team',
#   '5',
#   'phoebe',
#   'v',
#   'five-spot',
#   'pentad'),
#  'exploring': ('search', 'research', 'explore'),
#  'ur': ('ur',),
#  'chance': ('luck',
#   'encounter',
#   'opportunity',
#   'risk',
#   'casual',
#   'bump',
#   'happen',
#   'prospect',
#   'take_chances',
#   'probability',
#   'take_a_chance',
#   'hazard',
#   'chance',
#   'run_a_risk',
#   'find',
#   'adventure',
#   'gamble',
#   'fortune'),
#  'else': (),
#  'name': ('advert',
#   'mention',
#   'name',
#   'public_figure',
#   'describe',
#   'refer',
#   'identify',
#   'bring_up',
#   'constitute',
#   'key',
#   'gens',
#   'make',
#   'epithet',
#   'distinguish',
#   'diagnose',
#   'appoint',
#   'nominate',
#   'figure',
#   'cite',
#   'call',
#   'key_out',
#   'discover',
#   'list'),
#  'nite': (),
#  'youtube': (),
#  'yippeewish': (),
#  'keep': ('livelihood',
#   'support',
#   'celebrate',
#   'go_on',
#   'observe',
#   'keep_open',
#   'keep',
#   'donjon',
#   'hold_on',
#   'preserve',
#   'living',
#   'sustain',
#   'keep_back',
#   'hold_open',
#   'stay_fresh',
#   'proceed',
#   'go_along',
#   'restrain',
#   'hold_back',
#   'retain',
#   'dungeon',
#   'continue',
#   'bread_and_butter',
#   'maintain',
#   'hold',
#   'keep_on',
#   'prevent',
#   'save',
#   'sustenance'),
#  'company': ('troupe',
#   'party',
#   "ship's_company",
#   'fellowship',
#   'caller',
#   'company',
#   'society',
#   'companionship',
#   'companion',
#   'keep_company',
#   'accompany'),
#  'hahah': (),
#  'geez': (),
#  'ago': ('agone', 'ago'),
#  'lack': ('miss', 'lack', 'want', 'deficiency'),
#  'many': ('many',),
#  'hot': ('red-hot', 'hot', 'spicy', 'live', 'blistering', 'raging'),
#  'town': ('ithiel_town', 'town', 'townsfolk', 'township', 'townspeople'),
#  'candy': ('confect', 'candy', 'sugarcoat', 'glaze'),
#  'store': ('storage',
#   'hive_away',
#   'lay_in',
#   'computer_storage',
#   'depot',
#   'fund',
#   'computer_memory',
#   'stock',
#   'storehouse',
#   'shop',
#   'memory_board',
#   'entrepot',
#   'put_in',
#   'salt_away',
#   'stack_away',
#   'stash_away',
#   'memory',
#   'store'),
#  'straight': ('flat',
#   'unbowed',
#   'directly',
#   'true',
#   'full-strength',
#   'straightaway',
#   'straight_person',
#   'straight',
#   'unbent',
#   'uncoiled',
#   'square',
#   'neat',
#   'heterosexual_person',
#   'straightforward',
#   'consecutive',
#   'direct',
#   'heterosexual'),
#  'sweet': ('cherubic',
#   'seraphic',
#   'sweet-flavored',
#   'afters',
#   'dulcet',
#   'honeyed',
#   'sugariness',
#   'confection',
#   'fresh',
#   'gratifying',
#   'angelical',
#   'angelic',
#   'odoriferous',
#   'mellisonant',
#   'mellifluous',
#   'perfumed',
#   'sugared',
#   'dessert',
#   'sweetness',
#   'sweet-smelling',
#   'sweet',
#   'sweet-scented',
#   'unfermented',
#   'odorous',
#   'sweetened',
#   'henry_sweet',
#   'scented',
#   'sweetly'),
#  'hotel': ('hotel',),
#  'note': ('remark',
#   'tone',
#   'bank_note',
#   'mention',
#   'billet',
#   'observe',
#   'government_note',
#   'preeminence',
#   'federal_reserve_note',
#   'take_down',
#   'eminence',
#   'note_of_hand',
#   'annotation',
#   'line',
#   'short_letter',
#   'distinction',
#   'notice',
#   'note',
#   'banknote',
#   'notation',
#   'bill',
#   'musical_note',
#   'mark',
#   'bank_bill',
#   "banker's_bill",
#   'take_note',
#   'promissory_note',
#   'greenback'),
#  'game': ('biz',
#   'crippled',
#   'gage',
#   'gamey',
#   'gamy',
#   'gritty',
#   'gimpy',
#   'mettlesome',
#   'back',
#   'plot',
#   'stake',
#   'game',
#   'lame',
#   'punt',
#   'halting',
#   'bet_on',
#   'spirited',
#   'secret_plan',
#   'halt',
#   'spunky'),
#  'storm': ('surprise',
#   'storm',
#   'violent_storm',
#   'ramp',
#   'tempest',
#   'rage',
#   'force'),
#  'acting': ('do',
#   'dissemble',
#   'act',
#   'playacting',
#   'acting',
#   'playing',
#   'behave',
#   'pretend',
#   'playact',
#   'represent',
#   'roleplay',
#   'move',
#   'play',
#   'performing',
#   'work',
#   'act_as'),
#  'discussion': ('discussion',
#   'word',
#   'give-and-take',
#   'discourse',
#   'treatment'),
#  'regarding': ('consider',
#   'see',
#   'view',
#   'regard',
#   'involve',
#   'affect',
#   'reckon'),
#  'social': ('societal', 'mixer', 'social', 'sociable'),
#  'medium': ('sensitive',
#   'medium',
#   'culture_medium',
#   'average',
#   'mass_medium',
#   'spiritualist',
#   'metier',
#   'intermediate'),
#  'scott': ('winfield_scott',
#   'walter_scott',
#   'sir_walter_scott',
#   'scott',
#   'george_c._scott',
#   'robert_falcon_scott',
#   'dred_scott',
#   'robert_scott'),
#  'lake': ('lake',),
#  'ceo': ('chief_operating_officer', 'ceo', 'chief_executive_officer'),
#  'thinksm': (),
#  'attending': ('attending',
#   'go_to',
#   'see',
#   'advert',
#   'attend',
#   'hang',
#   'give_ear',
#   'assist',
#   'look',
#   'wait_on',
#   'pay_heed',
#   'attend_to',
#   'take_care',
#   'attendance',
#   'attention',
#   'serve'),
#  'answer': ('do',
#   'result',
#   'response',
#   'reply',
#   'resolution',
#   'solvent',
#   'answer',
#   'respond',
#   'suffice',
#   'serve',
#   'solution',
#   'resolve'),
#  'riddle': ('screen',
#   'conundrum',
#   'imbue',
#   'enigma',
#   'riddle',
#   'diffuse',
#   'interpenetrate',
#   'penetrate',
#   'brain-teaser',
#   'pervade',
#   'permeate'),
#  'pooper': (),
#  'joke': ('laugh',
#   'antic',
#   'trick',
#   'put-on',
#   'prank',
#   'joke',
#   'gag',
#   'caper',
#   'jape',
#   'jocularity',
#   'jest'),
#  'joyce': ('james_joyce', 'james_augustine_aloysius_joyce', 'joyce'),
#  'hav': (),
#  'gr': (),
#  'taco': ('greaser', 'wetback', 'taco'),
#  'garden': ('garden',),
#  'itd': (),
#  'cash': ('cash',
#   'hard_currency',
#   'cash_in',
#   'hard_cash',
#   'johnny_cash',
#   'john_cash',
#   'immediate_payment'),
#  'aaah': (),
#  'bye': ('goodby',
#   'good_day',
#   'bye-bye',
#   'sayonara',
#   'good-bye',
#   'bye',
#   'auf_wiedersehen',
#   'pass',
#   'adieu',
#   'cheerio',
#   'good-by',
#   'adios',
#   'so_long',
#   'arrivederci',
#   'au_revoir',
#   'goodbye'),
#  'mikee': (),
#  'smoked': ('smoke', 'smoked', 'fume', 'smoke-cured', 'smoke-dried'),
#  'crab': ('bellyache',
#   'crabby_person',
#   'pubic_louse',
#   'crabmeat',
#   'phthirius_pubis',
#   'bitch',
#   'beef',
#   'cancer',
#   'squawk',
#   'cancer_the_crab',
#   'crab',
#   'holler',
#   'gripe',
#   'crab_louse',
#   'grouse'),
#  'copyright': ('right_of_first_publication', 'copyright'),
#  'exemption': ('granting_immunity', 'exemption', 'immunity', 'freedom'),
#  'apparently': ('plain',
#   'on_the_face_of_it',
#   'manifestly',
#   'patently',
#   'plainly',
#   'seemingly',
#   'ostensibly',
#   'evidently',
#   'apparently',
#   'obviously'),
#  'trying': ('essay',
#   'stress',
#   'strain',
#   'taste',
#   'try_out',
#   'prove',
#   'try',
#   'render',
#   'examine',
#   'try_on',
#   'judge',
#   'test',
#   'assay',
#   'nerve-wracking',
#   'trying',
#   'sample',
#   'adjudicate',
#   'attempt',
#   'stressful',
#   'hear',
#   'seek',
#   'nerve-racking'),
#  'ensure': ('insure',
#   'see',
#   'ensure',
#   'assure',
#   'ascertain',
#   'secure',
#   'guarantee',
#   'see_to_it',
#   'check',
#   'control'),
#  'rest': ('repose',
#   'balance',
#   'remain',
#   'relaxation',
#   'roost',
#   'relief',
#   'ease',
#   'reside',
#   'perch',
#   'rest',
#   'quietus',
#   'pillow',
#   'residual',
#   'residue',
#   'lie',
#   'sleep',
#   'eternal_sleep',
#   'take_a_breather',
#   'breathe',
#   'eternal_rest',
#   'respite',
#   'stay',
#   'rest_period',
#   'residuum',
#   "catch_one's_breath",
#   'remainder'),
#  'lightening': ('relieve',
#   'lighten_up',
#   'brighten',
#   'buoy_up',
#   'lighten',
#   'whitening',
#   'lightening'),
#  'thunder': ('thunder',
#   'hell_dust',
#   'skag',
#   'roaring',
#   'scag',
#   'roar',
#   'nose_drops',
#   'smack',
#   'big_h',
#   'boom'),
#  'pm': ('postmortem_examination',
#   'promethium',
#   'post-mortem',
#   'necropsy',
#   'postmortem',
#   'phase_modulation',
#   'pm',
#   'post-mortem_examination',
#   'autopsy',
#   'atomic_number_61',
#   'prime_minister',
#   'premier'),
#  'sweldo': (),
#  'dork': ('dork', 'jerk'),
#  'promoting': ('raise',
#   'kick_upstairs',
#   'elevate',
#   'boost',
#   'promote',
#   'advertise',
#   'upgrade',
#   'further',
#   'advertize',
#   'encourage',
#   'advance',
#   'push'),
#  'muziknot': (),
#  'eating': ('eat',
#   'use_up',
#   'feeding',
#   'rust',
#   'deplete',
#   'exhaust',
#   'run_through',
#   'wipe_out',
#   'eat_up',
#   'consume',
#   'eating',
#   'feed',
#   'eat_on',
#   'corrode'),
#  'lmaao': (),
#  'iced': ('ice', 'frost'),
#  'coffee': ('coffee_bean',
#   'java',
#   'coffee_berry',
#   'coffee_tree',
#   'chocolate',
#   'coffee',
#   'burnt_umber',
#   'deep_brown',
#   'umber'),
#  'christ': ('jesus_of_nazareth',
#   'saviour',
#   'christ',
#   'good_shepherd',
#   'deliverer',
#   'messiah',
#   'the_nazarene',
#   'jesus',
#   'savior',
#   'redeemer',
#   'jesus_christ'),
#  'tasted': ('sample', 'savor', 'taste', 'try_out', 'savour', 'smack', 'try'),
#  'nasty': ('tight', 'awful', 'filthy', 'nasty', 'foul', 'cruddy', 'smutty'),
#  'pair': ('mate',
#   'partner_off',
#   'dyad',
#   'copulate',
#   'twin',
#   'duo',
#   'geminate',
#   'duet',
#   'twain',
#   'twosome',
#   'yoke',
#   'pair_off',
#   'duad',
#   'couplet',
#   'span',
#   'brace',
#   'couple',
#   'match',
#   'distich',
#   'pair'),
#  'git': ('rat',
#   'skunk',
#   'git',
#   'rotter',
#   'scum_bag',
#   'stinkpot',
#   'so-and-so',
#   'bum',
#   'lowlife',
#   'dirty_dog',
#   'crumb',
#   'stinker',
#   'puke'),
#  'mega': (),
#  'bus': ('passenger_vehicle',
#   'heap',
#   'omnibus',
#   'motorbus',
#   'jitney',
#   'autobus',
#   'bus_topology',
#   'bus',
#   'busbar',
#   'charabanc',
#   'coach',
#   'double-decker',
#   'motorcoach',
#   'jalopy'),
#  'lovely': ('pin-up', 'lovely', 'adorable', 'endearing', 'cover_girl'),
#  'stupid': ('stupefied',
#   'dullard',
#   'poor_fish',
#   'pillock',
#   'pudding_head',
#   'unintelligent',
#   'stupid',
#   'pudden-head',
#   'stunned',
#   'stupid_person',
#   'dolt',
#   'dazed',
#   'stupe'),
#  'slapton': (),
#  'ians': (),
#  'congrats': (),
#  'mollie': ('mollie', 'molly'),
#  'conti': (),
#  'boooooooo': (),
#  'chivalry': ('politesse', 'chivalry', 'gallantry', 'knightliness'),
#  'dead': ('absolutely',
#   'bushed',
#   'numb',
#   'short',
#   'beat',
#   'all_in',
#   'drained',
#   'suddenly',
#   'idle',
#   'abruptly',
#   'perfectly',
#   'stagnant',
#   'deadened',
#   'utterly',
#   'utter',
#   'dead'),
#  'rare': ('rare', 'rarified', 'rarefied', 'uncommon'),
#  'breakfast': ('breakfast',),
#  'maintenance': ('sustainment',
#   'criminal_maintenance',
#   'maintenance',
#   'care',
#   'sustentation',
#   'upkeep',
#   'alimony',
#   'sustenance'),
#  'dnt': (),
#  'even': ('eventide',
#   'fifty-fifty',
#   'even',
#   'regular',
#   'tied',
#   'level',
#   'yet',
#   'still',
#   'eve',
#   'flush',
#   'evening',
#   'even_out'),
#  'wearing': ('wear',
#   'don',
#   'break',
#   'wearing_away',
#   'outwear',
#   'tire',
#   'bear',
#   'hold_out',
#   'wear_down',
#   'wear_upon',
#   'put_on',
#   'get_into',
#   'wearying',
#   'wear_out',
#   'weary',
#   'bust',
#   'assume',
#   'endure',
#   'jade',
#   'wear_thin',
#   'fall_apart',
#   'have_on',
#   'fag_out',
#   'wearing',
#   'tire_out',
#   'fag',
#   'fatigue',
#   'eroding',
#   'erosion',
#   'eating_away',
#   'exhausting',
#   'wear_off',
#   'tiring'),
#  'skinny': ('scrawny',
#   'tight-fitting',
#   'near',
#   'tightfitting',
#   'underweight',
#   'weedy',
#   'penny-pinching',
#   'tight_fitting',
#   'close',
#   'tightly_fitting',
#   'cheeseparing',
#   'scraggy',
#   'skinny',
#   'boney'),
#  'jean': ('blue_jean', 'dungaree', 'jean', 'denim'),
#  'bitch': ('bellyache',
#   'beef',
#   'bitch',
#   'holler',
#   'backbite',
#   'squawk',
#   'kick',
#   'crab',
#   'gripe',
#   'cunt',
#   'grouse'),
#  ...}

# %%
# remove null value in synonym_dict
synonym_dict = {k: v for k, v in synonym_dict.items() if v}

synonym_dict
# Out:
# {'much': ('a_lot',
#   'much',
#   'often',
#   'lots',
#   'a_great_deal',
#   'very_much',
#   'a_good_deal',
#   'practically'),
#  'better': ('honest',
#   'advantageously',
#   'break',
#   'well',
#   'improve',
#   'secure',
#   'good',
#   'adept',
#   'considerably',
#   'dear',
#   'amend',
#   'practiced',
#   'intimately',
#   'near',
#   'ameliorate',
#   'in_effect',
#   'wagerer',
#   'right',
#   'best',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'meliorate',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'substantially',
#   'easily',
#   'skilful',
#   'safe',
#   'skillful',
#   'bettor',
#   'beneficial',
#   'better',
#   'effective',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'comfortably',
#   'dependable',
#   'undecomposed',
#   'ripe',
#   'punter'),
#  'far': ('far',
#   'alir',
#   'interahamwe',
#   'former_armed_forces',
#   'army_for_the_liberation_of_rwanda'),
#  'still': ('nonetheless',
#   'tranquillise',
#   'relieve',
#   'soundless',
#   'placid',
#   'even',
#   'yet',
#   'allay',
#   'quiet',
#   'ease',
#   'hush',
#   'hush_up',
#   'distillery',
#   'static',
#   'inactive',
#   'quieten',
#   'withal',
#   'silent',
#   'silence',
#   'motionless',
#   'tranquil',
#   'tranquilize',
#   'shut_up',
#   'noneffervescent',
#   'still',
#   'all_the_same',
#   'even_so',
#   'stock-still',
#   'tranquillize',
#   'calm_down',
#   'notwithstanding',
#   'unruffled',
#   'smooth',
#   'stillness',
#   'lull',
#   'nevertheless',
#   'calm',
#   'however'),
#  'quite': ('quite_a', 'rather', 'quite', 'quite_an'),
#  'early': ('betimes',
#   'too_soon',
#   'early_on',
#   'ahead_of_time',
#   'early',
#   'former',
#   'other'),
#  'last': ('utmost',
#   'lowest',
#   'end',
#   'live',
#   'net',
#   'stopping_point',
#   'terminal',
#   'go',
#   'hold_out',
#   'last',
#   'death',
#   'final_stage',
#   'live_on',
#   'close',
#   'finis',
#   'finish',
#   'concluding',
#   'lastly',
#   'hold_up',
#   'last-place',
#   'endure',
#   'final',
#   'finale',
#   'finally',
#   "cobbler's_last",
#   'survive',
#   "shoemaker's_last",
#   'conclusion',
#   'in_conclusion'),
#  'great': ('keen',
#   'expectant',
#   'majuscule',
#   'bang-up',
#   'corking',
#   'slap-up',
#   'nifty',
#   'swell',
#   'groovy',
#   'not_bad',
#   'bully',
#   'great',
#   'with_child',
#   'big',
#   'capital',
#   'gravid',
#   'peachy',
#   'cracking',
#   'neat',
#   'enceinte',
#   'large',
#   'outstanding',
#   'dandy',
#   'smashing',
#   'heavy'),
#  'see': ('visualise',
#   'consider',
#   'encounter',
#   'ensure',
#   'attend',
#   'get_a_line',
#   'understand',
#   'regard',
#   'ascertain',
#   'get_word',
#   'go_through',
#   'escort',
#   'check',
#   'see_to_it',
#   'watch',
#   'find_out',
#   'control',
#   'pick_up',
#   'take_in',
#   'project',
#   'come_across',
#   'visualize',
#   'look',
#   'examine',
#   'find',
#   'run_across',
#   'picture',
#   'catch',
#   'reckon',
#   'envision',
#   'insure',
#   'see',
#   'meet',
#   'run_into',
#   'determine',
#   'visit',
#   'assure',
#   'date',
#   'image',
#   'get_wind',
#   'realize',
#   'go_steady',
#   'witness',
#   'view',
#   'construe',
#   'figure',
#   'take_care',
#   'interpret',
#   'go_out',
#   'hear',
#   'discover',
#   'realise',
#   'fancy',
#   'learn',
#   'experience'),
#  'cynthia': ('artemis', 'cynthia'),
#  'happy': ('felicitous', 'well-chosen', 'happy', 'glad'),
#  'dinner': ('dinner', 'dinner_party'),
#  'cute': ('cunning', 'precious', 'cute'),
#  'little': ('little',
#   'lilliputian',
#   'piddling',
#   'niggling',
#   'picayune',
#   'trivial',
#   'short',
#   'minuscule',
#   'slight',
#   'piffling',
#   'small',
#   'fiddling',
#   'petty',
#   'footling'),
#  'place': ('rank',
#   'send',
#   'place',
#   'office',
#   'billet',
#   'shoes',
#   'plaza',
#   'stead',
#   'put',
#   'set',
#   'grade',
#   'localise',
#   'identify',
#   'locate',
#   'localize',
#   'lieu',
#   'order',
#   'come_out',
#   'home',
#   'rate',
#   'range',
#   'piazza',
#   'space',
#   'site',
#   'spot',
#   'come_in',
#   'direct',
#   'post',
#   'property',
#   'topographic_point',
#   'invest',
#   'target',
#   'seat',
#   'position',
#   'commit',
#   'berth',
#   'situation',
#   'pose',
#   'lay',
#   'blank_space',
#   'point',
#   'aim',
#   'station'),
#  'bad': ('badly',
#   'unsound',
#   'big',
#   'risky',
#   'unfit',
#   'regretful',
#   'high-risk',
#   'uncollectible',
#   'tough',
#   'badness',
#   'sorry',
#   'speculative',
#   'spoiled',
#   'bad',
#   'defective',
#   'spoilt',
#   'forged'),
#  'sick': ('fed_up',
#   'queasy',
#   'spew',
#   'nauseous',
#   'tired_of',
#   'unhinged',
#   'pallid',
#   'upchuck',
#   'macabre',
#   'cast',
#   'barf',
#   'vomit',
#   'ghastly',
#   'demented',
#   'crazy',
#   'retch',
#   'purge',
#   'cat',
#   'spue',
#   'sick_of',
#   'mad',
#   'throw_up',
#   'disgorge',
#   'disturbed',
#   'chuck',
#   'sick',
#   'wan',
#   'honk',
#   'gruesome',
#   'pale',
#   'grim',
#   'brainsick',
#   'ill',
#   'vomit_up',
#   'regorge',
#   'grisly',
#   'disgusted',
#   'be_sick',
#   'nauseated',
#   'sickish',
#   'unbalanced',
#   'regurgitate',
#   'puke'),
#  'afterwards': ('subsequently',
#   'afterwards',
#   'after',
#   'afterward',
#   'later',
#   'later_on'),
#  'dude': ('dude',
#   'fashion_plate',
#   'swell',
#   'clotheshorse',
#   'dandy',
#   'buster',
#   'fop',
#   'fellow',
#   'sheik',
#   'gallant',
#   'beau'),
#  'favorite': ('deary',
#   'favourite',
#   'dearie',
#   'ducky',
#   'preferent',
#   'best-loved',
#   'favored',
#   'preferred',
#   'favorite',
#   'darling',
#   'pet',
#   'front-runner'),
#  'sandwich': ('sandwich',),
#  'ever': ('ever_so', 'always', "e'er", 'of_all_time', 'ever'),
#  'take': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'yield',
#   'require',
#   'issue',
#   'lease',
#   'strike',
#   'proceeds',
#   'take_in',
#   'use_up',
#   'call_for',
#   'payoff',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'return',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'takings',
#   'learn'),
#  'picture': ('video',
#   'visualise',
#   'film',
#   'motion-picture_show',
#   'ikon',
#   'scene',
#   'depict',
#   'render',
#   'project',
#   'impression',
#   'pictorial_matter',
#   'visualize',
#   'movie',
#   'delineation',
#   'mental_picture',
#   'picture',
#   'word-painting',
#   'picture_show',
#   'characterisation',
#   'word_picture',
#   'exposure',
#   'envision',
#   'see',
#   'pic',
#   'show',
#   'moving_picture',
#   'icon',
#   'motion_picture',
#   'painting',
#   'photograph',
#   'image',
#   'characterization',
#   'flick',
#   'photo',
#   'figure',
#   'moving-picture_show',
#   'fancy',
#   'depiction'),
#  'need': ('require',
#   'call_for',
#   'pauperization',
#   'pauperism',
#   'involve',
#   'postulate',
#   'demand',
#   'penury',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'motive',
#   'need',
#   'indigence',
#   'motivation'),
#  'pack': ('ring',
#   'multitude',
#   'clique',
#   'ingroup',
#   'mob',
#   'tamp_down',
#   'large_number',
#   'coterie',
#   'load_down',
#   'inner_circle',
#   'jam',
#   'plurality',
#   'gang',
#   'battalion',
#   'pack',
#   'wad',
#   'pile',
#   'camp',
#   'backpack',
#   'bundle',
#   'compact',
#   'tamp',
#   'throng',
#   'carry',
#   'take',
#   'face_pack'),
#  'cali': ('cali',),
#  'can': ('displace',
#   'rump',
#   'buttocks',
#   'hind_end',
#   'bathroom',
#   'john',
#   'behind',
#   'bottom',
#   'lav',
#   'prat',
#   'tooshie',
#   'nates',
#   'throne',
#   'fundament',
#   'send_away',
#   'butt',
#   'ass',
#   'canful',
#   'stern',
#   'tush',
#   'privy',
#   'can',
#   'force_out',
#   'fire',
#   'fanny',
#   'arse',
#   'buns',
#   'sack',
#   'crapper',
#   'dismiss',
#   'derriere',
#   'stool',
#   'potty',
#   'bum',
#   'rear_end',
#   'seat',
#   'terminate',
#   'posterior',
#   'give_notice',
#   'keister',
#   'tin_can',
#   'backside',
#   'toilet',
#   'lavatory',
#   'give_the_sack',
#   'give_the_axe',
#   'tail_end',
#   'hindquarters',
#   'tin',
#   'can_buoy',
#   'pot',
#   'commode',
#   'put_up',
#   'tail',
#   'rear'),
#  'not': ('not', 'non'),
#  'thinking': ('consider',
#   'recollect',
#   'believe',
#   'guess',
#   'imagine',
#   'thought',
#   'intelligent',
#   'call_back',
#   'opine',
#   'cerebrate',
#   'mentation',
#   'reckon',
#   'recall',
#   'call_up',
#   'intend',
#   'reasoning',
#   'remember',
#   'cogitate',
#   'think',
#   'mean',
#   'intellection',
#   'retrieve',
#   'conceive',
#   'thought_process',
#   'cerebration',
#   'thinking',
#   'suppose'),
#  'glass': ('crank',
#   'field_glass',
#   'glass',
#   'chicken_feed',
#   'ice',
#   'deoxyephedrine',
#   'spyglass',
#   'methedrine',
#   'drinking_glass',
#   'glass_over',
#   'glaze_over',
#   'glassful',
#   'methamphetamine_hydrochloride',
#   'trash',
#   'shabu',
#   'chalk',
#   'looking_glass',
#   'meth',
#   'glaze',
#   'methamphetamine',
#   'glass_in'),
#  'wine': ('wine-coloured', 'wine', 'wine-colored', 'vino'),
#  'order': ('ordination',
#   'dictate',
#   'rank',
#   'place',
#   'ordinate',
#   'regularize',
#   'edict',
#   'ordain',
#   'put',
#   'grade',
#   'tell',
#   'guild',
#   'holy_order',
#   'say',
#   'order',
#   'prescribe',
#   'lodge',
#   'rate',
#   'range',
#   'ordering',
#   'gild',
#   'parliamentary_procedure',
#   'monastic_order',
#   'set_up',
#   'parliamentary_law',
#   'orderliness',
#   'enjoin',
#   'club',
#   'rescript',
#   'arrange',
#   'society',
#   'govern',
#   'social_club',
#   'regulate',
#   'rules_of_order',
#   'consecrate',
#   'purchase_order',
#   'order_of_magnitude',
#   'fiat',
#   'regularise',
#   'decree'),
#  'celebrate': ('lionise', 'celebrate', 'observe', 'keep', 'lionize', 'fete'),
#  'weekend': ('weekend',),
#  'work': ('act',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'employment',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'oeuvre',
#   'operate',
#   'ferment',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'piece_of_work',
#   'workplace',
#   'process',
#   'lick',
#   'mould',
#   'run',
#   'study',
#   'make_for',
#   'body_of_work',
#   'exercise',
#   'knead'),
#  'morrow': ('morrow',),
#  'tho': ('tho',),
#  'took': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'require',
#   'lease',
#   'strike',
#   'take_in',
#   'use_up',
#   'call_for',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'learn'),
#  'math': ('maths', 'math', 'mathematics'),
#  'test': ('test',
#   'screen',
#   'quiz',
#   'essay',
#   'trial_run',
#   'mental_test',
#   'mental_testing',
#   'examination',
#   'psychometric_test',
#   'trial',
#   'examine',
#   'try_out',
#   'tryout',
#   'run',
#   'exam',
#   'prove',
#   'try'),
#  'today': ('today', 'now', 'nowadays'),
#  'teacher': ('instructor', 'teacher'),
#  'say': ('order',
#   'enjoin',
#   'allege',
#   'pronounce',
#   'aver',
#   'enounce',
#   'read',
#   'tell',
#   'enunciate',
#   'articulate',
#   'sound_out',
#   'say',
#   'state',
#   'suppose'),
#  'bring': ('wreak',
#   'lend',
#   'fetch',
#   'add',
#   'land',
#   'convey',
#   'bring',
#   'impart',
#   'play',
#   'take',
#   'get',
#   'institute',
#   'bestow',
#   'bring_in',
#   'contribute',
#   'make_for',
#   'work'),
#  'calculator': ('figurer',
#   'calculator',
#   'calculating_machine',
#   'estimator',
#   'computer',
#   'reckoner'),
#  'luke': ('luke',
#   'st._luke',
#   'saint_luke',
#   'gospel_according_to_luke',
#   'gospel_of_luke'),
#  'confident': ('sure-footed',
#   'convinced',
#   'positive',
#   'surefooted',
#   'confident'),
#  'decided': ('decide',
#   'determine',
#   'settle',
#   'adjudicate',
#   "make_up_one's_mind",
#   'distinct',
#   'decided',
#   'resolve'),
#  'concert': ('concert',),
#  'awesome': ('awful', 'amazing', 'awe-inspiring', 'awesome', 'awing'),
#  'madrigal': ('madrigal',),
#  'gave': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'contribute',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chill': ('frisson',
#   'shivering',
#   'quiver',
#   'thrill',
#   'iciness',
#   'shiver',
#   'pall',
#   'cool',
#   'chill',
#   'tingle',
#   'gelidity',
#   'cool_down',
#   'shudder'),
#  'almost': ('about',
#   'near',
#   'nigh',
#   'almost',
#   'virtually',
#   'well-nigh',
#   'nearly',
#   'most'),
#  'every': ('every',),
#  'also': ('as_well', 'too', 'likewise', 'besides', 'also'),
#  'called': ('ring',
#   'foretell',
#   'shout',
#   'forebode',
#   'name',
#   'squall',
#   'address',
#   'promise',
#   'prognosticate',
#   'anticipate',
#   'holler',
#   'hollo',
#   'scream',
#   'send_for',
#   'call_up',
#   'call_in',
#   'visit',
#   'call_off',
#   'cry',
#   'predict',
#   'phone',
#   'bid',
#   'call',
#   'shout_out',
#   'telephone',
#   'yell'),
#  'alumnus': ('graduate', 'alumna', 'alumnus', 'grad', 'alum'),
#  'cant': ('chamfer',
#   'slant',
#   'tilt',
#   'cant_over',
#   'bank',
#   'lingo',
#   'cant',
#   'vernacular',
#   'buzzword',
#   'patois',
#   'slang',
#   'pious_platitude',
#   'jargon',
#   'argot',
#   'camber',
#   'bevel',
#   'pitch'),
#  'minute': ('moment',
#   'min',
#   'instant',
#   'bit',
#   'minute_of_arc',
#   'hour',
#   'narrow',
#   'minute',
#   'arcminute',
#   'mo',
#   'second',
#   'infinitesimal'),
#  'treadmill': ('tread-wheel', 'salt_mine', 'treadwheel', 'treadmill'),
#  'done': ('act',
#   'fare',
#   'cause',
#   'set',
#   'perform',
#   'serve',
#   'execute',
#   'practice',
#   'coiffe',
#   'do',
#   'practise',
#   'behave',
#   'done',
#   'make_out',
#   'coif',
#   'get_along',
#   'coiffure',
#   'make',
#   'dress',
#   'arrange',
#   'suffice',
#   'through_with',
#   'manage',
#   'through',
#   'answer',
#   'come',
#   'exercise'),
#  'already': ('already',),
#  'na': ('sodium', 'atomic_number_11', 'na'),
#  'roomy': ('roommate', 'spacious', 'roomie', 'roomy'),
#  'wait': ('postponement',
#   'look',
#   'hold',
#   'time_lag',
#   'wait',
#   'hold_off',
#   'waitress',
#   'waiting',
#   'delay',
#   'hold_back',
#   'expect',
#   'await'),
#  'zombie': ('living_dead',
#   'zombie',
#   'automaton',
#   'zombi',
#   'snake_god',
#   'zombie_spirit',
#   'zombi_spirit'),
#  'cr': ('cr', 'chromium', 'atomic_number_24'),
#  'week': ('calendar_week', 'week', 'workweek', 'hebdomad'),
#  'spilled': ('spill',
#   'slop',
#   'run_out',
#   'talk',
#   'splatter',
#   'shed',
#   'disgorge',
#   'pour_forth'),
#  'beer': ('beer',),
#  'leg': ('branch',
#   'pegleg',
#   'peg',
#   'wooden_leg',
#   'stage',
#   'ramification',
#   'leg'),
#  'wasted': ('cadaverous',
#   'wasted',
#   'scourge',
#   'superfluous',
#   'rot',
#   'blow',
#   'emaciated',
#   'run_off',
#   'squandered',
#   'emaciate',
#   'pointless',
#   'ware',
#   'neutralise',
#   'otiose',
#   'macerate',
#   'liquidate',
#   'bony',
#   'squander',
#   'knock_off',
#   'senseless',
#   'atrophied',
#   'neutralize',
#   'haggard',
#   'do_in',
#   'pine_away',
#   'diminished',
#   'desolate',
#   'skeletal',
#   'waste',
#   'ravage',
#   'pinched',
#   'gaunt',
#   'lay_waste_to',
#   'consume',
#   'devastate',
#   'languish',
#   'purposeless'),
#  'half': ('one-half', 'half'),
#  'home': ('place',
#   'home_plate',
#   'house',
#   'home_base',
#   'menage',
#   'interior',
#   'plate',
#   'abode',
#   'home',
#   'base',
#   'national',
#   'dwelling_house',
#   'household',
#   'internal',
#   'dwelling',
#   'domicile',
#   'habitation',
#   'rest_home',
#   'nursing_home',
#   'family'),
#  'met': ('encounter',
#   'play',
#   'conform_to',
#   'gather',
#   'touch',
#   'adjoin',
#   'come_across',
#   'fulfill',
#   'suffer',
#   'satisfy',
#   'run_across',
#   'contact',
#   'run_into',
#   'meet',
#   'see',
#   'take_on',
#   'fulfil',
#   'forgather',
#   'get_together',
#   'fit',
#   'cope_with',
#   'receive',
#   'match',
#   'converge',
#   'fill',
#   'assemble',
#   'foregather'),
#  'girl': ('miss',
#   'female_child',
#   'young_woman',
#   'daughter',
#   'little_girl',
#   'girl',
#   'missy',
#   'lady_friend',
#   'fille',
#   'girlfriend',
#   'young_lady'),
#  'good': ('honest',
#   'well',
#   'secure',
#   'good',
#   'adept',
#   'dear',
#   'practiced',
#   'soundly',
#   'near',
#   'in_effect',
#   'right',
#   'goodness',
#   'trade_good',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'skilful',
#   'thoroughly',
#   'safe',
#   'skillful',
#   'beneficial',
#   'effective',
#   'commodity',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'dependable',
#   'undecomposed',
#   'ripe'),
#  'conversation': ('conversation',),
#  'english': ('english_language', 'english', 'english_people', 'side'),
#  'class': ('sort',
#   'sort_out',
#   'socio-economic_class',
#   'course_of_instruction',
#   'form',
#   'category',
#   'grade',
#   'course',
#   'class',
#   'stratum',
#   'year',
#   'separate',
#   'family',
#   'course_of_study',
#   'assort',
#   'classify',
#   'social_class',
#   'division'),
#  'working': ('working',
#   'act',
#   'workings',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'ferment',
#   'operate',
#   'functional',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'on_the_job',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'running',
#   'process',
#   'lick',
#   'mould',
#   'operative',
#   'run',
#   'make_for',
#   'exercise',
#   'knead'),
#  'interactive': ('interactional', 'synergistic', 'interactive'),
#  'oral': ('oral_exam',
#   'viva_voce',
#   'oral',
#   'viva',
#   'oral_examination',
#   'unwritten'),
#  'boring': ('tire',
#   'dull',
#   'wearisome',
#   'tiresome',
#   'bore',
#   'irksome',
#   'oil_production',
#   'ho-hum',
#   'slow',
#   'drilling',
#   'drill',
#   'boring',
#   'tedious',
#   'deadening'),
#  'wan': ('sick', 'wan', 'pallid', 'wide_area_network', 'pale'),
#  'sing': ('whistle',
#   'babble',
#   'babble_out',
#   'spill_the_beans',
#   'let_the_cat_out_of_the_bag',
#   'sing',
#   'talk',
#   'peach',
#   'blab',
#   'blab_out',
#   'tattle'),
#  'right': ('rectify',
#   'rightfulness',
#   'compensate',
#   'decent',
#   'in_good_order',
#   'good',
#   'properly',
#   'the_right_way',
#   'right_hand',
#   'flop',
#   'justly',
#   'correctly',
#   'right-hand',
#   'aright',
#   'right',
#   'redress',
#   'mighty',
#   'correct',
#   'proper',
#   'veracious',
#   'right_field',
#   'powerful',
#   'right_wing',
#   'right_on',
#   'rightfield',
#   'mightily',
#   'decently',
#   'ripe'),
#  'must': ('moldiness', 'must', 'mustiness'),
#  'new': ('fresh',
#   'raw',
#   'novel',
#   'unexampled',
#   'freshly',
#   'new',
#   'modern',
#   'newfangled',
#   'newly',
#   'young'),
#  'music': ('euphony', 'medicine', 'music'),
#  'wont': ('habit', 'wont'),
#  'sleep': ('kip',
#   "log_z's",
#   "catch_some_z's",
#   'nap',
#   'sleep',
#   'slumber',
#   'rest',
#   'sopor',
#   'eternal_sleep',
#   'quietus',
#   'eternal_rest'),
#  'give': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'springiness',
#   'contribute',
#   'spring',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chapter': ('chapter',),
#  'might': ('mightiness', 'power', 'might'),
#  'die': ('die',
#   'become_flat',
#   'croak',
#   'break',
#   'give-up_the_ghost',
#   'buy_the_farm',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'conk_out',
#   'go',
#   'conk',
#   'break_down',
#   'decease',
#   'drop_dead',
#   'die_out',
#   'go_bad',
#   'pass',
#   'pop_off',
#   'pall',
#   'choke',
#   'pass_away',
#   'dice',
#   "cash_in_one's_chips",
#   'exit',
#   'fail',
#   'snuff_it',
#   'give_way',
#   'expire'),
#  'first': ('low_gear',
#   'get-go',
#   '1st',
#   'beginning',
#   'number_one',
#   'first-class_honours_degree',
#   'first_gear',
#   'first_of_all',
#   'number_1',
#   'firstly',
#   'start',
#   'first',
#   'first_base',
#   'inaugural',
#   'showtime',
#   'initiatory',
#   'low',
#   'first_off',
#   'world-class',
#   'foremost',
#   'commencement',
#   'maiden',
#   'outset',
#   'initiative',
#   'starting_time',
#   'kickoff',
#   'offset',
#   'for_the_first_time'),
#  'though': ('though',),
#  'hurry': ('speed',
#   'zip',
#   'travel_rapidly',
#   'festinate',
#   'precipitation',
#   'look_sharp',
#   'hastiness',
#   'rush',
#   'hurry',
#   'hurriedness',
#   'haste',
#   'hasten',
#   'rushing'),
#  'look': ('tone',
#   'feel',
#   'attend',
#   'facial_expression',
#   'bet',
#   'seem',
#   'front',
#   'await',
#   'depend',
#   'look',
#   'calculate',
#   'reckon',
#   'expect',
#   'looking',
#   'see',
#   'feeling',
#   'search',
#   'appear',
#   'aspect',
#   'smell',
#   'expression',
#   'spirit',
#   'face',
#   'looking_at',
#   'wait',
#   'take_care',
#   'flavour',
#   'flavor',
#   'count'),
#  'lot': ('luck',
#   'circumstances',
#   'mess',
#   'deal',
#   'bunch',
#   'passel',
#   'set',
#   'slew',
#   'stack',
#   'mete_out',
#   'parcel_out',
#   'tidy_sum',
#   'administer',
#   'circle',
#   'band',
#   'portion',
#   'dole_out',
#   'mountain',
#   'hatful',
#   'flock',
#   'great_deal',
#   'batch',
#   'wad',
#   'heap',
#   'deal_out',
#   'allot',
#   'mass',
#   'pile',
#   'distribute',
#   'quite_a_little',
#   'destiny',
#   'shell_out',
#   'sight',
#   'muckle',
#   'caboodle',
#   'draw',
#   'dispense',
#   'mint',
#   'spate',
#   'fortune',
#   'raft',
#   'fate',
#   'peck',
#   'mickle',
#   'good_deal',
#   'pot',
#   'dish_out',
#   'lot',
#   'plenty'),
#  'hi': ('howdy',
#   "hawai'i",
#   'aloha_state',
#   'hullo',
#   'hi',
#   'how-do-you-do',
#   'hawaii',
#   'hello'),
#  'enough': ('decent', 'sufficiency', 'adequate', 'enough', 'plenty'),
#  'replay': ('rematch',
#   'action_replay',
#   'instant_replay',
#   'replay',
#   'play_back'),
#  'please': ('please', 'delight'),
#  'love': ('love_life',
#   'bonk',
#   'roll_in_the_hay',
#   'have_sex',
#   'hump',
#   'get_it_on',
#   'passion',
#   'dear',
#   'dearest',
#   'be_intimate',
#   'love',
#   'screw',
#   'bang',
#   'have_it_away',
#   'sleep_with',
#   'get_laid',
#   'make_out',
#   'jazz',
#   'erotic_love',
#   'bed',
#   'have_it_off',
#   'have_a_go_at_it',
#   'making_love',
#   'lovemaking',
#   'do_it',
#   'honey',
#   'sleep_together',
#   'eff',
#   'sexual_love',
#   'have_intercourse',
#   'make_love',
#   'lie_with',
#   'enjoy',
#   'know',
#   'fuck',
#   'beloved'),
#  'big': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'boastfully',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'vauntingly',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'vanessa': ('genus_vanessa', 'vanessa'),
#  'going': ('release',
#   'die',
#   'loss',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'passing',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'expiration',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'leaving',
#   'departure',
#   'move',
#   'function',
#   'going_away',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'going',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'sledding',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'september': ('september', 'sept', 'sep'),
#  'fast': ('degenerate',
#   'immobile',
#   'tight',
#   'fasting',
#   'quick',
#   'fast',
#   'firm',
#   'profligate',
#   'truehearted',
#   'degraded',
#   'dissolute',
#   'dissipated',
#   'flying',
#   'loyal',
#   'debauched',
#   'libertine',
#   'riotous'),
#  'hard': ('voiceless',
#   'laborious',
#   'operose',
#   'toilsome',
#   'gruelling',
#   'tough',
#   'firmly',
#   'knockout',
#   'intemperate',
#   'severely',
#   'punishing',
#   'severe',
#   'unvoiced',
#   'heavily',
#   'concentrated',
#   'difficult',
#   'intemperately',
#   'strong',
#   'hard',
#   'surd',
#   'backbreaking',
#   'arduous',
#   'heavy',
#   'grueling'),
#  'miss': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'young_woman',
#   'girl',
#   'misfire',
#   'pretermit',
#   'missy',
#   'overleap',
#   'fille',
#   'neglect',
#   'escape',
#   'omit',
#   'young_lady',
#   'lose'),
#  'lord': ('overlord',
#   'noble',
#   'almighty',
#   'nobleman',
#   'maker',
#   'godhead',
#   'master',
#   'lord',
#   'creator',
#   'divine',
#   'jehovah',
#   'god_almighty'),
#  'seen': ('visualise',
#   'consider',
#   'encounter',
#   'ensure',
#   'attend',
#   'get_a_line',
#   'understand',
#   'regard',
#   'ascertain',
#   'get_word',
#   'go_through',
#   'escort',
#   'check',
#   'see_to_it',
#   'watch',
#   'find_out',
#   'control',
#   'pick_up',
#   'take_in',
#   'project',
#   'come_across',
#   'visualize',
#   'look',
#   'examine',
#   'find',
#   'run_across',
#   'picture',
#   'catch',
#   'reckon',
#   'envision',
#   'insure',
#   'see',
#   'meet',
#   'run_into',
#   'determine',
#   'visit',
#   'assure',
#   'date',
#   'image',
#   'get_wind',
#   'realize',
#   'go_steady',
#   'witness',
#   'view',
#   'construe',
#   'figure',
#   'take_care',
#   'interpret',
#   'go_out',
#   'hear',
#   'discover',
#   'realise',
#   'fancy',
#   'learn',
#   'experience'),
#  'agency': ('bureau',
#   'office',
#   'way',
#   'means',
#   'authority',
#   'government_agency',
#   'representation',
#   'federal_agency',
#   'delegacy',
#   'agency'),
#  'upcoming': ('coming', 'forthcoming', 'approaching', 'upcoming'),
#  'open': ('spread_out',
#   'loose',
#   'heart-to-heart',
#   'open_air',
#   'candid',
#   'assailable',
#   'subject',
#   'undefended',
#   'capable',
#   'overt',
#   'out-of-doors',
#   'spread',
#   'give',
#   'receptive',
#   'surface',
#   'open',
#   'unresolved',
#   'clear',
#   'undefendable',
#   'unfold',
#   'outdoors',
#   'undecided',
#   'undetermined',
#   'opened',
#   'exposed',
#   'unfastened',
#   'afford',
#   'open_up'),
#  'money': ('money',),
#  'jam': ('muddle',
#   'crush',
#   'mess',
#   'chock_up',
#   'block',
#   'press',
#   'mob',
#   'jamming',
#   'jampack',
#   'fix',
#   'ram',
#   'jam',
#   'pack',
#   'wad',
#   'hole',
#   'occlude',
#   'electronic_jamming',
#   'pile',
#   'kettle_of_fish',
#   'pickle',
#   'obstruct',
#   'close_up',
#   'throng',
#   'obturate',
#   'cram',
#   'impede'),
#  'foster': ('foster',
#   'surrogate',
#   'nurture',
#   'further',
#   'stephen_foster',
#   'stephen_collins_foster'),
#  'kitten': ('kitten', 'kitty'),
#  'getting': ('stupefy',
#   'have',
#   'begin',
#   'obtain',
#   'getting',
#   'cause',
#   'set_out',
#   'mother',
#   'become',
#   "get_under_one's_skin",
#   'nonplus',
#   'start',
#   'go',
#   'induce',
#   'fetch',
#   'gravel',
#   'start_out',
#   'beget',
#   'arrive',
#   'dumbfound',
#   'acquiring',
#   'sustain',
#   'contract',
#   'fix',
#   'find',
#   'suffer',
#   'arrest',
#   'incur',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'let',
#   'develop',
#   'drive',
#   'get_down',
#   'commence',
#   'puzzle',
#   'beat',
#   'grow',
#   'buzz_off',
#   'stick',
#   'flummox',
#   'bring',
#   'acquire',
#   'make',
#   'baffle',
#   'draw',
#   'stimulate',
#   'engender',
#   'scram',
#   'capture',
#   'produce',
#   'receive',
#   'pay_back',
#   'bugger_off',
#   'bring_forth',
#   'convey',
#   'pay_off',
#   'generate',
#   'fuck_off',
#   'mystify',
#   'take',
#   'get',
#   'come',
#   'vex',
#   'set_about',
#   'father',
#   'sire',
#   'aim',
#   'catch',
#   'pose',
#   'experience'),
#  'b': ('b',
#   'b-complex_vitamin',
#   'boron',
#   'group_b',
#   'b_complex',
#   'atomic_number_5',
#   'vitamin_b',
#   'bel',
#   'b_vitamin',
#   'bacillus',
#   'type_b',
#   'vitamin_b_complex',
#   'barn'),
#  'missed': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'pretermit',
#   'overleap',
#   'missed',
#   'neglect',
#   'escape',
#   'omit',
#   'lost',
#   'lose'),
#  'amazing': ('awful',
#   'stupefy',
#   'awesome',
#   'nonplus',
#   'awing',
#   'gravel',
#   'amazing',
#   'astonish',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'puzzle',
#   'beat',
#   'flummox',
#   'astound',
#   'baffle',
#   'awe-inspiring',
#   'astonishing',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'ready': ('gear_up',
#   'set',
#   'quick',
#   'fix',
#   'cook',
#   'make',
#   'prepare',
#   'set_up',
#   'ready'),
#  'school': ('shoal',
#   'educate',
#   'cultivate',
#   'schooling',
#   'schoolhouse',
#   'school',
#   'civilize',
#   'schooltime',
#   'school_day',
#   'train',
#   'civilise'),
#  'second': ('endorsement',
#   'sec',
#   'bit',
#   'indorse',
#   'mo',
#   'second_gear',
#   'instant',
#   'back',
#   'secondly',
#   'second_base',
#   '2d',
#   'second',
#   's',
#   'indorsement',
#   'irregular',
#   'endorse',
#   '2nd',
#   'moment',
#   'minute',
#   'arcsecond',
#   'secondment'),
#  'year': ('yr', 'twelvemonth', 'class', 'year'),
#  'next': ('side_by_side',
#   'following',
#   'adjacent',
#   'next',
#   'succeeding',
#   'future'),
#  'officially': ('officially', 'formally'),
#  'th': ('atomic_number_90', 'th', 'thorium', 'thursday'),
#  'friday': ('friday', 'fri'),
#  'yay': ('yay',),
#  'bonus': ('fillip', 'bonus', 'incentive'),
#  'drive': ('driving_force',
#   'force_back',
#   'thrust',
#   'cause',
#   'private_road',
#   'beat_back',
#   'repel',
#   'driveway',
#   'tug',
#   'labor',
#   'force',
#   'push',
#   'labour',
#   'ride',
#   'ram',
#   'drive',
#   'effort',
#   'driving',
#   'motor',
#   'push_back',
#   'repulse',
#   'movement',
#   'parkway',
#   'campaign',
#   'crusade',
#   'get',
#   'take',
#   'aim'),
#  'wale': ('wheal', 'strake', 'wale', 'welt', 'weal'),
#  'tonight': ('tonight', 'this_evening', 'this_night'),
#  'cuddle': ('nuzzle', 'draw_close', 'cuddle', 'snuggle', 'nest', 'nestle'),
#  'ride': ('tantalise',
#   'hinge_upon',
#   'depend_upon',
#   'rally',
#   'devolve_on',
#   'tantalize',
#   'ride',
#   'cod',
#   'taunt',
#   'drive',
#   'depend_on',
#   'turn_on',
#   'rag',
#   'hinge_on',
#   'razz',
#   'tease',
#   'twit',
#   'sit',
#   'mount',
#   'bait'),
#  'ok': ('alright',
#   'very_well',
#   'ok',
#   'all_right',
#   'fine',
#   'okeh',
#   'okey',
#   'okay',
#   'oklahoma',
#   'sooner_state',
#   'hunky-dory',
#   'o.k.'),
#  'shoe': ('skid', 'shoe', 'horseshoe', 'brake_shoe'),
#  'club': ('order',
#   'golf_club',
#   'golf-club',
#   'cabaret',
#   'baseball_club',
#   'lodge',
#   'club',
#   'gild',
#   'clubhouse',
#   'bludgeon',
#   'ball_club',
#   'night_club',
#   'nine',
#   'guild',
#   'society',
#   'nightspot',
#   'social_club',
#   'nightclub'),
#  'cool': ('aplomb',
#   'poise',
#   'coolheaded',
#   'cool',
#   'cool_off',
#   'chill',
#   'nerveless',
#   'sang-froid',
#   'cool_down',
#   'assuredness'),
#  'fun': ('merriment', 'playfulness', 'sport', 'play', 'fun'),
#  'except': ('leave_out',
#   'exclude',
#   'except',
#   'omit',
#   'demur',
#   'leave_off',
#   'take_out'),
#  'dance': ('saltation',
#   'terpsichore',
#   'dance',
#   'trip_the_light_fantastic',
#   'dancing',
#   'trip_the_light_fantastic_toe'),
#  'wit': ('mentality',
#   'wit',
#   'humour',
#   'learning_ability',
#   'wittiness',
#   'witticism',
#   'humor',
#   'card',
#   'brain',
#   'brainpower',
#   'mental_capacity',
#   'wag'),
#  'emmy': ('emmy',),
#  'latin': ('romance', 'latin'),
#  'help': ('facilitate',
#   'assist',
#   'assistant',
#   'supporter',
#   'service',
#   'help_oneself',
#   'helper',
#   'assistance',
#   'help',
#   'avail',
#   'serve',
#   'aid'),
#  'study': ('canvass',
#   'consider',
#   'hit_the_books',
#   'contemplate',
#   'read',
#   'canvas',
#   'work',
#   'survey',
#   'discipline',
#   'subject',
#   'subject_field',
#   'examine',
#   'written_report',
#   'bailiwick',
#   'study',
#   'report',
#   'sketch',
#   'subject_area',
#   'cogitation',
#   'analyse',
#   'take',
#   'field_of_study',
#   'meditate',
#   'analyze',
#   'learn',
#   'field'),
#  'aptitude': ('aptitude',),
#  'grad': ('graduate', 'alumna', 'grade', 'alumnus', 'grad', 'alum'),
#  'wish': ('wishing',
#   'like',
#   'bid',
#   'wish',
#   'regard',
#   'care',
#   'indirect_request',
#   'want',
#   'compliments',
#   'wish_well'),
#  'fly': ('wing',
#   'vaporize',
#   'vanish',
#   'rainfly',
#   'fly_front',
#   'fly_sheet',
#   'tent_flap',
#   'fly_ball',
#   'aviate',
#   'tent-fly',
#   'fell',
#   'flee',
#   'take_flight',
#   'fly',
#   'pilot'),
#  'someone': ('person', 'someone', 'individual', 'soul', 'mortal', 'somebody'),
#  'la': ('lanthanum',
#   'louisiana',
#   'lah',
#   'pelican_state',
#   'la',
#   'atomic_number_57'),
#  'lemon': ('gamboge',
#   'lemon_yellow',
#   'lemon',
#   'citrus_limon',
#   'lemon_tree',
#   'maize',
#   'stinker'),
#  'tree': ('tree',
#   'sir_herbert_beerbohm_tree',
#   'tree_diagram',
#   'shoetree',
#   'corner'),
#  'who': ('who', 'world_health_organization'),
#  'always': ('constantly',
#   'always',
#   "e'er",
#   'perpetually',
#   'forever',
#   'ever',
#   'invariably',
#   'incessantly'),
#  'oh': ('buckeye_state', 'oh', 'ohio'),
#  'yeah': ('yeah', 'yea'),
#  'interesting': ('interest',
#   'concern',
#   'matter_to',
#   'interesting',
#   'occupy',
#   'worry'),
#  'show': ('evidence',
#   'register',
#   'read',
#   'record',
#   'depict',
#   'display',
#   'prove',
#   'demo',
#   'appearance',
#   'render',
#   'testify',
#   'usher',
#   'indicate',
#   'show_up',
#   'picture',
#   'express',
#   'evince',
#   'demonstrate',
#   'shew',
#   'present',
#   'show',
#   'designate',
#   'bear_witness',
#   'exhibit',
#   'point',
#   'establish'),
#  'least': ('to_the_lowest_degree', 'least'),
#  'recap': ('retread', 'review', 'recapitulation', 'recapitulate', 'recap'),
#  'tomorrow': ('tomorrow',),
#  'man': ('isle_of_man',
#   'mankind',
#   'military_man',
#   'adult_male',
#   'humanity',
#   'human_beings',
#   'man',
#   'human',
#   'human_being',
#   'valet_de_chambre',
#   'human_race',
#   'humans',
#   'humankind',
#   'valet',
#   'piece',
#   'military_personnel',
#   'gentleman',
#   'homo',
#   'world',
#   'serviceman',
#   "gentleman's_gentleman"),
#  'come': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'ejaculate',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'cum',
#   'amount',
#   'semen',
#   'seed',
#   'total',
#   'follow',
#   'occur',
#   'seminal_fluid',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'everyday': ('casual',
#   'workaday',
#   'routine',
#   'mundane',
#   'everyday',
#   'unremarkable',
#   'quotidian',
#   'daily'),
#  'instead': ('rather', 'instead', 'alternatively', 'or_else'),
#  'like': ('comparable',
#   'the_likes_of',
#   'like',
#   'corresponding',
#   'wish',
#   'alike',
#   'ilk',
#   'same',
#   'care',
#   'similar',
#   'the_like'),
#  'flight': ('trajectory',
#   'fledge',
#   'flight_of_steps',
#   'flight',
#   'flying',
#   'escape',
#   'flight_of_stairs'),
#  'booked': ('engaged', 'book', 'booked', 'hold', 'reserve', 'set-aside'),
#  'plus': ('plus', 'positive', 'summation', 'asset', 'addition'),
#  'birthday': ('birthday', 'natal_day'),
#  'especially': ('especially', 'particularly', 'specially', 'peculiarly'),
#  'missing': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'lacking',
#   'wanting',
#   'pretermit',
#   'overleap',
#   'absent',
#   'neglect',
#   'escape',
#   'omit',
#   'lose',
#   'missing'),
#  'hear': ('pick_up',
#   'see',
#   'get_a_line',
#   'get_word',
#   'listen',
#   'take_heed',
#   'try',
#   'hear',
#   'discover',
#   'find_out',
#   'learn',
#   'get_wind'),
#  'degree': ('academic_degree',
#   'stage',
#   'level',
#   'grade',
#   'degree',
#   'point',
#   'arcdegree'),
#  'movie': ('pic',
#   'film',
#   'moving_picture',
#   'motion_picture',
#   'movie',
#   'flick',
#   'motion-picture_show',
#   'picture',
#   'moving-picture_show',
#   'picture_show'),
#  'guy': ('guy_wire',
#   'make_fun',
#   'guy_cable',
#   'blackguard',
#   'rib',
#   'laugh_at',
#   'cat',
#   'guy_rope',
#   'bozo',
#   'ridicule',
#   'guy',
#   'jest_at',
#   'hombre',
#   'roast',
#   'poke_fun'),
#  'economy': ('saving', 'thriftiness', 'economic_system', 'economy'),
#  'sorry': ('deplorable',
#   'distressing',
#   'drab',
#   'meritless',
#   'no-account',
#   'disconsolate',
#   'blue',
#   'lamentable',
#   'gloomy',
#   'no-good',
#   'no-count',
#   'dismal',
#   'sorry',
#   'dark',
#   'grim',
#   'dingy',
#   'drear',
#   'regretful',
#   'good-for-nothing',
#   'pitiful',
#   'dreary',
#   'good-for-naught',
#   'bad',
#   'sad'),
#  'another': ('some_other', 'another'),
#  'enjoy': ('love',
#   'revel',
#   'savor',
#   'relish',
#   'delight',
#   'savour',
#   'enjoy',
#   'bask'),
#  'came': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'amount',
#   'total',
#   'follow',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'fell': ('drop',
#   'light',
#   'devolve',
#   'decrease',
#   'savage',
#   'descend',
#   'strike_down',
#   'vicious',
#   'strike',
#   'accrue',
#   'come_down',
#   'hang',
#   'shine',
#   'fell',
#   'hide',
#   'barbarous',
#   'brutal',
#   'fall_down',
#   'return',
#   'precipitate',
#   'pass',
#   'settle',
#   'roughshod',
#   'diminish',
#   'go_down',
#   'fly',
#   'lessen',
#   'cruel',
#   'vanish',
#   'felled_seam',
#   'fall',
#   'come',
#   'cut_down',
#   'flow'),
#  'asleep': ('benumbed',
#   'asleep',
#   'numb',
#   'gone',
#   'at_rest',
#   'departed',
#   'at_peace',
#   'deceased'),
#  'friend': ('ally',
#   'admirer',
#   'booster',
#   'protagonist',
#   'supporter',
#   'friend',
#   'quaker',
#   'acquaintance',
#   'champion'),
#  'deeply': ('deep', 'profoundly', 'deeply'),
#  'moving': ('displace',
#   'act',
#   'prompt',
#   'propel',
#   'strike',
#   'go',
#   'move',
#   'actuate',
#   'proceed',
#   'moving',
#   'affect',
#   'motivate',
#   'be_active',
#   'incite',
#   'make_a_motion',
#   'impress',
#   'travel',
#   'run',
#   'locomote'),
#  'snow': ('coke',
#   'bamboozle',
#   'nose_candy',
#   'snow',
#   'snowfall',
#   'blow',
#   'lead_by_the_nose',
#   'baron_snow_of_leicester',
#   "pull_the_wool_over_someone's_eyes",
#   'charles_percy_snow',
#   'c',
#   'hoodwink',
#   'c._p._snow',
#   'play_false'),
#  'patrol': ('police', 'patrol'),
#  'stuck': ('sting',
#   'stupefy',
#   'stuck',
#   'stay_put',
#   'nonplus',
#   'stick_by',
#   'bind',
#   'lodge',
#   'wedge',
#   'adhere',
#   'gravel',
#   'stick_to',
#   'cohere',
#   'amaze',
#   'hold_fast',
#   'perplex',
#   'cling',
#   'bewilder',
#   'cleave',
#   'puzzle',
#   'stick_around',
#   'beat',
#   'stand_by',
#   'flummox',
#   'baffle',
#   'bond',
#   'stay',
#   'deposit',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'indoors': ('inside', 'indoors'),
#  'coming': ('advent',
#   'fare',
#   'approach',
#   'derive',
#   'add_up',
#   'descend',
#   'climax',
#   'do',
#   'arrive',
#   'make_out',
#   'coming',
#   'issue_forth',
#   'orgasm',
#   'come_in',
#   'hail',
#   'forthcoming',
#   'sexual_climax',
#   'get_along',
#   'amount',
#   'approaching',
#   'follow',
#   'total',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall',
#   'upcoming'),
#  'fresh': ('invigorated',
#   'novel',
#   'smart',
#   'refreshing',
#   'new',
#   'tonic',
#   'clean',
#   'fresh',
#   'impertinent',
#   'overbold',
#   'reinvigorated',
#   'refreshful',
#   'impudent',
#   'sassy',
#   'unused',
#   'freshly',
#   'saucy',
#   'newly',
#   'brisk',
#   'sweet',
#   'unfermented',
#   'wise',
#   'bracing',
#   'refreshed'),
#  'air': ('gentle_wind',
#   'send',
#   'ventilate',
#   'vent',
#   'air',
#   'strain',
#   'air_travel',
#   'tune',
#   'publicise',
#   'transmit',
#   'aura',
#   'broadcast',
#   'line',
#   'breeze',
#   'melodic_phrase',
#   'aerate',
#   'airwave',
#   'bare',
#   'beam',
#   'melody',
#   'air_out',
#   'atmosphere',
#   'publicize',
#   'zephyr',
#   'melodic_line',
#   'aviation'),
#  'excellent': ('excellent', 'first-class', 'fantabulous', 'splendid'),
#  'hope': ('hope',
#   'promise',
#   'bob_hope',
#   'trust',
#   'leslie_townes_hope',
#   'go_for',
#   'desire'),
#  'sunny': ('cheery', 'gay', 'sunny'),
#  'load': ('warhead',
#   'lode',
#   'burden',
#   'stretch',
#   'incumbrance',
#   'loading',
#   'lade',
#   'shipment',
#   'consignment',
#   'dilute',
#   'debase',
#   'cargo',
#   'encumbrance',
#   'payload',
#   'lading',
#   'charge',
#   'onus',
#   'freight',
#   'load_up',
#   'laden',
#   'load',
#   'adulterate'),
#  'sun': ('solarize',
#   'insolate',
#   'sunlight',
#   'solarise',
#   'dominicus',
#   'sunbathe',
#   "lord's_day",
#   'sun',
#   'sunday',
#   'sunshine'),
#  'hurrah': ('hurrah', 'hooray'),
#  'babe': ('baby', 'infant', 'sister', 'babe'),
#  'thank': ('give_thanks', 'thank'),
#  'making': ('create',
#   'shit',
#   'fashioning',
#   'score',
#   'lay_down',
#   'have',
#   'take_a_shit',
#   'pretend',
#   'cause',
#   'name',
#   'gain',
#   'micturate',
#   'piddle',
#   'pee',
#   'make_water',
#   'wee',
#   'prepare',
#   'qualification',
#   'throw',
#   'work',
#   'wee-wee',
#   'do',
#   'take_in',
#   'induce',
#   'earn',
#   'pass_water',
#   'constitute',
#   'spend_a_penny',
#   'fix',
#   'pee-pee',
#   'piss',
#   'give',
#   'puddle',
#   'ca-ca',
#   'devising',
#   'making',
#   'seduce',
#   'make_up',
#   'take_a_crap',
#   'form',
#   'get_to',
#   'arrive_at',
#   'clear',
#   'hit',
#   'stool',
#   'make_believe',
#   'make',
#   'construct',
#   'draw',
#   'stimulate',
#   'urinate',
#   'progress_to',
#   'build',
#   'realize',
#   'produce',
#   'ready',
#   'relieve_oneself',
#   'take_a_leak',
#   'nominate',
#   'hold',
#   'reach',
#   'attain',
#   'defecate',
#   'bring_in',
#   'cook',
#   'take',
#   'get',
#   'crap',
#   'realise',
#   'pull_in',
#   'establish'),
#  'happen': ('encounter',
#   'occur',
#   'bump',
#   'happen',
#   'go_on',
#   'materialize',
#   'bechance',
#   'find',
#   'befall',
#   'pass',
#   'take_place',
#   'hap',
#   'pass_off',
#   'fall_out',
#   'come_about',
#   'materialise',
#   'chance'),
#  'lady': ('madam',
#   'peeress',
#   'noblewoman',
#   'lady',
#   "ma'am",
#   'gentlewoman',
#   'dame'),
#  'time': ('metre',
#   'clip',
#   'fourth_dimension',
#   'meter',
#   'sentence',
#   'time',
#   'clock',
#   'clock_time',
#   'prison_term'),
#  'went': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'move',
#   'function',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'family': ('kinfolk',
#   'house',
#   'category',
#   'phratry',
#   'menage',
#   'kin',
#   'family_unit',
#   'kinsperson',
#   'family_line',
#   'mob',
#   'home',
#   'folk',
#   'class',
#   'household',
#   'crime_syndicate',
#   'fellowship',
#   'family',
#   'kinsfolk',
#   'sept',
#   'syndicate'),
#  'party': ('political_party', 'company', 'party'),
#  'rocked': ('rock', 'sway', 'shake'),
#  'tuesday': ('tues', 'tuesday'),
#  'id': ('idaho', 'id', 'gem_state', 'i.d.'),
#  'really': ('truly',
#   'genuinely',
#   'in_truth',
#   'rattling',
#   'really',
#   'very',
#   'real',
#   'actually'),
#  'machine': ('motorcar',
#   'machine',
#   'simple_machine',
#   'automobile',
#   'car',
#   'auto',
#   'political_machine'),
#  'twitter': ('chirrup', 'chitter', 'twitter'),
#  'back': ('cover',
#   'vertebral_column',
#   'backbone',
#   'support',
#   'indorse',
#   'binding',
#   'plump_for',
#   'gage',
#   'rachis',
#   'backward',
#   'backrest',
#   'spinal_column',
#   'back',
#   'stake',
#   'second',
#   'rearward',
#   'game',
#   'backwards',
#   'spine',
#   'endorse',
#   'dorsum',
#   'book_binding',
#   'punt',
#   'back_up',
#   'hinder',
#   'rearwards',
#   'plunk_for',
#   'hind',
#   'bet_on',
#   'rear'),
#  'watching': ('observe',
#   'ascertain',
#   'keep_an_eye_on',
#   'observation',
#   'watch',
#   'find_out',
#   'take_in',
#   'look_out',
#   'look_on',
#   'see',
#   'determine',
#   'observance',
#   'follow',
#   'view',
#   'watching',
#   'watch_over',
#   'watch_out',
#   'learn',
#   'check',
#   'catch'),
#  'jay': ('john_jay', 'jay'),
#  'nd': ('neodymium',
#   'atomic_number_60',
#   'peace_garden_state',
#   'north_dakota',
#   'nd'),
#  'gone': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'at_rest',
#   'departed',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'bypast',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'gone',
#   'move',
#   'function',
#   'run_low',
#   'done_for',
#   'proceed',
#   'break_down',
#   'decease',
#   'at_peace',
#   'sound',
#   'kaput',
#   'drop_dead',
#   'hold_up',
#   'asleep',
#   'belong',
#   'plump',
#   'blend_in',
#   'bygone',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'deceased',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'foregone',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'four': ('four',
#   'quadruplet',
#   'foursome',
#   'four-spot',
#   '4',
#   'quatern',
#   'quaternity',
#   'quartet',
#   'iv',
#   'little_joe',
#   'quaternion',
#   'tetrad',
#   'quaternary'),
#  'years': ('age',
#   'years',
#   'geezerhood',
#   'yr',
#   'class',
#   'year',
#   'twelvemonth',
#   'eld',
#   'days',
#   'long_time',
#   'old_age'),
#  'biggest': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'headache': ('head_ache',
#   'headache',
#   'vexation',
#   'concern',
#   'cephalalgia',
#   'worry'),
#  'washed': ('moisten',
#   'wash_off',
#   'lap',
#   'washed',
#   'wash',
#   'rinse',
#   'dampen',
#   'wash_away',
#   'lave',
#   'water-washed',
#   'wash_out',
#   'launder'),
#  'hair': ('whisker',
#   'hair',
#   'tomentum',
#   'pilus',
#   'haircloth',
#   "hair's-breadth",
#   'hairsbreadth',
#   'fuzz'),
#  'mum': ('ma',
#   "florist's_chrysanthemum",
#   'mum',
#   'mom',
#   'mummy',
#   'mamma',
#   "florists'_chrysanthemum",
#   'mammy',
#   'dendranthema_grandifloruom',
#   'chrysanthemum_morifolium',
#   'silent',
#   'momma',
#   'mommy',
#   'mama'),
#  'shampoo': ('shampoo',),
#  'gross': ('vulgar',
#   'rank',
#   'stark',
#   'receipts',
#   'glaring',
#   'sodding',
#   'megascopic',
#   'arrant',
#   '144',
#   'unadulterated',
#   'staring',
#   'complete',
#   'utter',
#   'gross',
#   'revenue',
#   'perfect',
#   'flagrant',
#   'double-dyed',
#   'egregious',
#   'pure',
#   'porcine',
#   'consummate',
#   'crude',
#   'thoroughgoing',
#   'earthy',
#   'crying',
#   'everlasting'),
#  'way': ('fashion',
#   'path',
#   'room',
#   'manner',
#   'way',
#   'style',
#   'way_of_life',
#   'mode',
#   'direction',
#   'right_smart',
#   'elbow_room',
#   'means',
#   'agency'),
#  'heading': ('header',
#   'drift',
#   'bearing',
#   'heading',
#   'head',
#   'maneuver',
#   'lead',
#   'head_up',
#   'manoeuver',
#   'steer',
#   'guide',
#   'channelize',
#   'gallery',
#   'channelise',
#   'point',
#   'aim',
#   'manoeuvre',
#   'direct'),
#  'buy': ('bribe',
#   'bargain',
#   'steal',
#   "grease_one's_palms",
#   'purchase',
#   'buy',
#   'corrupt'),
#  'needed': ('needed',
#   'call_for',
#   'involve',
#   'postulate',
#   'requisite',
#   'demand',
#   'required',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'needful',
#   'need',
#   'require'),
#  'bottle': ('bottleful', 'feeding_bottle', 'bottle', 'nursing_bottle'),
#  'drink': ('boozing',
#   'wassail',
#   'tope',
#   'drinkable',
#   'potable',
#   'imbibe',
#   'swallow',
#   'fuddle',
#   'booze',
#   'drink_in',
#   'pledge',
#   'drunkenness',
#   'crapulence',
#   'drinking',
#   'drink',
#   'deglutition',
#   'toast',
#   'salute',
#   'beverage'),
#  'wallet': ('billfold', 'notecase', 'wallet', 'pocketbook'),
#  'faking': ("talk_through_one's_hat",
#   'manipulate',
#   'fudge',
#   'fake',
#   'cook',
#   'misrepresent',
#   'falsify',
#   'forge',
#   'wangle',
#   'bullshit',
#   'bull',
#   'counterfeit'),
#  'kid': ('pull_the_leg_of',
#   'minor',
#   'kid',
#   'kyd',
#   'tike',
#   'child',
#   'nipper',
#   'banter',
#   'jolly',
#   'shaver',
#   'nestling',
#   'fry',
#   'tiddler',
#   'josh',
#   'chaff',
#   'kidskin',
#   'thomas_kid',
#   'thomas_kyd',
#   'youngster',
#   'small_fry',
#   'tyke'),
#  'grade': ('order',
#   'score',
#   'rank',
#   'rate',
#   'place',
#   'form',
#   'range',
#   'ground_level',
#   'level',
#   'course',
#   'grade',
#   'class',
#   'gradation',
#   'tier',
#   'mark',
#   'degree',
#   'grad'),
#  'spelling': ('spell', 'write', 'spell_out', 'spelling', 'import'),
#  'bee': ('bee',),
#  'trailing': ('track',
#   'shack',
#   'chase',
#   'drop_back',
#   'give_chase',
#   'tail',
#   'tracking',
#   'drop_behind',
# ...
#   'jam',
#   'mob',
#   'backpack'),
#  'canterbury': ('canterbury',),
#  'fab': ('fab', 'fabulous'),
#  'colleague': ('fellow_worker',
#   'confrere',
#   'workfellow',
#   'fellow',
#   'co-worker',
#   'colleague'),
#  'bunch': ('bundle',
#   'bunch',
#   'crew',
#   'clump',
#   'bunch_together',
#   'crowd',
#   'clustering',
#   'cluster',
#   'caboodle',
#   'bunch_up',
#   'lot',
#   'gang'),
#  'moment': ('moment',
#   'instant',
#   'bit',
#   'minute',
#   'mo',
#   'present_moment',
#   'import',
#   'second',
#   'consequence',
#   'here_and_now'),
#  'mama': ('ma',
#   'mum',
#   'mom',
#   'mummy',
#   'mamma',
#   'mammy',
#   'momma',
#   'mommy',
#   'mama'),
#  'calling': ('ring',
#   'foretell',
#   'shout',
#   'forebode',
#   'name',
#   'career',
#   'squall',
#   'address',
#   'calling',
#   'promise',
#   'prognosticate',
#   'anticipate',
#   'holler',
#   'hollo',
#   'scream',
#   'send_for',
#   'call_up',
#   'vocation',
#   'call_in',
#   'visit',
#   'call_off',
#   'cry',
#   'predict',
#   'phone',
#   'bid',
#   'call',
#   'shout_out',
#   'telephone',
#   'yell'),
#  'seeing': ('seeing',
#   'visualise',
#   'consider',
#   'encounter',
#   'ensure',
#   'attend',
#   'get_a_line',
#   'understand',
#   'regard',
#   'ascertain',
#   'get_word',
#   'go_through',
#   'escort',
#   'check',
#   'see_to_it',
#   'watch',
#   'find_out',
#   'control',
#   'pick_up',
#   'take_in',
#   'project',
#   'come_across',
#   'visualize',
#   'look',
#   'examine',
#   'find',
#   'run_across',
#   'picture',
#   'catch',
#   'reckon',
#   'envision',
#   'insure',
#   'see',
#   'meet',
#   'run_into',
#   'determine',
#   'visit',
#   'assure',
#   'date',
#   'image',
#   'beholding',
#   'get_wind',
#   'eyesight',
#   'realize',
#   'witness',
#   'go_steady',
#   'view',
#   'visual_perception',
#   'construe',
#   'figure',
#   'take_care',
#   'interpret',
#   'go_out',
#   'sightedness',
#   'hear',
#   'discover',
#   'realise',
#   'fancy',
#   'learn',
#   'experience'),
#  'coursework': ('coursework',),
#  'licking': ('bat',
#   'drub',
#   'work',
#   'figure_out',
#   'lap',
#   'solve',
#   'puzzle_out',
#   'trouncing',
#   'cream',
#   'drubbing',
#   'thrash',
#   'defeat',
#   'lacing',
#   'lap_up',
#   'beating',
#   'licking',
#   'work_out',
#   'whacking',
#   'thrashing',
#   'clobber',
#   'lick'),
#  'chocolate': ('hot_chocolate',
#   'burnt_umber',
#   'chocolate',
#   'drinking_chocolate',
#   'coffee',
#   'cocoa',
#   'deep_brown',
#   'umber'),
#  'crumb': ('stinker',
#   'rat',
#   'skunk',
#   'git',
#   'rotter',
#   'scum_bag',
#   'stinkpot',
#   'so-and-so',
#   'bum',
#   'lowlife',
#   'crumb',
#   'dirty_dog',
#   'puke'),
#  'twirl': ('whirl',
#   'swirl',
#   'spin',
#   'twisting',
#   'twiddle',
#   'kink',
#   'birl',
#   'twist',
#   'twirl'),
#  'wrapper': ('wrapper',
#   'neglige',
#   'housecoat',
#   'peignoir',
#   'negligee',
#   'wrap',
#   'wrapping'),
#  'km': ('kilometer', 'klick', 'kilometre', 'km'),
#  'traffic': ('traffic', 'dealings'),
#  'lap': ('swosh',
#   'swoosh',
#   'overlap',
#   'lap',
#   'swish',
#   'lap_covering',
#   'lap_up',
#   'lick',
#   'wash',
#   'circuit',
#   'circle',
#   'lave'),
#  'sale': ('sales_event', 'sales_agreement', 'sale', 'cut-rate_sale'),
#  'speak': ('address',
#   'speak',
#   'talk',
#   'verbalise',
#   'verbalize',
#   'mouth',
#   'utter'),
#  'convince': ('convert', 'convince', 'win_over'),
#  'diamond': ('baseball_field',
#   'infield',
#   'baseball_diamond',
#   'rhomb',
#   'ball_field',
#   'rhombus',
#   'adamant',
#   'diamond'),
#  'sub': ('italian_sandwich',
#   'submarine_sandwich',
#   'cuban_sandwich',
#   'substitute',
#   'sub',
#   'zep',
#   'grinder',
#   'u-boat',
#   'wedge',
#   'hero',
#   'hoagy',
#   'pigboat',
#   'submarine',
#   'bomber',
#   'torpedo',
#   'poor_boy',
#   'fill_in',
#   'hero_sandwich',
#   'stand_in',
#   'hoagie'),
#  'whistling': ('whistle', 'whistling', 'sing'),
#  'lame': ('halting',
#   'cripple',
#   'crippled',
#   'gimpy',
#   'square',
#   'feeble',
#   'lame',
#   'halt',
#   'game'),
#  'spent': ('spent',
#   'worn_out',
#   'played_out',
#   'drop',
#   'spend',
#   'dog-tired',
#   'expend',
#   'worn-out',
#   'pass',
#   'washed-out',
#   'fatigued',
#   'fagged',
#   'exhausted'),
#  'sitting': ('session',
#   'posing',
#   'seance',
#   'sit_down',
#   'ride',
#   'sitting',
#   'seated',
#   'model',
#   'sit_around',
#   'seat',
#   'posture',
#   'baby-sit',
#   'sit',
#   'pose'),
#  'picnic': ('pushover',
#   'walkover',
#   'cinch',
#   'snap',
#   'field_day',
#   'outing',
#   'picnic',
#   'piece_of_cake',
#   "child's_play",
#   'breeze',
#   'duck_soup'),
#  'ice': ('crank',
#   'ice_rink',
#   'glass',
#   'chicken_feed',
#   'ice',
#   'deoxyephedrine',
#   'methedrine',
#   'frost',
#   'frosting',
#   'frappe',
#   'sparkler',
#   'icing',
#   'water_ice',
#   'internal-combustion_engine',
#   'ice-skating_rink',
#   'methamphetamine_hydrochloride',
#   'trash',
#   'shabu',
#   'chalk',
#   'meth',
#   'methamphetamine'),
#  'cream': ('skim_off',
#   'bat',
#   'ointment',
#   'emollient',
#   'clobber',
#   'pick',
#   'skim',
#   'lick',
#   'cream',
#   'drub',
#   'cream_off',
#   'thrash'),
#  'win': ('come_through',
#   'get_ahead',
#   'win',
#   'make_headway',
#   'profits',
#   'bring_home_the_bacon',
#   'deliver_the_goods',
#   'gain',
#   'winnings',
#   'acquire',
#   'gain_ground',
#   'succeed',
#   'pull_ahead',
#   'advance'),
#  'food': ('food',
#   'food_for_thought',
#   'solid_food',
#   'nutrient',
#   'intellectual_nourishment'),
#  'roach': ('r-2',
#   'forget_me_drug',
#   'rutilus_rutilus',
#   'rophy',
#   'cockroach',
#   'roach',
#   'roofy',
#   'mexican_valium',
#   'rope',
#   'circle'),
#  'apartment': ('flat', 'apartment'),
#  'shower': ('rain_shower',
#   'exhibitor',
#   'lavish',
#   'exhibitioner',
#   'cascade',
#   'shower',
#   'shower_down',
#   'shower_bath'),
#  'got': ('stupefy',
#   'have',
#   'begin',
#   'obtain',
#   'cause',
#   'set_out',
#   'mother',
#   'become',
#   "get_under_one's_skin",
#   'nonplus',
#   'start',
#   'go',
#   'induce',
#   'fetch',
#   'gravel',
#   'start_out',
#   'beget',
#   'arrive',
#   'dumbfound',
#   'sustain',
#   'contract',
#   'fix',
#   'find',
#   'suffer',
#   'arrest',
#   'incur',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'let',
#   'develop',
#   'drive',
#   'get_down',
#   'commence',
#   'puzzle',
#   'beat',
#   'grow',
#   'buzz_off',
#   'stick',
#   'flummox',
#   'bring',
#   'acquire',
#   'make',
#   'baffle',
#   'draw',
#   'stimulate',
#   'engender',
#   'scram',
#   'capture',
#   'produce',
#   'receive',
#   'pay_back',
#   'bugger_off',
#   'bring_forth',
#   'convey',
#   'pay_off',
#   'generate',
#   'fuck_off',
#   'mystify',
#   'take',
#   'get',
#   'come',
#   'vex',
#   'set_about',
#   'father',
#   'sire',
#   'aim',
#   'catch',
#   'pose',
#   'experience'),
#  'ta': ('atomic_number_73', 'ta', 'tantalum'),
#  'couple': ('mate',
#   'partner_off',
#   'dyad',
#   'copulate',
#   'twin',
#   'duo',
#   'mates',
#   'duet',
#   'twain',
#   'twosome',
#   'yoke',
#   'couple_on',
#   'pair_off',
#   'duad',
#   'couplet',
#   'span',
#   'brace',
#   'couple',
#   'match',
#   'distich',
#   'pair',
#   'couple_up'),
#  'esther': ('esther', 'book_of_esther'),
#  'ps': ('p', 'phosphorus', 'atomic_number_15', 'ps', 'postscript'),
#  'radio': ('wireless',
#   'radio',
#   'radio_receiver',
#   'tuner',
#   'radiocommunication',
#   'radio_set',
#   'receiving_set'),
#  'disney': ('disney', 'walter_elias_disney', 'walt_disney'),
#  'latest': ('belated',
#   'former',
#   'modish',
#   'late',
#   'in_vogue',
#   'a_la_mode',
#   'tardy',
#   'recent',
#   'latest',
#   'in_style',
#   'previous',
#   'later',
#   'up-to-the-minute'),
#  'run': ('head_for_the_hills',
#   'run_away',
#   'consort',
#   'run_for',
#   'extend',
#   'tend',
#   'ply',
#   'course',
#   'incline',
#   'break_away',
#   'play',
#   'discharge',
#   'track_down',
#   'melt',
#   'ladder',
#   'lam',
#   'work',
#   'execute',
#   'fly_the_coop',
#   'political_campaign',
#   'go',
#   'bleed',
#   'bunk',
#   'range',
#   'operate',
#   'be_given',
#   'melt_down',
#   'rill',
#   'die_hard',
#   'hunt',
#   'move',
#   'function',
#   'runnel',
#   'persist',
#   'escape',
#   'scarper',
#   'test',
#   'rivulet',
#   'flow',
#   'scat',
#   'endure',
#   'tally',
#   'pass',
#   'running_play',
#   'prevail',
#   'draw',
#   'race',
#   'streamlet',
#   'running_game',
#   'lean',
#   'guide',
#   'black_market',
#   'ravel',
#   'hunt_down',
#   'turn_tail',
#   'footrace',
#   'hightail_it',
#   'take_to_the_woods',
#   'outpouring',
#   'lead',
#   'foot_race',
#   'trial',
#   'running',
#   'carry',
#   'campaign',
#   'run',
#   'unravel',
#   'feed',
#   'streak'),
#  'beaumont': ('francis_beaumont', 'beaumont', 'william_beaumont'),
#  'pretty': ('middling',
#   'passably',
#   'reasonably',
#   'jolly',
#   'moderately',
#   'fairly',
#   'somewhat',
#   'pretty'),
#  'overdid': ('exaggerate', 'overdo'),
#  'sparkling': ('effervesce',
#   'coruscate',
#   'scintillate',
#   'froth',
#   'sparkling',
#   'scintillation',
#   'spark',
#   'sparkle',
#   'effervescent',
#   'form_bubbles',
#   'fizz',
#   'foam',
#   'twinkle'),
#  'tea': ('camellia_sinensis', 'tea', 'tea_leaf', 'afternoon_tea', 'teatime'),
#  'receive': ('encounter',
#   'pick_up',
#   'take_in',
#   'meet',
#   'receive',
#   'have',
#   'obtain',
#   'find',
#   'welcome',
#   'get',
#   'incur',
#   'invite',
#   'experience'),
#  'viva': ('oral_exam', 'viva_voce', 'oral', 'viva', 'oral_examination'),
#  'broadcast': ('send',
#   'disseminate',
#   'broadcast',
#   'program',
#   'diffuse',
#   'distribute',
#   'air',
#   'beam',
#   'circularise',
#   'disperse',
#   'pass_around',
#   'circulate',
#   'spread',
#   'propagate',
#   'programme',
#   'circularize',
#   'transmit'),
#  'online': ('online', 'on-line'),
#  'beta': ('beta', 'genus_beta'),
#  'madden': ('madden', 'craze'),
#  'recollecting': ('call_back',
#   'recollect',
#   'call_up',
#   'retrieve',
#   'recall',
#   'think',
#   'remember'),
#  'jog': ('trot',
#   'ramble_on',
#   'jog',
#   'clip',
#   'nudge',
#   'square_up',
#   'ramble',
#   'lope',
#   'even_up'),
#  'perfect': ('consummate',
#   'gross',
#   'perfective_tense',
#   'staring',
#   'arrant',
#   'thoroughgoing',
#   'perfect',
#   'perfect_tense',
#   'stark',
#   'everlasting',
#   'double-dyed',
#   'unadulterated',
#   'pure',
#   'complete',
#   'sodding',
#   'utter',
#   'hone',
#   'perfective'),
#  'type': ('case', 'type', 'typecast', 'typewrite', 'eccentric', 'character'),
#  'hanging': ('advert',
#   'hang',
#   'attend',
#   'dangling',
#   'give_ear',
#   'pay_heed',
#   'string_up',
#   'hang_up',
#   'fall',
#   'wall_hanging',
#   'suspension',
#   'hanging',
#   'cling',
#   'flow'),
#  'vehicle': ('fomite', 'vehicle'),
#  'mental': ('genial', 'mental'),
#  'noise': ('make_noise',
#   'stochasticity',
#   'resound',
#   'dissonance',
#   'haphazardness',
#   'randomness',
#   'interference',
#   'disturbance',
#   'racket',
#   'noise'),
#  'mile': ('sea_mile',
#   'geographical_mile',
#   'mi',
#   'mile',
#   'land_mile',
#   'roman_mile',
#   'swedish_mile',
#   'international_mile',
#   'statute_mile',
#   'naut_mi',
#   'air_mile',
#   'admiralty_mile',
#   'mil',
#   'stat_mi',
#   'knot',
#   'international_nautical_mile',
#   'nautical_mile'),
#  'post': ('send',
#   'place',
#   'office',
#   'billet',
#   'mail_service',
#   'stake',
#   'spot',
#   'post',
#   'wiley_post',
#   'emily_price_post',
#   'military_post',
#   'emily_post',
#   'postal_service',
#   'position',
#   'charles_william_post',
#   'c._w._post',
#   'berth',
#   'mail',
#   'situation',
#   'brand',
#   'carry',
#   'put_up',
#   'station'),
#  'blue': ('low-spirited',
#   'dispirited',
#   'blue_sky',
#   'naughty',
#   'aristocratic',
#   'gamey',
#   'blue-blooded',
#   'profane',
#   'gamy',
#   'wild_blue_yonder',
#   'bluish',
#   'drab',
#   'down_in_the_mouth',
#   'blue_devil',
#   'down',
#   'aristocratical',
#   'disconsolate',
#   'blue',
#   'gloomy',
#   'low',
#   'downcast',
#   'amytal',
#   'depressed',
#   'dismal',
#   'spicy',
#   'juicy',
#   'amobarbital_sodium',
#   'risque',
#   'puritanical',
#   'downhearted',
#   'gentle',
#   'blasphemous',
#   'bluing',
#   'blueish',
#   'sorry',
#   'dark',
#   'grim',
#   'blue_air',
#   'dingy',
#   'drear',
#   'patrician',
#   'puritanic',
#   'blueness',
#   'blue_angel',
#   'blueing',
#   'dreary',
#   'racy'),
#  'bb': ('bb', 'bb_shot'),
#  'esr': ('electron_paramagnetic_resonance',
#   'sedimentation_rate',
#   'sed_rate',
#   'esr',
#   'erythrocyte_sedimentation_rate',
#   'electron_spin_resonance'),
#  'click': ('cluck',
#   'get_through',
#   'tick',
#   'dog',
#   'click',
#   'sink_in',
#   'clack',
#   'dawn',
#   'fall_into_place',
#   'snap',
#   'chink',
#   'get_across',
#   'penetrate',
#   'pawl',
#   'come_home',
#   'chatter',
#   'clink',
#   'suction_stop',
#   'mouse_click',
#   'flick',
#   'detent'),
#  'cousin': ('full_cousin', 'cousin', 'first_cousin', 'cousin-german'),
#  'married': ('tie',
#   'marry',
#   'conjoin',
#   'marital',
#   'married',
#   'get_hitched_with',
#   'get_married',
#   'splice',
#   'espouse',
#   'hook_up_with',
#   'wed',
#   'matrimonial'),
#  'flag': ('signal_flag',
#   'sword_lily',
#   'flag',
#   'pin',
#   'droop',
#   'fleur-de-lis',
#   'iris',
#   'ease_up',
#   'ease_off',
#   'swag',
#   'slacken_off',
#   'sag',
#   'flagstone',
#   'masthead'),
#  'bored': ('tire', 'bore', 'drill', 'blase', 'bored', 'world-weary'),
#  'nobody': ('cypher', 'nobody', 'cipher', 'nonentity'),
#  'senior': ('fourth-year', 'elder', 'older', 'aged', 'elderly', 'senior'),
#  'however': ('notwithstanding',
#   'nonetheless',
#   'yet',
#   'still',
#   'all_the_same',
#   'even_so',
#   'withal',
#   'nevertheless',
#   'however'),
#  'tickling': ('titillate',
#   'tickling',
#   'titillation',
#   'thrill',
#   'vibrate',
#   'tingling',
#   'vellicate',
#   'titillating',
#   'tickle'),
#  'floor': ('story',
#   'knock_down',
#   'take_aback',
#   'ball_over',
#   'level',
#   'flooring',
#   'storey',
#   'blow_out_of_the_water',
#   'dump',
#   'deck',
#   'trading_floor',
#   'shock',
#   'coldcock',
#   'floor',
#   'base'),
#  'giggling': ('titter', 'giggle'),
#  'worth': ('worth', 'deserving', 'charles_frederick_worth'),
#  'asked': ('call_for',
#   'involve',
#   'inquire',
#   'enquire',
#   'postulate',
#   'demand',
#   'take',
#   'necessitate',
#   'ask',
#   'need',
#   'require',
#   'expect'),
#  'pub': ('gin_mill', 'public_house', 'pothouse', 'pub', 'saloon', 'taphouse'),
#  'boiling': ('boiling',
#   'moil',
#   'stewing',
#   'seethe',
#   'boil',
#   'churn',
#   'roil',
#   'simmering'),
#  'attempting': ('essay',
#   'assay',
#   'undertake',
#   'attempt',
#   'set_about',
#   'seek',
#   'try'),
#  'played': ('encounter',
#   'bet',
#   'act',
#   'diddle',
#   'wager',
#   'play',
#   'trifle',
#   'work',
#   'act_as',
#   'spiel',
#   'played',
#   'flirt',
#   'wreak',
#   'meet',
#   'dally',
#   'playact',
#   'take_on',
#   'fiddle',
#   'roleplay',
#   'bring',
#   'toy',
#   'represent',
#   'run',
#   'make_for',
#   'recreate'),
#  'stoked': ('stoke',),
#  'member': ('penis',
#   'phallus',
#   'fellow_member',
#   'extremity',
#   'appendage',
#   'member'),
#  'cf': ('atomic_number_98',
#   'cystic_fibrosis',
#   'californium',
#   'pancreatic_fibrosis',
#   'cf.',
#   'mucoviscidosis',
#   'cf',
#   'fibrocystic_disease_of_the_pancreas'),
#  'computer': ('figurer',
#   'information_processing_system',
#   'computing_machine',
#   'calculator',
#   'data_processor',
#   'estimator',
#   'computer',
#   'computing_device',
#   'electronic_computer',
#   'reckoner'),
#  'immediately': ('now',
#   'instantly',
#   'immediately',
#   'forthwith',
#   'straightaway',
#   'like_a_shot',
#   'straight_off',
#   'at_once',
#   'directly',
#   'right_away'),
#  'waiting': ('ready_and_waiting',
#   'look',
#   'wait',
#   'hold_off',
#   'waitress',
#   'waiting',
#   'hold_back',
#   'expect',
#   'await'),
#  'teary': ('teary-eyed', 'teary', 'watery-eyed'),
#  'fucking': ('bonk',
#   'roll_in_the_hay',
#   'have_sex',
#   'hump',
#   'get_it_on',
#   'nooky',
#   'be_intimate',
#   'love',
#   'screw',
#   'piece_of_tail',
#   'shag',
#   'have_it_away',
#   'piece_of_ass',
#   'sleep_with',
#   'get_laid',
#   'bang',
#   'make_out',
#   'blinking',
#   'jazz',
#   'ass',
#   'fucking',
#   'bed',
#   'have_it_off',
#   'have_a_go_at_it',
#   'bally',
#   'do_it',
#   'sleep_together',
#   'eff',
#   'nookie',
#   'have_intercourse',
#   'shtup',
#   'bloody',
#   'blooming',
#   'make_love',
#   'lie_with',
#   'know',
#   'crashing',
#   'fuck',
#   'screwing',
#   'flaming'),
#  'sit': ('sit_down',
#   'ride',
#   'model',
#   'sit_around',
#   'seat',
#   'posture',
#   'baby-sit',
#   'sit',
#   'pose'),
#  'brave': ('intrepid',
#   'brave_out',
#   'gay',
#   'brave',
#   'dauntless',
#   'courageous',
#   'unfearing',
#   'endure',
#   'fearless',
#   'weather',
#   'braw',
#   'hardy',
#   'audacious'),
#  'friendly': ('well-disposed', 'favorable', 'friendly'),
#  'gm': ('gm', 'g', 'gramme', 'gram'),
#  'pt': ('atomic_number_78', 'platinum', 'pt'),
#  'offensively': ('obnoxiously', 'objectionably', 'offensively'),
#  'timing': ('clock', 'time', 'timing'),
#  'israel': ('yisrael', 'israel', 'zion', 'sion', 'state_of_israel'),
#  'player': ('player',
#   'thespian',
#   'instrumentalist',
#   'musician',
#   'actor',
#   'histrion',
#   'participant',
#   'role_player'),
#  'teach': ('instruct',
#   'edward_teach',
#   'blackbeard',
#   'teach',
#   'thatch',
#   'edward_thatch',
#   'learn'),
#  'blindly': ('blindly',),
#  ...}

# %%
import collections
value_occurrences = collections.Counter(synonym_dict.values())

filtered_synonym = {key: value for key, value in synonym_dict.items() if value_occurrences[value] == 1}

# %%
filtered_synonym
# Out:
# {'much': ('a_lot',
#   'much',
#   'often',
#   'lots',
#   'a_great_deal',
#   'very_much',
#   'a_good_deal',
#   'practically'),
#  'better': ('honest',
#   'advantageously',
#   'break',
#   'well',
#   'improve',
#   'secure',
#   'good',
#   'adept',
#   'considerably',
#   'dear',
#   'amend',
#   'practiced',
#   'intimately',
#   'near',
#   'ameliorate',
#   'in_effect',
#   'wagerer',
#   'right',
#   'best',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'meliorate',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'substantially',
#   'easily',
#   'skilful',
#   'safe',
#   'skillful',
#   'bettor',
#   'beneficial',
#   'better',
#   'effective',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'comfortably',
#   'dependable',
#   'undecomposed',
#   'ripe',
#   'punter'),
#  'far': ('far',
#   'alir',
#   'interahamwe',
#   'former_armed_forces',
#   'army_for_the_liberation_of_rwanda'),
#  'still': ('nonetheless',
#   'tranquillise',
#   'relieve',
#   'soundless',
#   'placid',
#   'even',
#   'yet',
#   'allay',
#   'quiet',
#   'ease',
#   'hush',
#   'hush_up',
#   'distillery',
#   'static',
#   'inactive',
#   'quieten',
#   'withal',
#   'silent',
#   'silence',
#   'motionless',
#   'tranquil',
#   'tranquilize',
#   'shut_up',
#   'noneffervescent',
#   'still',
#   'all_the_same',
#   'even_so',
#   'stock-still',
#   'tranquillize',
#   'calm_down',
#   'notwithstanding',
#   'unruffled',
#   'smooth',
#   'stillness',
#   'lull',
#   'nevertheless',
#   'calm',
#   'however'),
#  'quite': ('quite_a', 'rather', 'quite', 'quite_an'),
#  'early': ('betimes',
#   'too_soon',
#   'early_on',
#   'ahead_of_time',
#   'early',
#   'former',
#   'other'),
#  'last': ('utmost',
#   'lowest',
#   'end',
#   'live',
#   'net',
#   'stopping_point',
#   'terminal',
#   'go',
#   'hold_out',
#   'last',
#   'death',
#   'final_stage',
#   'live_on',
#   'close',
#   'finis',
#   'finish',
#   'concluding',
#   'lastly',
#   'hold_up',
#   'last-place',
#   'endure',
#   'final',
#   'finale',
#   'finally',
#   "cobbler's_last",
#   'survive',
#   "shoemaker's_last",
#   'conclusion',
#   'in_conclusion'),
#  'great': ('keen',
#   'expectant',
#   'majuscule',
#   'bang-up',
#   'corking',
#   'slap-up',
#   'nifty',
#   'swell',
#   'groovy',
#   'not_bad',
#   'bully',
#   'great',
#   'with_child',
#   'big',
#   'capital',
#   'gravid',
#   'peachy',
#   'cracking',
#   'neat',
#   'enceinte',
#   'large',
#   'outstanding',
#   'dandy',
#   'smashing',
#   'heavy'),
#  'cynthia': ('artemis', 'cynthia'),
#  'dinner': ('dinner', 'dinner_party'),
#  'little': ('little',
#   'lilliputian',
#   'piddling',
#   'niggling',
#   'picayune',
#   'trivial',
#   'short',
#   'minuscule',
#   'slight',
#   'piffling',
#   'small',
#   'fiddling',
#   'petty',
#   'footling'),
#  'place': ('rank',
#   'send',
#   'place',
#   'office',
#   'billet',
#   'shoes',
#   'plaza',
#   'stead',
#   'put',
#   'set',
#   'grade',
#   'localise',
#   'identify',
#   'locate',
#   'localize',
#   'lieu',
#   'order',
#   'come_out',
#   'home',
#   'rate',
#   'range',
#   'piazza',
#   'space',
#   'site',
#   'spot',
#   'come_in',
#   'direct',
#   'post',
#   'property',
#   'topographic_point',
#   'invest',
#   'target',
#   'seat',
#   'position',
#   'commit',
#   'berth',
#   'situation',
#   'pose',
#   'lay',
#   'blank_space',
#   'point',
#   'aim',
#   'station'),
#  'bad': ('badly',
#   'unsound',
#   'big',
#   'risky',
#   'unfit',
#   'regretful',
#   'high-risk',
#   'uncollectible',
#   'tough',
#   'badness',
#   'sorry',
#   'speculative',
#   'spoiled',
#   'bad',
#   'defective',
#   'spoilt',
#   'forged'),
#  'sick': ('fed_up',
#   'queasy',
#   'spew',
#   'nauseous',
#   'tired_of',
#   'unhinged',
#   'pallid',
#   'upchuck',
#   'macabre',
#   'cast',
#   'barf',
#   'vomit',
#   'ghastly',
#   'demented',
#   'crazy',
#   'retch',
#   'purge',
#   'cat',
#   'spue',
#   'sick_of',
#   'mad',
#   'throw_up',
#   'disgorge',
#   'disturbed',
#   'chuck',
#   'sick',
#   'wan',
#   'honk',
#   'gruesome',
#   'pale',
#   'grim',
#   'brainsick',
#   'ill',
#   'vomit_up',
#   'regorge',
#   'grisly',
#   'disgusted',
#   'be_sick',
#   'nauseated',
#   'sickish',
#   'unbalanced',
#   'regurgitate',
#   'puke'),
#  'afterwards': ('subsequently',
#   'afterwards',
#   'after',
#   'afterward',
#   'later',
#   'later_on'),
#  'dude': ('dude',
#   'fashion_plate',
#   'swell',
#   'clotheshorse',
#   'dandy',
#   'buster',
#   'fop',
#   'fellow',
#   'sheik',
#   'gallant',
#   'beau'),
#  'sandwich': ('sandwich',),
#  'ever': ('ever_so', 'always', "e'er", 'of_all_time', 'ever'),
#  'take': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'yield',
#   'require',
#   'issue',
#   'lease',
#   'strike',
#   'proceeds',
#   'take_in',
#   'use_up',
#   'call_for',
#   'payoff',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'return',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'takings',
#   'learn'),
#  'picture': ('video',
#   'visualise',
#   'film',
#   'motion-picture_show',
#   'ikon',
#   'scene',
#   'depict',
#   'render',
#   'project',
#   'impression',
#   'pictorial_matter',
#   'visualize',
#   'movie',
#   'delineation',
#   'mental_picture',
#   'picture',
#   'word-painting',
#   'picture_show',
#   'characterisation',
#   'word_picture',
#   'exposure',
#   'envision',
#   'see',
#   'pic',
#   'show',
#   'moving_picture',
#   'icon',
#   'motion_picture',
#   'painting',
#   'photograph',
#   'image',
#   'characterization',
#   'flick',
#   'photo',
#   'figure',
#   'moving-picture_show',
#   'fancy',
#   'depiction'),
#  'need': ('require',
#   'call_for',
#   'pauperization',
#   'pauperism',
#   'involve',
#   'postulate',
#   'demand',
#   'penury',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'motive',
#   'need',
#   'indigence',
#   'motivation'),
#  'pack': ('ring',
#   'multitude',
#   'clique',
#   'ingroup',
#   'mob',
#   'tamp_down',
#   'large_number',
#   'coterie',
#   'load_down',
#   'inner_circle',
#   'jam',
#   'plurality',
#   'gang',
#   'battalion',
#   'pack',
#   'wad',
#   'pile',
#   'camp',
#   'backpack',
#   'bundle',
#   'compact',
#   'tamp',
#   'throng',
#   'carry',
#   'take',
#   'face_pack'),
#  'cali': ('cali',),
#  'can': ('displace',
#   'rump',
#   'buttocks',
#   'hind_end',
#   'bathroom',
#   'john',
#   'behind',
#   'bottom',
#   'lav',
#   'prat',
#   'tooshie',
#   'nates',
#   'throne',
#   'fundament',
#   'send_away',
#   'butt',
#   'ass',
#   'canful',
#   'stern',
#   'tush',
#   'privy',
#   'can',
#   'force_out',
#   'fire',
#   'fanny',
#   'arse',
#   'buns',
#   'sack',
#   'crapper',
#   'dismiss',
#   'derriere',
#   'stool',
#   'potty',
#   'bum',
#   'rear_end',
#   'seat',
#   'terminate',
#   'posterior',
#   'give_notice',
#   'keister',
#   'tin_can',
#   'backside',
#   'toilet',
#   'lavatory',
#   'give_the_sack',
#   'give_the_axe',
#   'tail_end',
#   'hindquarters',
#   'tin',
#   'can_buoy',
#   'pot',
#   'commode',
#   'put_up',
#   'tail',
#   'rear'),
#  'thinking': ('consider',
#   'recollect',
#   'believe',
#   'guess',
#   'imagine',
#   'thought',
#   'intelligent',
#   'call_back',
#   'opine',
#   'cerebrate',
#   'mentation',
#   'reckon',
#   'recall',
#   'call_up',
#   'intend',
#   'reasoning',
#   'remember',
#   'cogitate',
#   'think',
#   'mean',
#   'intellection',
#   'retrieve',
#   'conceive',
#   'thought_process',
#   'cerebration',
#   'thinking',
#   'suppose'),
#  'glass': ('crank',
#   'field_glass',
#   'glass',
#   'chicken_feed',
#   'ice',
#   'deoxyephedrine',
#   'spyglass',
#   'methedrine',
#   'drinking_glass',
#   'glass_over',
#   'glaze_over',
#   'glassful',
#   'methamphetamine_hydrochloride',
#   'trash',
#   'shabu',
#   'chalk',
#   'looking_glass',
#   'meth',
#   'glaze',
#   'methamphetamine',
#   'glass_in'),
#  'wine': ('wine-coloured', 'wine', 'wine-colored', 'vino'),
#  'order': ('ordination',
#   'dictate',
#   'rank',
#   'place',
#   'ordinate',
#   'regularize',
#   'edict',
#   'ordain',
#   'put',
#   'grade',
#   'tell',
#   'guild',
#   'holy_order',
#   'say',
#   'order',
#   'prescribe',
#   'lodge',
#   'rate',
#   'range',
#   'ordering',
#   'gild',
#   'parliamentary_procedure',
#   'monastic_order',
#   'set_up',
#   'parliamentary_law',
#   'orderliness',
#   'enjoin',
#   'club',
#   'rescript',
#   'arrange',
#   'society',
#   'govern',
#   'social_club',
#   'regulate',
#   'rules_of_order',
#   'consecrate',
#   'purchase_order',
#   'order_of_magnitude',
#   'fiat',
#   'regularise',
#   'decree'),
#  'weekend': ('weekend',),
#  'work': ('act',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'employment',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'oeuvre',
#   'operate',
#   'ferment',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'piece_of_work',
#   'workplace',
#   'process',
#   'lick',
#   'mould',
#   'run',
#   'study',
#   'make_for',
#   'body_of_work',
#   'exercise',
#   'knead'),
#  'morrow': ('morrow',),
#  'tho': ('tho',),
#  'took': ('consider',
#   'film',
#   'have',
#   'deal',
#   'rent',
#   'submit',
#   'pick_out',
#   'postulate',
#   'exact',
#   'read',
#   'take_away',
#   'require',
#   'lease',
#   'strike',
#   'take_in',
#   'use_up',
#   'call_for',
#   'withdraw',
#   'subscribe',
#   'select',
#   'contract',
#   'necessitate',
#   'choose',
#   'remove',
#   'shoot',
#   'claim',
#   'direct',
#   'subscribe_to',
#   'assume',
#   'conduct',
#   'hire',
#   'drive',
#   'adopt',
#   'pack',
#   'look_at',
#   'engage',
#   'get_hold_of',
#   'take_on',
#   'bring',
#   'acquire',
#   'demand',
#   'make',
#   'train',
#   'accept',
#   'guide',
#   'need',
#   'take_aim',
#   'take_up',
#   'charter',
#   'admit',
#   'convey',
#   'lead',
#   'fill',
#   'involve',
#   'occupy',
#   'ingest',
#   'consume',
#   'carry',
#   'take',
#   'hold',
#   'get',
#   'ask',
#   'contain',
#   'study',
#   'aim',
#   'learn'),
#  'math': ('maths', 'math', 'mathematics'),
#  'test': ('test',
#   'screen',
#   'quiz',
#   'essay',
#   'trial_run',
#   'mental_test',
#   'mental_testing',
#   'examination',
#   'psychometric_test',
#   'trial',
#   'examine',
#   'try_out',
#   'tryout',
#   'run',
#   'exam',
#   'prove',
#   'try'),
#  'today': ('today', 'now', 'nowadays'),
#  'teacher': ('instructor', 'teacher'),
#  'say': ('order',
#   'enjoin',
#   'allege',
#   'pronounce',
#   'aver',
#   'enounce',
#   'read',
#   'tell',
#   'enunciate',
#   'articulate',
#   'sound_out',
#   'say',
#   'state',
#   'suppose'),
#  'calculator': ('figurer',
#   'calculator',
#   'calculating_machine',
#   'estimator',
#   'computer',
#   'reckoner'),
#  'luke': ('luke',
#   'st._luke',
#   'saint_luke',
#   'gospel_according_to_luke',
#   'gospel_of_luke'),
#  'confident': ('sure-footed',
#   'convinced',
#   'positive',
#   'surefooted',
#   'confident'),
#  'decided': ('decide',
#   'determine',
#   'settle',
#   'adjudicate',
#   "make_up_one's_mind",
#   'distinct',
#   'decided',
#   'resolve'),
#  'concert': ('concert',),
#  'madrigal': ('madrigal',),
#  'gave': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'contribute',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chill': ('frisson',
#   'shivering',
#   'quiver',
#   'thrill',
#   'iciness',
#   'shiver',
#   'pall',
#   'cool',
#   'chill',
#   'tingle',
#   'gelidity',
#   'cool_down',
#   'shudder'),
#  'almost': ('about',
#   'near',
#   'nigh',
#   'almost',
#   'virtually',
#   'well-nigh',
#   'nearly',
#   'most'),
#  'every': ('every',),
#  'also': ('as_well', 'too', 'likewise', 'besides', 'also'),
#  'called': ('ring',
#   'foretell',
#   'shout',
#   'forebode',
#   'name',
#   'squall',
#   'address',
#   'promise',
#   'prognosticate',
#   'anticipate',
#   'holler',
#   'hollo',
#   'scream',
#   'send_for',
#   'call_up',
#   'call_in',
#   'visit',
#   'call_off',
#   'cry',
#   'predict',
#   'phone',
#   'bid',
#   'call',
#   'shout_out',
#   'telephone',
#   'yell'),
#  'alumnus': ('graduate', 'alumna', 'alumnus', 'grad', 'alum'),
#  'cant': ('chamfer',
#   'slant',
#   'tilt',
#   'cant_over',
#   'bank',
#   'lingo',
#   'cant',
#   'vernacular',
#   'buzzword',
#   'patois',
#   'slang',
#   'pious_platitude',
#   'jargon',
#   'argot',
#   'camber',
#   'bevel',
#   'pitch'),
#  'minute': ('moment',
#   'min',
#   'instant',
#   'bit',
#   'minute_of_arc',
#   'hour',
#   'narrow',
#   'minute',
#   'arcminute',
#   'mo',
#   'second',
#   'infinitesimal'),
#  'treadmill': ('tread-wheel', 'salt_mine', 'treadwheel', 'treadmill'),
#  'done': ('act',
#   'fare',
#   'cause',
#   'set',
#   'perform',
#   'serve',
#   'execute',
#   'practice',
#   'coiffe',
#   'do',
#   'practise',
#   'behave',
#   'done',
#   'make_out',
#   'coif',
#   'get_along',
#   'coiffure',
#   'make',
#   'dress',
#   'arrange',
#   'suffice',
#   'through_with',
#   'manage',
#   'through',
#   'answer',
#   'come',
#   'exercise'),
#  'already': ('already',),
#  'na': ('sodium', 'atomic_number_11', 'na'),
#  'roomy': ('roommate', 'spacious', 'roomie', 'roomy'),
#  'wait': ('postponement',
#   'look',
#   'hold',
#   'time_lag',
#   'wait',
#   'hold_off',
#   'waitress',
#   'waiting',
#   'delay',
#   'hold_back',
#   'expect',
#   'await'),
#  'zombie': ('living_dead',
#   'zombie',
#   'automaton',
#   'zombi',
#   'snake_god',
#   'zombie_spirit',
#   'zombi_spirit'),
#  'cr': ('cr', 'chromium', 'atomic_number_24'),
#  'week': ('calendar_week', 'week', 'workweek', 'hebdomad'),
#  'spilled': ('spill',
#   'slop',
#   'run_out',
#   'talk',
#   'splatter',
#   'shed',
#   'disgorge',
#   'pour_forth'),
#  'beer': ('beer',),
#  'leg': ('branch',
#   'pegleg',
#   'peg',
#   'wooden_leg',
#   'stage',
#   'ramification',
#   'leg'),
#  'wasted': ('cadaverous',
#   'wasted',
#   'scourge',
#   'superfluous',
#   'rot',
#   'blow',
#   'emaciated',
#   'run_off',
#   'squandered',
#   'emaciate',
#   'pointless',
#   'ware',
#   'neutralise',
#   'otiose',
#   'macerate',
#   'liquidate',
#   'bony',
#   'squander',
#   'knock_off',
#   'senseless',
#   'atrophied',
#   'neutralize',
#   'haggard',
#   'do_in',
#   'pine_away',
#   'diminished',
#   'desolate',
#   'skeletal',
#   'waste',
#   'ravage',
#   'pinched',
#   'gaunt',
#   'lay_waste_to',
#   'consume',
#   'devastate',
#   'languish',
#   'purposeless'),
#  'half': ('one-half', 'half'),
#  'home': ('place',
#   'home_plate',
#   'house',
#   'home_base',
#   'menage',
#   'interior',
#   'plate',
#   'abode',
#   'home',
#   'base',
#   'national',
#   'dwelling_house',
#   'household',
#   'internal',
#   'dwelling',
#   'domicile',
#   'habitation',
#   'rest_home',
#   'nursing_home',
#   'family'),
#  'met': ('encounter',
#   'play',
#   'conform_to',
#   'gather',
#   'touch',
#   'adjoin',
#   'come_across',
#   'fulfill',
#   'suffer',
#   'satisfy',
#   'run_across',
#   'contact',
#   'run_into',
#   'meet',
#   'see',
#   'take_on',
#   'fulfil',
#   'forgather',
#   'get_together',
#   'fit',
#   'cope_with',
#   'receive',
#   'match',
#   'converge',
#   'fill',
#   'assemble',
#   'foregather'),
#  'girl': ('miss',
#   'female_child',
#   'young_woman',
#   'daughter',
#   'little_girl',
#   'girl',
#   'missy',
#   'lady_friend',
#   'fille',
#   'girlfriend',
#   'young_lady'),
#  'good': ('honest',
#   'well',
#   'secure',
#   'good',
#   'adept',
#   'dear',
#   'practiced',
#   'soundly',
#   'near',
#   'in_effect',
#   'right',
#   'goodness',
#   'trade_good',
#   'sound',
#   'just',
#   'upright',
#   'honorable',
#   'serious',
#   'unspoiled',
#   'salutary',
#   'in_force',
#   'respectable',
#   'full',
#   'expert',
#   'skilful',
#   'thoroughly',
#   'safe',
#   'skillful',
#   'beneficial',
#   'effective',
#   'commodity',
#   'estimable',
#   'proficient',
#   'unspoilt',
#   'dependable',
#   'undecomposed',
#   'ripe'),
#  'conversation': ('conversation',),
#  'english': ('english_language', 'english', 'english_people', 'side'),
#  'class': ('sort',
#   'sort_out',
#   'socio-economic_class',
#   'course_of_instruction',
#   'form',
#   'category',
#   'grade',
#   'course',
#   'class',
#   'stratum',
#   'year',
#   'separate',
#   'family',
#   'course_of_study',
#   'assort',
#   'classify',
#   'social_class',
#   'division'),
#  'working': ('working',
#   'act',
#   'workings',
#   'influence',
#   'play',
#   'act_upon',
#   'crop',
#   'work',
#   'figure_out',
#   'go',
#   'mold',
#   'solve',
#   'puzzle_out',
#   'ferment',
#   'operate',
#   'functional',
#   'function',
#   'forge',
#   'work_on',
#   'wreak',
#   'on_the_job',
#   'cultivate',
#   'form',
#   'do_work',
#   'bring',
#   'make',
#   'shape',
#   'sour',
#   'turn',
#   'work_out',
#   'put_to_work',
#   'exploit',
#   'running',
#   'process',
#   'lick',
#   'mould',
#   'operative',
#   'run',
#   'make_for',
#   'exercise',
#   'knead'),
#  'interactive': ('interactional', 'synergistic', 'interactive'),
#  'oral': ('oral_exam',
#   'viva_voce',
#   'oral',
#   'viva',
#   'oral_examination',
#   'unwritten'),
#  'boring': ('tire',
#   'dull',
#   'wearisome',
#   'tiresome',
#   'bore',
#   'irksome',
#   'oil_production',
#   'ho-hum',
#   'slow',
#   'drilling',
#   'drill',
#   'boring',
#   'tedious',
#   'deadening'),
#  'wan': ('sick', 'wan', 'pallid', 'wide_area_network', 'pale'),
#  'right': ('rectify',
#   'rightfulness',
#   'compensate',
#   'decent',
#   'in_good_order',
#   'good',
#   'properly',
#   'the_right_way',
#   'right_hand',
#   'flop',
#   'justly',
#   'correctly',
#   'right-hand',
#   'aright',
#   'right',
#   'redress',
#   'mighty',
#   'correct',
#   'proper',
#   'veracious',
#   'right_field',
#   'powerful',
#   'right_wing',
#   'right_on',
#   'rightfield',
#   'mightily',
#   'decently',
#   'ripe'),
#  'must': ('moldiness', 'must', 'mustiness'),
#  'new': ('fresh',
#   'raw',
#   'novel',
#   'unexampled',
#   'freshly',
#   'new',
#   'modern',
#   'newfangled',
#   'newly',
#   'young'),
#  'music': ('euphony', 'medicine', 'music'),
#  'wont': ('habit', 'wont'),
#  'sleep': ('kip',
#   "log_z's",
#   "catch_some_z's",
#   'nap',
#   'sleep',
#   'slumber',
#   'rest',
#   'sopor',
#   'eternal_sleep',
#   'quietus',
#   'eternal_rest'),
#  'give': ('dedicate',
#   'turn_over',
#   'have',
#   'pass_on',
#   'break',
#   'fall_in',
#   'leave',
#   'grant',
#   'yield',
#   'throw',
#   'devote',
#   'render',
#   'collapse',
#   'gift',
#   'hand',
#   'founder',
#   'apply',
#   'ease_up',
#   'sacrifice',
#   'give',
#   'springiness',
#   'contribute',
#   'spring',
#   'cave_in',
#   'open',
#   'present',
#   'return',
#   'move_over',
#   'make',
#   'pay',
#   'pass',
#   'commit',
#   'chip_in',
#   'hold',
#   'generate',
#   'reach',
#   'consecrate',
#   'impart',
#   'give_way',
#   'afford',
#   'kick_in',
#   'feed',
#   'establish'),
#  'chapter': ('chapter',),
#  'might': ('mightiness', 'power', 'might'),
#  'die': ('die',
#   'become_flat',
#   'croak',
#   'break',
#   'give-up_the_ghost',
#   'buy_the_farm',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'conk_out',
#   'go',
#   'conk',
#   'break_down',
#   'decease',
#   'drop_dead',
#   'die_out',
#   'go_bad',
#   'pass',
#   'pop_off',
#   'pall',
#   'choke',
#   'pass_away',
#   'dice',
#   "cash_in_one's_chips",
#   'exit',
#   'fail',
#   'snuff_it',
#   'give_way',
#   'expire'),
#  'first': ('low_gear',
#   'get-go',
#   '1st',
#   'beginning',
#   'number_one',
#   'first-class_honours_degree',
#   'first_gear',
#   'first_of_all',
#   'number_1',
#   'firstly',
#   'start',
#   'first',
#   'first_base',
#   'inaugural',
#   'showtime',
#   'initiatory',
#   'low',
#   'first_off',
#   'world-class',
#   'foremost',
#   'commencement',
#   'maiden',
#   'outset',
#   'initiative',
#   'starting_time',
#   'kickoff',
#   'offset',
#   'for_the_first_time'),
#  'though': ('though',),
#  'hurry': ('speed',
#   'zip',
#   'travel_rapidly',
#   'festinate',
#   'precipitation',
#   'look_sharp',
#   'hastiness',
#   'rush',
#   'hurry',
#   'hurriedness',
#   'haste',
#   'hasten',
#   'rushing'),
#  'look': ('tone',
#   'feel',
#   'attend',
#   'facial_expression',
#   'bet',
#   'seem',
#   'front',
#   'await',
#   'depend',
#   'look',
#   'calculate',
#   'reckon',
#   'expect',
#   'looking',
#   'see',
#   'feeling',
#   'search',
#   'appear',
#   'aspect',
#   'smell',
#   'expression',
#   'spirit',
#   'face',
#   'looking_at',
#   'wait',
#   'take_care',
#   'flavour',
#   'flavor',
#   'count'),
#  'lot': ('luck',
#   'circumstances',
#   'mess',
#   'deal',
#   'bunch',
#   'passel',
#   'set',
#   'slew',
#   'stack',
#   'mete_out',
#   'parcel_out',
#   'tidy_sum',
#   'administer',
#   'circle',
#   'band',
#   'portion',
#   'dole_out',
#   'mountain',
#   'hatful',
#   'flock',
#   'great_deal',
#   'batch',
#   'wad',
#   'heap',
#   'deal_out',
#   'allot',
#   'mass',
#   'pile',
#   'distribute',
#   'quite_a_little',
#   'destiny',
#   'shell_out',
#   'sight',
#   'muckle',
#   'caboodle',
#   'draw',
#   'dispense',
#   'mint',
#   'spate',
#   'fortune',
#   'raft',
#   'fate',
#   'peck',
#   'mickle',
#   'good_deal',
#   'pot',
#   'dish_out',
#   'lot',
#   'plenty'),
#  'hi': ('howdy',
#   "hawai'i",
#   'aloha_state',
#   'hullo',
#   'hi',
#   'how-do-you-do',
#   'hawaii',
#   'hello'),
#  'enough': ('decent', 'sufficiency', 'adequate', 'enough', 'plenty'),
#  'replay': ('rematch',
#   'action_replay',
#   'instant_replay',
#   'replay',
#   'play_back'),
#  'please': ('please', 'delight'),
#  'love': ('love_life',
#   'bonk',
#   'roll_in_the_hay',
#   'have_sex',
#   'hump',
#   'get_it_on',
#   'passion',
#   'dear',
#   'dearest',
#   'be_intimate',
#   'love',
#   'screw',
#   'bang',
#   'have_it_away',
#   'sleep_with',
#   'get_laid',
#   'make_out',
#   'jazz',
#   'erotic_love',
#   'bed',
#   'have_it_off',
#   'have_a_go_at_it',
#   'making_love',
#   'lovemaking',
#   'do_it',
#   'honey',
#   'sleep_together',
#   'eff',
#   'sexual_love',
#   'have_intercourse',
#   'make_love',
#   'lie_with',
#   'enjoy',
#   'know',
#   'fuck',
#   'beloved'),
#  'big': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'boastfully',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'vauntingly',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'vanessa': ('genus_vanessa', 'vanessa'),
#  'going': ('release',
#   'die',
#   'loss',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'passing',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'expiration',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'leaving',
#   'departure',
#   'move',
#   'function',
#   'going_away',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'going',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'sledding',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'september': ('september', 'sept', 'sep'),
#  'fast': ('degenerate',
#   'immobile',
#   'tight',
#   'fasting',
#   'quick',
#   'fast',
#   'firm',
#   'profligate',
#   'truehearted',
#   'degraded',
#   'dissolute',
#   'dissipated',
#   'flying',
#   'loyal',
#   'debauched',
#   'libertine',
#   'riotous'),
#  'miss': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'young_woman',
#   'girl',
#   'misfire',
#   'pretermit',
#   'missy',
#   'overleap',
#   'fille',
#   'neglect',
#   'escape',
#   'omit',
#   'young_lady',
#   'lose'),
#  'lord': ('overlord',
#   'noble',
#   'almighty',
#   'nobleman',
#   'maker',
#   'godhead',
#   'master',
#   'lord',
#   'creator',
#   'divine',
#   'jehovah',
#   'god_almighty'),
#  'agency': ('bureau',
#   'office',
#   'way',
#   'means',
#   'authority',
#   'government_agency',
#   'representation',
#   'federal_agency',
#   'delegacy',
#   'agency'),
#  'upcoming': ('coming', 'forthcoming', 'approaching', 'upcoming'),
#  'open': ('spread_out',
#   'loose',
#   'heart-to-heart',
#   'open_air',
#   'candid',
#   'assailable',
#   'subject',
#   'undefended',
#   'capable',
#   'overt',
#   'out-of-doors',
#   'spread',
#   'give',
#   'receptive',
#   'surface',
#   'open',
#   'unresolved',
#   'clear',
#   'undefendable',
#   'unfold',
#   'outdoors',
#   'undecided',
#   'undetermined',
#   'opened',
#   'exposed',
#   'unfastened',
#   'afford',
#   'open_up'),
#  'money': ('money',),
#  'jam': ('muddle',
#   'crush',
#   'mess',
#   'chock_up',
#   'block',
#   'press',
#   'mob',
#   'jamming',
#   'jampack',
#   'fix',
#   'ram',
#   'jam',
#   'pack',
#   'wad',
#   'hole',
#   'occlude',
#   'electronic_jamming',
#   'pile',
#   'kettle_of_fish',
#   'pickle',
#   'obstruct',
#   'close_up',
#   'throng',
#   'obturate',
#   'cram',
#   'impede'),
#  'foster': ('foster',
#   'surrogate',
#   'nurture',
#   'further',
#   'stephen_foster',
#   'stephen_collins_foster'),
#  'kitten': ('kitten', 'kitty'),
#  'getting': ('stupefy',
#   'have',
#   'begin',
#   'obtain',
#   'getting',
#   'cause',
#   'set_out',
#   'mother',
#   'become',
#   "get_under_one's_skin",
#   'nonplus',
#   'start',
#   'go',
#   'induce',
#   'fetch',
#   'gravel',
#   'start_out',
#   'beget',
#   'arrive',
#   'dumbfound',
#   'acquiring',
#   'sustain',
#   'contract',
#   'fix',
#   'find',
#   'suffer',
#   'arrest',
#   'incur',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'let',
#   'develop',
#   'drive',
#   'get_down',
#   'commence',
#   'puzzle',
#   'beat',
#   'grow',
#   'buzz_off',
#   'stick',
#   'flummox',
#   'bring',
#   'acquire',
#   'make',
#   'baffle',
#   'draw',
#   'stimulate',
#   'engender',
#   'scram',
#   'capture',
#   'produce',
#   'receive',
#   'pay_back',
#   'bugger_off',
#   'bring_forth',
#   'convey',
#   'pay_off',
#   'generate',
#   'fuck_off',
#   'mystify',
#   'take',
#   'get',
#   'come',
#   'vex',
#   'set_about',
#   'father',
#   'sire',
#   'aim',
#   'catch',
#   'pose',
#   'experience'),
#  'b': ('b',
#   'b-complex_vitamin',
#   'boron',
#   'group_b',
#   'b_complex',
#   'atomic_number_5',
#   'vitamin_b',
#   'bel',
#   'b_vitamin',
#   'bacillus',
#   'type_b',
#   'vitamin_b_complex',
#   'barn'),
#  'missed': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'pretermit',
#   'overleap',
#   'missed',
#   'neglect',
#   'escape',
#   'omit',
#   'lost',
#   'lose'),
#  'amazing': ('awful',
#   'stupefy',
#   'awesome',
#   'nonplus',
#   'awing',
#   'gravel',
#   'amazing',
#   'astonish',
#   'amaze',
#   'perplex',
#   'bewilder',
#   'puzzle',
#   'beat',
#   'flummox',
#   'astound',
#   'baffle',
#   'awe-inspiring',
#   'astonishing',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'ready': ('gear_up',
#   'set',
#   'quick',
#   'fix',
#   'cook',
#   'make',
#   'prepare',
#   'set_up',
#   'ready'),
#  'school': ('shoal',
#   'educate',
#   'cultivate',
#   'schooling',
#   'schoolhouse',
#   'school',
#   'civilize',
#   'schooltime',
#   'school_day',
#   'train',
#   'civilise'),
#  'second': ('endorsement',
#   'sec',
#   'bit',
#   'indorse',
#   'mo',
#   'second_gear',
#   'instant',
#   'back',
#   'secondly',
#   'second_base',
#   '2d',
#   'second',
#   's',
#   'indorsement',
#   'irregular',
#   'endorse',
#   '2nd',
#   'moment',
#   'minute',
#   'arcsecond',
#   'secondment'),
#  'year': ('yr', 'twelvemonth', 'class', 'year'),
#  'next': ('side_by_side',
#   'following',
#   'adjacent',
#   'next',
#   'succeeding',
#   'future'),
#  'officially': ('officially', 'formally'),
#  'th': ('atomic_number_90', 'th', 'thorium', 'thursday'),
#  'yay': ('yay',),
#  'bonus': ('fillip', 'bonus', 'incentive'),
#  'drive': ('driving_force',
#   'force_back',
#   'thrust',
#   'cause',
#   'private_road',
#   'beat_back',
#   'repel',
#   'driveway',
#   'tug',
#   'labor',
#   'force',
#   'push',
#   'labour',
#   'ride',
#   'ram',
#   'drive',
#   'effort',
#   'driving',
#   'motor',
#   'push_back',
#   'repulse',
#   'movement',
#   'parkway',
#   'campaign',
#   'crusade',
#   'get',
#   'take',
#   'aim'),
#  'wale': ('wheal', 'strake', 'wale', 'welt', 'weal'),
#  'tonight': ('tonight', 'this_evening', 'this_night'),
#  'ride': ('tantalise',
#   'hinge_upon',
#   'depend_upon',
#   'rally',
#   'devolve_on',
#   'tantalize',
#   'ride',
#   'cod',
#   'taunt',
#   'drive',
#   'depend_on',
#   'turn_on',
#   'rag',
#   'hinge_on',
#   'razz',
#   'tease',
#   'twit',
#   'sit',
#   'mount',
#   'bait'),
#  'ok': ('alright',
#   'very_well',
#   'ok',
#   'all_right',
#   'fine',
#   'okeh',
#   'okey',
#   'okay',
#   'oklahoma',
#   'sooner_state',
#   'hunky-dory',
#   'o.k.'),
#  'shoe': ('skid', 'shoe', 'horseshoe', 'brake_shoe'),
#  'club': ('order',
#   'golf_club',
#   'golf-club',
#   'cabaret',
#   'baseball_club',
#   'lodge',
#   'club',
#   'gild',
#   'clubhouse',
#   'bludgeon',
#   'ball_club',
#   'night_club',
#   'nine',
#   'guild',
#   'society',
#   'nightspot',
#   'social_club',
#   'nightclub'),
#  'cool': ('aplomb',
#   'poise',
#   'coolheaded',
#   'cool',
#   'cool_off',
#   'chill',
#   'nerveless',
#   'sang-froid',
#   'cool_down',
#   'assuredness'),
#  'fun': ('merriment', 'playfulness', 'sport', 'play', 'fun'),
#  'except': ('leave_out',
#   'exclude',
#   'except',
#   'omit',
#   'demur',
#   'leave_off',
#   'take_out'),
#  'wit': ('mentality',
#   'wit',
#   'humour',
#   'learning_ability',
#   'wittiness',
#   'witticism',
#   'humor',
#   'card',
#   'brain',
#   'brainpower',
#   'mental_capacity',
#   'wag'),
#  'emmy': ('emmy',),
#  'latin': ('romance', 'latin'),
#  'help': ('facilitate',
#   'assist',
#   'assistant',
#   'supporter',
#   'service',
#   'help_oneself',
#   'helper',
#   'assistance',
#   'help',
#   'avail',
#   'serve',
#   'aid'),
#  'study': ('canvass',
#   'consider',
#   'hit_the_books',
#   'contemplate',
#   'read',
#   'canvas',
#   'work',
#   'survey',
#   'discipline',
#   'subject',
#   'subject_field',
#   'examine',
#   'written_report',
#   'bailiwick',
#   'study',
#   'report',
#   'sketch',
#   'subject_area',
#   'cogitation',
#   'analyse',
#   'take',
#   'field_of_study',
#   'meditate',
#   'analyze',
#   'learn',
#   'field'),
#  'aptitude': ('aptitude',),
#  'grad': ('graduate', 'alumna', 'grade', 'alumnus', 'grad', 'alum'),
#  'wish': ('wishing',
#   'like',
#   'bid',
#   'wish',
#   'regard',
#   'care',
#   'indirect_request',
#   'want',
#   'compliments',
#   'wish_well'),
#  'fly': ('wing',
#   'vaporize',
#   'vanish',
#   'rainfly',
#   'fly_front',
#   'fly_sheet',
#   'tent_flap',
#   'fly_ball',
#   'aviate',
#   'tent-fly',
#   'fell',
#   'flee',
#   'take_flight',
#   'fly',
#   'pilot'),
#  'la': ('lanthanum',
#   'louisiana',
#   'lah',
#   'pelican_state',
#   'la',
#   'atomic_number_57'),
#  'lemon': ('gamboge',
#   'lemon_yellow',
#   'lemon',
#   'citrus_limon',
#   'lemon_tree',
#   'maize',
#   'stinker'),
#  'tree': ('tree',
#   'sir_herbert_beerbohm_tree',
#   'tree_diagram',
#   'shoetree',
#   'corner'),
#  'who': ('who', 'world_health_organization'),
#  'always': ('constantly',
#   'always',
#   "e'er",
#   'perpetually',
#   'forever',
#   'ever',
#   'invariably',
#   'incessantly'),
#  'oh': ('buckeye_state', 'oh', 'ohio'),
#  'interesting': ('interest',
#   'concern',
#   'matter_to',
#   'interesting',
#   'occupy',
#   'worry'),
#  'show': ('evidence',
#   'register',
#   'read',
#   'record',
#   'depict',
#   'display',
#   'prove',
#   'demo',
#   'appearance',
#   'render',
#   'testify',
#   'usher',
#   'indicate',
#   'show_up',
#   'picture',
#   'express',
#   'evince',
#   'demonstrate',
#   'shew',
#   'present',
#   'show',
#   'designate',
#   'bear_witness',
#   'exhibit',
#   'point',
#   'establish'),
#  'least': ('to_the_lowest_degree', 'least'),
#  'recap': ('retread', 'review', 'recapitulation', 'recapitulate', 'recap'),
#  'tomorrow': ('tomorrow',),
#  'man': ('isle_of_man',
#   'mankind',
#   'military_man',
#   'adult_male',
#   'humanity',
#   'human_beings',
#   'man',
#   'human',
#   'human_being',
#   'valet_de_chambre',
#   'human_race',
#   'humans',
#   'humankind',
#   'valet',
#   'piece',
#   'military_personnel',
#   'gentleman',
#   'homo',
#   'world',
#   'serviceman',
#   "gentleman's_gentleman"),
#  'come': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'ejaculate',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'cum',
#   'amount',
#   'semen',
#   'seed',
#   'total',
#   'follow',
#   'occur',
#   'seminal_fluid',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'everyday': ('casual',
#   'workaday',
#   'routine',
#   'mundane',
#   'everyday',
#   'unremarkable',
#   'quotidian',
#   'daily'),
#  'instead': ('rather', 'instead', 'alternatively', 'or_else'),
#  'like': ('comparable',
#   'the_likes_of',
#   'like',
#   'corresponding',
#   'wish',
#   'alike',
#   'ilk',
#   'same',
#   'care',
#   'similar',
#   'the_like'),
#  'flight': ('trajectory',
#   'fledge',
#   'flight_of_steps',
#   'flight',
#   'flying',
#   'escape',
#   'flight_of_stairs'),
#  'booked': ('engaged', 'book', 'booked', 'hold', 'reserve', 'set-aside'),
#  'plus': ('plus', 'positive', 'summation', 'asset', 'addition'),
#  'birthday': ('birthday', 'natal_day'),
#  'especially': ('especially', 'particularly', 'specially', 'peculiarly'),
#  'missing': ('miss',
#   'leave_out',
#   'drop',
#   'lack',
#   'overlook',
#   'lacking',
#   'wanting',
#   'pretermit',
#   'overleap',
#   'absent',
#   'neglect',
#   'escape',
#   'omit',
#   'lose',
#   'missing'),
#  'hear': ('pick_up',
#   'see',
#   'get_a_line',
#   'get_word',
#   'listen',
#   'take_heed',
#   'try',
#   'hear',
#   'discover',
#   'find_out',
#   'learn',
#   'get_wind'),
#  'degree': ('academic_degree',
#   'stage',
#   'level',
#   'grade',
#   'degree',
#   'point',
#   'arcdegree'),
#  'movie': ('pic',
#   'film',
#   'moving_picture',
#   'motion_picture',
#   'movie',
#   'flick',
#   'motion-picture_show',
#   'picture',
#   'moving-picture_show',
#   'picture_show'),
#  'guy': ('guy_wire',
#   'make_fun',
#   'guy_cable',
#   'blackguard',
#   'rib',
#   'laugh_at',
#   'cat',
#   'guy_rope',
#   'bozo',
#   'ridicule',
#   'guy',
#   'jest_at',
#   'hombre',
#   'roast',
#   'poke_fun'),
#  'economy': ('saving', 'thriftiness', 'economic_system', 'economy'),
#  'sorry': ('deplorable',
#   'distressing',
#   'drab',
#   'meritless',
#   'no-account',
#   'disconsolate',
#   'blue',
#   'lamentable',
#   'gloomy',
#   'no-good',
#   'no-count',
#   'dismal',
#   'sorry',
#   'dark',
#   'grim',
#   'dingy',
#   'drear',
#   'regretful',
#   'good-for-nothing',
#   'pitiful',
#   'dreary',
#   'good-for-naught',
#   'bad',
#   'sad'),
#  'another': ('some_other', 'another'),
#  'came': ('fare',
#   'derive',
#   'add_up',
#   'descend',
#   'do',
#   'arrive',
#   'make_out',
#   'issue_forth',
#   'come_in',
#   'hail',
#   'get_along',
#   'amount',
#   'total',
#   'follow',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall'),
#  'fell': ('drop',
#   'light',
#   'devolve',
#   'decrease',
#   'savage',
#   'descend',
#   'strike_down',
#   'vicious',
#   'strike',
#   'accrue',
#   'come_down',
#   'hang',
#   'shine',
#   'fell',
#   'hide',
#   'barbarous',
#   'brutal',
#   'fall_down',
#   'return',
#   'precipitate',
#   'pass',
#   'settle',
#   'roughshod',
#   'diminish',
#   'go_down',
#   'fly',
#   'lessen',
#   'cruel',
#   'vanish',
#   'felled_seam',
#   'fall',
#   'come',
#   'cut_down',
#   'flow'),
#  'asleep': ('benumbed',
#   'asleep',
#   'numb',
#   'gone',
#   'at_rest',
#   'departed',
#   'at_peace',
#   'deceased'),
#  'friend': ('ally',
#   'admirer',
#   'booster',
#   'protagonist',
#   'supporter',
#   'friend',
#   'quaker',
#   'acquaintance',
#   'champion'),
#  'deeply': ('deep', 'profoundly', 'deeply'),
#  'moving': ('displace',
#   'act',
#   'prompt',
#   'propel',
#   'strike',
#   'go',
#   'move',
#   'actuate',
#   'proceed',
#   'moving',
#   'affect',
#   'motivate',
#   'be_active',
#   'incite',
#   'make_a_motion',
#   'impress',
#   'travel',
#   'run',
#   'locomote'),
#  'snow': ('coke',
#   'bamboozle',
#   'nose_candy',
#   'snow',
#   'snowfall',
#   'blow',
#   'lead_by_the_nose',
#   'baron_snow_of_leicester',
#   "pull_the_wool_over_someone's_eyes",
#   'charles_percy_snow',
#   'c',
#   'hoodwink',
#   'c._p._snow',
#   'play_false'),
#  'patrol': ('police', 'patrol'),
#  'stuck': ('sting',
#   'stupefy',
#   'stuck',
#   'stay_put',
#   'nonplus',
#   'stick_by',
#   'bind',
#   'lodge',
#   'wedge',
#   'adhere',
#   'gravel',
#   'stick_to',
#   'cohere',
#   'amaze',
#   'hold_fast',
#   'perplex',
#   'cling',
#   'bewilder',
#   'cleave',
#   'puzzle',
#   'stick_around',
#   'beat',
#   'stand_by',
#   'flummox',
#   'baffle',
#   'bond',
#   'stay',
#   'deposit',
#   'mystify',
#   'vex',
#   'get',
#   'stick',
#   'pose',
#   'dumbfound'),
#  'indoors': ('inside', 'indoors'),
#  'coming': ('advent',
#   'fare',
#   'approach',
#   'derive',
#   'add_up',
#   'descend',
#   'climax',
#   'do',
#   'arrive',
#   'make_out',
#   'coming',
#   'issue_forth',
#   'orgasm',
#   'come_in',
#   'hail',
#   'forthcoming',
#   'sexual_climax',
#   'get_along',
#   'amount',
#   'approaching',
#   'follow',
#   'total',
#   'occur',
#   'come_up',
#   'number',
#   'get',
#   'come',
#   'fall',
#   'upcoming'),
#  'fresh': ('invigorated',
#   'novel',
#   'smart',
#   'refreshing',
#   'new',
#   'tonic',
#   'clean',
#   'fresh',
#   'impertinent',
#   'overbold',
#   'reinvigorated',
#   'refreshful',
#   'impudent',
#   'sassy',
#   'unused',
#   'freshly',
#   'saucy',
#   'newly',
#   'brisk',
#   'sweet',
#   'unfermented',
#   'wise',
#   'bracing',
#   'refreshed'),
#  'air': ('gentle_wind',
#   'send',
#   'ventilate',
#   'vent',
#   'air',
#   'strain',
#   'air_travel',
#   'tune',
#   'publicise',
#   'transmit',
#   'aura',
#   'broadcast',
#   'line',
#   'breeze',
#   'melodic_phrase',
#   'aerate',
#   'airwave',
#   'bare',
#   'beam',
#   'melody',
#   'air_out',
#   'atmosphere',
#   'publicize',
#   'zephyr',
#   'melodic_line',
#   'aviation'),
#  'excellent': ('excellent', 'first-class', 'fantabulous', 'splendid'),
#  'hope': ('hope',
#   'promise',
#   'bob_hope',
#   'trust',
#   'leslie_townes_hope',
#   'go_for',
#   'desire'),
#  'sunny': ('cheery', 'gay', 'sunny'),
#  'load': ('warhead',
#   'lode',
#   'burden',
#   'stretch',
#   'incumbrance',
#   'loading',
#   'lade',
#   'shipment',
#   'consignment',
#   'dilute',
#   'debase',
#   'cargo',
#   'encumbrance',
#   'payload',
#   'lading',
#   'charge',
#   'onus',
#   'freight',
#   'load_up',
#   'laden',
#   'load',
#   'adulterate'),
#  'sun': ('solarize',
#   'insolate',
#   'sunlight',
#   'solarise',
#   'dominicus',
#   'sunbathe',
#   "lord's_day",
#   'sun',
#   'sunday',
#   'sunshine'),
#  'babe': ('baby', 'infant', 'sister', 'babe'),
#  'thank': ('give_thanks', 'thank'),
#  'making': ('create',
#   'shit',
#   'fashioning',
#   'score',
#   'lay_down',
#   'have',
#   'take_a_shit',
#   'pretend',
#   'cause',
#   'name',
#   'gain',
#   'micturate',
#   'piddle',
#   'pee',
#   'make_water',
#   'wee',
#   'prepare',
#   'qualification',
#   'throw',
#   'work',
#   'wee-wee',
#   'do',
#   'take_in',
#   'induce',
#   'earn',
#   'pass_water',
#   'constitute',
#   'spend_a_penny',
#   'fix',
#   'pee-pee',
#   'piss',
#   'give',
#   'puddle',
#   'ca-ca',
#   'devising',
#   'making',
#   'seduce',
#   'make_up',
#   'take_a_crap',
#   'form',
#   'get_to',
#   'arrive_at',
#   'clear',
#   'hit',
#   'stool',
#   'make_believe',
#   'make',
#   'construct',
#   'draw',
#   'stimulate',
#   'urinate',
#   'progress_to',
#   'build',
#   'realize',
#   'produce',
#   'ready',
#   'relieve_oneself',
#   'take_a_leak',
#   'nominate',
#   'hold',
#   'reach',
#   'attain',
#   'defecate',
#   'bring_in',
#   'cook',
#   'take',
#   'get',
#   'crap',
#   'realise',
#   'pull_in',
#   'establish'),
#  'lady': ('madam',
#   'peeress',
#   'noblewoman',
#   'lady',
#   "ma'am",
#   'gentlewoman',
#   'dame'),
#  'time': ('metre',
#   'clip',
#   'fourth_dimension',
#   'meter',
#   'sentence',
#   'time',
#   'clock',
#   'clock_time',
#   'prison_term'),
#  'went': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'move',
#   'function',
#   'run_low',
#   'proceed',
#   'break_down',
#   'decease',
#   'sound',
#   'drop_dead',
#   'hold_up',
#   'belong',
#   'plump',
#   'blend_in',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'family': ('kinfolk',
#   'house',
#   'category',
#   'phratry',
#   'menage',
#   'kin',
#   'family_unit',
#   'kinsperson',
#   'family_line',
#   'mob',
#   'home',
#   'folk',
#   'class',
#   'household',
#   'crime_syndicate',
#   'fellowship',
#   'family',
#   'kinsfolk',
#   'sept',
#   'syndicate'),
#  'party': ('political_party', 'company', 'party'),
#  'id': ('idaho', 'id', 'gem_state', 'i.d.'),
#  'really': ('truly',
#   'genuinely',
#   'in_truth',
#   'rattling',
#   'really',
#   'very',
#   'real',
#   'actually'),
#  'machine': ('motorcar',
#   'machine',
#   'simple_machine',
#   'automobile',
#   'car',
#   'auto',
#   'political_machine'),
#  'twitter': ('chirrup', 'chitter', 'twitter'),
#  'back': ('cover',
#   'vertebral_column',
#   'backbone',
#   'support',
#   'indorse',
#   'binding',
#   'plump_for',
#   'gage',
#   'rachis',
#   'backward',
#   'backrest',
#   'spinal_column',
#   'back',
#   'stake',
#   'second',
#   'rearward',
#   'game',
#   'backwards',
#   'spine',
#   'endorse',
#   'dorsum',
#   'book_binding',
#   'punt',
#   'back_up',
#   'hinder',
#   'rearwards',
#   'plunk_for',
#   'hind',
#   'bet_on',
#   'rear'),
#  'watching': ('observe',
#   'ascertain',
#   'keep_an_eye_on',
#   'observation',
#   'watch',
#   'find_out',
#   'take_in',
#   'look_out',
#   'look_on',
#   'see',
#   'determine',
#   'observance',
#   'follow',
#   'view',
#   'watching',
#   'watch_over',
#   'watch_out',
#   'learn',
#   'check',
#   'catch'),
#  'jay': ('john_jay', 'jay'),
#  'nd': ('neodymium',
#   'atomic_number_60',
#   'peace_garden_state',
#   'north_dakota',
#   'nd'),
#  'gone': ('die',
#   'croak',
#   'go_away',
#   'give-up_the_ghost',
#   'extend',
#   'break',
#   'buy_the_farm',
#   'live',
#   'at_rest',
#   'departed',
#   'become',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'work',
#   'start',
#   'conk_out',
#   'go',
#   'hold_out',
#   'get_going',
#   'conk',
#   'bypast',
#   'depart',
#   'operate',
#   'last',
#   'live_on',
#   'gone',
#   'move',
#   'function',
#   'run_low',
#   'done_for',
#   'proceed',
#   'break_down',
#   'decease',
#   'at_peace',
#   'sound',
#   'kaput',
#   'drop_dead',
#   'hold_up',
#   'asleep',
#   'belong',
#   'plump',
#   'blend_in',
#   'bygone',
#   'go_bad',
#   'endure',
#   'pass',
#   'pop_off',
#   'travel',
#   'run_short',
#   'choke',
#   'deceased',
#   'pass_away',
#   'fit',
#   "cash_in_one's_chips",
#   'foregone',
#   'exit',
#   'survive',
#   'fail',
#   'lead',
#   'blend',
#   'snuff_it',
#   'get',
#   'run',
#   'rifle',
#   'give_way',
#   'expire',
#   'locomote'),
#  'four': ('four',
#   'quadruplet',
#   'foursome',
#   'four-spot',
#   '4',
#   'quatern',
#   'quaternity',
#   'quartet',
#   'iv',
#   'little_joe',
#   'quaternion',
#   'tetrad',
#   'quaternary'),
#  'years': ('age',
#   'years',
#   'geezerhood',
#   'yr',
#   'class',
#   'year',
#   'twelvemonth',
#   'eld',
#   'days',
#   'long_time',
#   'old_age'),
#  'biggest': ('expectant',
#   'grown',
#   'bighearted',
#   'self-aggrandizing',
#   'freehanded',
#   'grownup',
#   'handsome',
#   'vainglorious',
#   'self-aggrandising',
#   'bountiful',
#   'openhanded',
#   'liberal',
#   'bounteous',
#   'full-grown',
#   'fully_grown',
#   'magnanimous',
#   'great',
#   'with_child',
#   'big',
#   'braggy',
#   'gravid',
#   'swelled',
#   'braggart',
#   'boastful',
#   'crowing',
#   'enceinte',
#   'large',
#   'adult',
#   'bragging',
#   'bad',
#   'cock-a-hoop',
#   'heavy',
#   'giving',
#   'prominent'),
#  'headache': ('head_ache',
#   'headache',
#   'vexation',
#   'concern',
#   'cephalalgia',
#   'worry'),
#  'washed': ('moisten',
#   'wash_off',
#   'lap',
#   'washed',
#   'wash',
#   'rinse',
#   'dampen',
#   'wash_away',
#   'lave',
#   'water-washed',
#   'wash_out',
#   'launder'),
#  'hair': ('whisker',
#   'hair',
#   'tomentum',
#   'pilus',
#   'haircloth',
#   "hair's-breadth",
#   'hairsbreadth',
#   'fuzz'),
#  'mum': ('ma',
#   "florist's_chrysanthemum",
#   'mum',
#   'mom',
#   'mummy',
#   'mamma',
#   "florists'_chrysanthemum",
#   'mammy',
#   'dendranthema_grandifloruom',
#   'chrysanthemum_morifolium',
#   'silent',
#   'momma',
#   'mommy',
#   'mama'),
#  'shampoo': ('shampoo',),
#  'gross': ('vulgar',
#   'rank',
#   'stark',
#   'receipts',
#   'glaring',
#   'sodding',
#   'megascopic',
#   'arrant',
#   '144',
#   'unadulterated',
#   'staring',
#   'complete',
#   'utter',
#   'gross',
#   'revenue',
#   'perfect',
#   'flagrant',
#   'double-dyed',
#   'egregious',
#   'pure',
#   'porcine',
#   'consummate',
#   'crude',
#   'thoroughgoing',
#   'earthy',
#   'crying',
#   'everlasting'),
#  'way': ('fashion',
#   'path',
#   'room',
#   'manner',
#   'way',
#   'style',
#   'way_of_life',
#   'mode',
#   'direction',
#   'right_smart',
#   'elbow_room',
#   'means',
#   'agency'),
#  'heading': ('header',
#   'drift',
#   'bearing',
#   'heading',
#   'head',
#   'maneuver',
#   'lead',
#   'head_up',
#   'manoeuver',
#   'steer',
#   'guide',
#   'channelize',
#   'gallery',
#   'channelise',
#   'point',
#   'aim',
#   'manoeuvre',
#   'direct'),
#  'buy': ('bribe',
#   'bargain',
#   'steal',
#   "grease_one's_palms",
#   'purchase',
#   'buy',
#   'corrupt'),
#  'needed': ('needed',
#   'call_for',
#   'involve',
#   'postulate',
#   'requisite',
#   'demand',
#   'required',
#   'take',
#   'necessitate',
#   'want',
#   'ask',
#   'needful',
#   'need',
#   'require'),
#  'bottle': ('bottleful', 'feeding_bottle', 'bottle', 'nursing_bottle'),
#  'drink': ('boozing',
#   'wassail',
#   'tope',
#   'drinkable',
#   'potable',
#   'imbibe',
#   'swallow',
#   'fuddle',
#   'booze',
#   'drink_in',
#   'pledge',
#   'drunkenness',
#   'crapulence',
#   'drinking',
#   'drink',
#   'deglutition',
#   'toast',
#   'salute',
#   'beverage'),
#  'wallet': ('billfold', 'notecase', 'wallet', 'pocketbook'),
#  'faking': ("talk_through_one's_hat",
#   'manipulate',
#   'fudge',
#   'fake',
#   'cook',
#   'misrepresent',
#   'falsify',
#   'forge',
#   'wangle',
#   'bullshit',
#   'bull',
#   'counterfeit'),
#  'kid': ('pull_the_leg_of',
#   'minor',
#   'kid',
#   'kyd',
#   'tike',
#   'child',
#   'nipper',
#   'banter',
#   'jolly',
#   'shaver',
#   'nestling',
#   'fry',
#   'tiddler',
#   'josh',
#   'chaff',
#   'kidskin',
#   'thomas_kid',
#   'thomas_kyd',
#   'youngster',
#   'small_fry',
#   'tyke'),
#  'grade': ('order',
#   'score',
#   'rank',
#   'rate',
#   'place',
#   'form',
#   'range',
#   'ground_level',
#   'level',
#   'course',
#   'grade',
#   'class',
#   'gradation',
#   'tier',
#   'mark',
#   'degree',
#   'grad'),
#  'spelling': ('spell', 'write', 'spell_out', 'spelling', 'import'),
#  'bee': ('bee',),
#  'trailing': ('track',
#   'shack',
#   'chase',
#   'drop_back',
#   'give_chase',
#   'tail',
#   'tracking',
#   'drop_behind',
#   'chase_after',
#   'trailing',
#   'train',
#   'tag',
#   'hang_back',
#   'dog',
#   'get_behind',
#   'drag',
#   'trail',
#   'go_after'),
#  'flame': ('fire', 'flame', 'flare', 'flaming'),
#  'word': ('christian_bible',
#   'book',
#   'word_of_god',
#   'parole',
#   'password',
#   'articulate',
#   'good_book',
#   'intelligence',
#   'logos',
#   'word_of_honor',
#   'son',
#   'bible',
#   'news',
#   'holy_writ',
#   'tidings',
#   'holy_scripture',
#   'discussion',
#   'scripture',
#   'give_voice',
#   'word',
#   'give-and-take',
#   'formulate',
#   'watchword',
#   'countersign',
#   'phrase'),
#  'county': ('county',),
#  'believe': ('consider', 'believe', 'conceive', 'trust', 'think'),
#  'night': ('night', 'nighttime', 'dark', 'nox'),
#  'episode': ('episode', 'installment', 'sequence', 'instalment'),
#  'encourage': ('boost', 'promote', 'further', 'encourage', 'advance'),
#  'watch': ('sentry',
#   'spotter',
#   'observe',
#   'vigil',
#   'ascertain',
#   'keep_an_eye_on',
#   'lookout',
#   'watch',
#   'find_out',
#   'ticker',
#   'take_in',
#   'look_out',
#   'look_on',
#   'scout',
#   'see',
#   'determine',
#   'picket',
#   'lookout_man',
#   'follow',
#   'sentinel',
#   'view',
#   'watch_over',
#   'watch_out',
#   'learn',
#   'check',
#   'catch'),
#  'welcome': ('welcome', 'receive'),
#  'bought': ('bribe', "grease_one's_palms", 'purchase', 'buy', 'corrupt'),
#  'combo': ('jazz_group', 'jazz_band', 'combo'),
#  'printer': ('printer', 'printing_machine', 'pressman'),
#  'j': ('j', 'watt_second', 'joule'),
#  'cause': ('grounds',
#   'causal_agent',
#   'have',
#   'cause',
#   'do',
#   'case',
#   'induce',
#   'reason',
#   'suit',
#   'lawsuit',
#   'drive',
#   'effort',
#   'make',
#   'stimulate',
#   'causa',
#   'movement',
#   'campaign',
#   'crusade',
#   'causal_agency',
#   'get'),
#  'cheaper': ('flashy',
#   'loud',
#   'meretricious',
#   'trashy',
#   'punk',
#   'gaudy',
#   'chintzy',
#   'crummy',
#   'sleazy',
#   'gimcrack',
#   'chinchy',
#   'brassy',
#   'cheesy',
#   'tatty',
#   'inexpensive',
#   'tinny',
#   'tawdry',
#   'bum',
#   'flash',
#   'tacky',
#   'cheap',
#   'garish'),
#  'ink': ('ink',),
#  'old': ('honest-to-god',
#   'honest-to-goodness',
#   'sure-enough',
#   'one-time',
#   'erstwhile',
#   'onetime',
#   'older',
#   'quondam',
#   'old',
#   'former',
#   'previous',
#   'sometime'),
#  'fax': ('facsimile', 'facsimile_machine', 'fax', 'telefax'),
#  'part': ('component_part',
#   'constituent',
#   'office',
#   'break',
#   'set_out',
#   'portion',
#   'start',
#   'partially',
#   'voice',
#   'start_out',
#   'partly',
#   'region',
#   'depart',
#   'break_up',
#   'section',
#   'function',
#   'share',
#   'parting',
#   'set_forth',
#   'split',
#   'role',
#   'set_off',
#   'take_off',
#   'part',
#   'component',
#   'separate',
#   'percentage',
#   'theatrical_role',
#   'character',
#   'divide',
#   'piece',
#   'division',
#   'contribution',
#   'persona',
#   'split_up',
#   'disunite'),
#  'wake': ('awaken',
#   'wake',
#   'fire_up',
#   'wake_island',
#   'arouse',
#   'come_alive',
#   'backwash',
#   'waken',
#   'wake_up',
#   'awake',
#   'stir_up',
#   'inflame',
#   'viewing',
#   'ignite',
#   'aftermath',
#   'rouse',
#   'heat'),
#  'goddam': ('blame',
#   'goddam',
#   'goddamned',
#   'goddamn',
#   'damned',
#   'blamed',
#   'infernal',
#   'damn',
#   'deuced',
#   'blasted',
#   'darned',
#   'blessed'),
#  'bummer': ('bummer',),
#  'sad': ('pitiful', 'deplorable', 'distressing', 'lamentable', 'sorry', 'sad'),
#  'glad': ('sword_lily', 'glad', 'gladiolus', 'beaming', 'happy', 'gladiola'),
#  'red': ('redness',
#   'ruddy',
#   'loss',
#   'scarlet',
#   'reddened',
#   'red-faced',
#   'bolshevik',
#   'violent',
# ...
#   'amobarbital_sodium',
#   'risque',
#   'puritanical',
#   'downhearted',
#   'gentle',
#   'blasphemous',
#   'bluing',
#   'blueish',
#   'sorry',
#   'dark',
#   'grim',
#   'blue_air',
#   'dingy',
#   'drear',
#   'patrician',
#   'puritanic',
#   'blueness',
#   'blue_angel',
#   'blueing',
#   'dreary',
#   'racy'),
#  'bb': ('bb', 'bb_shot'),
#  'esr': ('electron_paramagnetic_resonance',
#   'sedimentation_rate',
#   'sed_rate',
#   'esr',
#   'erythrocyte_sedimentation_rate',
#   'electron_spin_resonance'),
#  'click': ('cluck',
#   'get_through',
#   'tick',
#   'dog',
#   'click',
#   'sink_in',
#   'clack',
#   'dawn',
#   'fall_into_place',
#   'snap',
#   'chink',
#   'get_across',
#   'penetrate',
#   'pawl',
#   'come_home',
#   'chatter',
#   'clink',
#   'suction_stop',
#   'mouse_click',
#   'flick',
#   'detent'),
#  'cousin': ('full_cousin', 'cousin', 'first_cousin', 'cousin-german'),
#  'married': ('tie',
#   'marry',
#   'conjoin',
#   'marital',
#   'married',
#   'get_hitched_with',
#   'get_married',
#   'splice',
#   'espouse',
#   'hook_up_with',
#   'wed',
#   'matrimonial'),
#  'flag': ('signal_flag',
#   'sword_lily',
#   'flag',
#   'pin',
#   'droop',
#   'fleur-de-lis',
#   'iris',
#   'ease_up',
#   'ease_off',
#   'swag',
#   'slacken_off',
#   'sag',
#   'flagstone',
#   'masthead'),
#  'bored': ('tire', 'bore', 'drill', 'blase', 'bored', 'world-weary'),
#  'nobody': ('cypher', 'nobody', 'cipher', 'nonentity'),
#  'senior': ('fourth-year', 'elder', 'older', 'aged', 'elderly', 'senior'),
#  'tickling': ('titillate',
#   'tickling',
#   'titillation',
#   'thrill',
#   'vibrate',
#   'tingling',
#   'vellicate',
#   'titillating',
#   'tickle'),
#  'floor': ('story',
#   'knock_down',
#   'take_aback',
#   'ball_over',
#   'level',
#   'flooring',
#   'storey',
#   'blow_out_of_the_water',
#   'dump',
#   'deck',
#   'trading_floor',
#   'shock',
#   'coldcock',
#   'floor',
#   'base'),
#  'worth': ('worth', 'deserving', 'charles_frederick_worth'),
#  'pub': ('gin_mill', 'public_house', 'pothouse', 'pub', 'saloon', 'taphouse'),
#  'boiling': ('boiling',
#   'moil',
#   'stewing',
#   'seethe',
#   'boil',
#   'churn',
#   'roil',
#   'simmering'),
#  'attempting': ('essay',
#   'assay',
#   'undertake',
#   'attempt',
#   'set_about',
#   'seek',
#   'try'),
#  'played': ('encounter',
#   'bet',
#   'act',
#   'diddle',
#   'wager',
#   'play',
#   'trifle',
#   'work',
#   'act_as',
#   'spiel',
#   'played',
#   'flirt',
#   'wreak',
#   'meet',
#   'dally',
#   'playact',
#   'take_on',
#   'fiddle',
#   'roleplay',
#   'bring',
#   'toy',
#   'represent',
#   'run',
#   'make_for',
#   'recreate'),
#  'stoked': ('stoke',),
#  'member': ('penis',
#   'phallus',
#   'fellow_member',
#   'extremity',
#   'appendage',
#   'member'),
#  'cf': ('atomic_number_98',
#   'cystic_fibrosis',
#   'californium',
#   'pancreatic_fibrosis',
#   'cf.',
#   'mucoviscidosis',
#   'cf',
#   'fibrocystic_disease_of_the_pancreas'),
#  'computer': ('figurer',
#   'information_processing_system',
#   'computing_machine',
#   'calculator',
#   'data_processor',
#   'estimator',
#   'computer',
#   'computing_device',
#   'electronic_computer',
#   'reckoner'),
#  'immediately': ('now',
#   'instantly',
#   'immediately',
#   'forthwith',
#   'straightaway',
#   'like_a_shot',
#   'straight_off',
#   'at_once',
#   'directly',
#   'right_away'),
#  'waiting': ('ready_and_waiting',
#   'look',
#   'wait',
#   'hold_off',
#   'waitress',
#   'waiting',
#   'hold_back',
#   'expect',
#   'await'),
#  'teary': ('teary-eyed', 'teary', 'watery-eyed'),
#  'fucking': ('bonk',
#   'roll_in_the_hay',
#   'have_sex',
#   'hump',
#   'get_it_on',
#   'nooky',
#   'be_intimate',
#   'love',
#   'screw',
#   'piece_of_tail',
#   'shag',
#   'have_it_away',
#   'piece_of_ass',
#   'sleep_with',
#   'get_laid',
#   'bang',
#   'make_out',
#   'blinking',
#   'jazz',
#   'ass',
#   'fucking',
#   'bed',
#   'have_it_off',
#   'have_a_go_at_it',
#   'bally',
#   'do_it',
#   'sleep_together',
#   'eff',
#   'nookie',
#   'have_intercourse',
#   'shtup',
#   'bloody',
#   'blooming',
#   'make_love',
#   'lie_with',
#   'know',
#   'crashing',
#   'fuck',
#   'screwing',
#   'flaming'),
#  'sit': ('sit_down',
#   'ride',
#   'model',
#   'sit_around',
#   'seat',
#   'posture',
#   'baby-sit',
#   'sit',
#   'pose'),
#  'brave': ('intrepid',
#   'brave_out',
#   'gay',
#   'brave',
#   'dauntless',
#   'courageous',
#   'unfearing',
#   'endure',
#   'fearless',
#   'weather',
#   'braw',
#   'hardy',
#   'audacious'),
#  'friendly': ('well-disposed', 'favorable', 'friendly'),
#  'gm': ('gm', 'g', 'gramme', 'gram'),
#  'offensively': ('obnoxiously', 'objectionably', 'offensively'),
#  'timing': ('clock', 'time', 'timing'),
#  'israel': ('yisrael', 'israel', 'zion', 'sion', 'state_of_israel'),
#  'player': ('player',
#   'thespian',
#   'instrumentalist',
#   'musician',
#   'actor',
#   'histrion',
#   'participant',
#   'role_player'),
#  'teach': ('instruct',
#   'edward_teach',
#   'blackbeard',
#   'teach',
#   'thatch',
#   'edward_thatch',
#   'learn'),
#  'blindly': ('blindly',),
#  'trust': ('entrust',
#   'believe',
#   'faith',
#   'trust',
#   'trustingness',
#   'confidence',
#   'rely',
#   'hope',
#   'intrust',
#   'reliance',
#   'cartel',
#   'combine',
#   'commit',
#   'desire',
#   'swear',
#   'bank',
#   'trustfulness',
#   'corporate_trust',
#   'confide'),
#  'amazon': ('virago', 'amazon', 'amazon_river'),
#  'search': ('lookup',
#   'explore',
#   'look',
#   'research',
#   'search',
#   'hunt',
#   'hunting',
#   'seek',
#   'look_for'),
#  'result': ('issue',
#   'result',
#   'effect',
#   'resultant',
#   'resultant_role',
#   'final_result',
#   'lead',
#   'event',
#   'resolution',
#   'outcome',
#   'termination',
#   'leave',
#   'solvent',
#   'answer',
#   'upshot',
#   'consequence',
#   'solution',
#   'ensue'),
#  'reading': ('register',
#   'understand',
#   'recital',
#   'read',
#   'record',
#   'version',
#   'say',
#   'scan',
#   'translate',
#   'reading',
#   'indication',
#   'show',
#   'interpretation',
#   'recitation',
#   'interpret',
#   'meter_reading',
#   'take',
#   'reading_material',
#   'study',
#   'learn'),
#  'jareds': ('clash', 'bump_around', 'jolt', 'collide', 'jar', 'shake_up'),
#  'sparkly': ('coruscant',
#   'glinting',
#   'scintillant',
#   'frothy',
#   'bubbling',
#   'sparkly',
#   'aglitter',
#   'fulgid',
#   'glittering',
#   'effervescent',
#   'glistering',
#   'glittery',
#   'scintillating'),
#  'eye': ('heart',
#   'middle',
#   'center',
#   'oculus',
#   'eye',
#   'centre',
#   'eyeball',
#   'optic'),
#  'highly': ('extremely', 'highly'),
#  'disorganized': ('disorganise',
#   'disorganized',
#   'disorganised',
#   'disorganize'),
#  'tom': ('uncle_tom', 'tomcat', 'turkey_cock', 'tom_turkey', 'tom', 'gobbler'),
#  'loser': ('loser',
#   'also-ran',
#   'unsuccessful_person',
#   'failure',
#   'nonstarter'),
#  'helen': ('helen_of_troy', 'helen'),
#  'improving': ('better',
#   'ameliorate',
#   'meliorate',
#   'improve',
#   'up',
#   'improving',
#   'amend'),
#  'bloody': ('bloody',
#   'bally',
#   'blooming',
#   'all-fired',
#   'blinking',
#   'fucking',
#   'damn',
#   'crashing',
#   'flaming'),
#  'tan': ('burn', 'sunburn', 'suntan', 'bronze', 'topaz', 'tangent', 'tan'),
#  'camping': ('camping',
#   'camp_out',
#   'bivouac',
#   'encamp',
#   'tenting',
#   'camp_down',
#   'bivouacking',
#   'camp',
#   'encampment',
#   'tent'),
#  'wi': ('badger_state', 'wi', 'wisconsin'),
#  'seven': ('7',
#   'vii',
#   'septet',
#   'seven-spot',
#   'seven',
#   'septenary',
#   'sevener',
#   'heptad'),
#  'ireland': ('ireland',
#   'irish_republic',
#   'emerald_isle',
#   'republic_of_ireland',
#   'hibernia',
#   'eire'),
#  'freedom': ('exemption', 'freedom'),
#  'damn': ('shit',
#   'all-fired',
#   'blamed',
#   'red_cent',
#   "tinker's_damn",
#   "tinker's_dam",
#   'anathemise',
#   'darn',
#   'bedamn',
#   'goddamned',
#   'maledict',
#   'blessed',
#   'infernal',
#   'curse',
#   'blame',
#   'beshrew',
#   'anathemize',
#   'goddamn',
#   'deuced',
#   'imprecate',
#   'goddam',
#   'bloody',
#   'hoot',
#   'shucks',
#   'damn',
#   'blasted',
#   'darned',
#   'damned'),
#  'listening': ('hearing',
#   'mind',
#   'take_heed',
#   'heed',
#   'hear',
#   'listen',
#   'listening'),
#  'alone': ('alone',
#   'unequaled',
#   'unaccompanied',
#   'unequalled',
#   'solitary',
#   'solely',
#   'entirely',
#   'solo',
#   'unique',
#   'only',
#   'exclusively',
#   'lonely',
#   'lone',
#   'unparalleled'),
#  'ranger': ('ranger',
#   'texas_ranger',
#   'fire_warden',
#   'forest_fire_fighter',
#   'commando'),
#  'afternoon': ('afternoon', 'good_afternoon'),
#  'teaching': ('instruct',
#   'instruction',
#   'commandment',
#   'educational_activity',
#   'education',
#   'teach',
#   'teaching',
#   'precept',
#   'didactics',
#   'pedagogy',
#   'learn'),
#  'son': ('word', 'boy', 'son', 'logos'),
#  'manner': ('fashion', 'manner', 'way', 'style', 'mode', 'personal_manner'),
#  'boy': ('male_child', 'boy', 'son'),
#  'lacking': ('miss',
#   'lack',
#   'lacking',
#   'deficient',
#   'wanting',
#   'absent',
#   'missing'),
#  'shag': ('shtup',
#   'screw',
#   'shag',
#   'piece_of_tail',
#   'piece_of_ass',
#   'roll_in_the_hay',
#   'fucking',
#   'ass',
#   'nooky',
#   'nookie',
#   'fuck',
#   'screwing'),
#  'crush': ('crush',
#   'crushed_leather',
#   'trounce',
#   'press',
#   'smash',
#   'demolish',
#   'compaction',
#   'suppress',
#   'infatuation',
#   'squelch',
#   'squash',
#   'jam',
#   'break_down',
#   'beat_out',
#   'puppy_love',
#   'shell',
#   'beat',
#   'oppress',
#   'mash',
#   'vanquish',
#   'squeeze',
#   'crunch',
#   'calf_love'),
#  'lecture': ('public_lecture',
#   'jaw',
#   'berate',
#   'trounce',
#   'scold',
#   'call_down',
#   'lambast',
#   'chide',
#   'lambaste',
#   'lecturing',
#   'reproof',
#   'take_to_task',
#   'reprimand',
#   'dress_down',
#   'bawl_out',
#   'talking_to',
#   'lecture',
#   'have_words',
#   'rag',
#   'chew_out',
#   'rebuke',
#   'remonstrate',
#   'chew_up',
#   'speech',
#   'talk',
#   'call_on_the_carpet'),
#  'mix': ('premix',
#   'mixture',
#   'intermixture',
#   'mingle',
#   'admixture',
#   'ruffle',
#   'integrate',
#   'meld',
#   'conflate',
#   'flux',
#   'unify',
#   'desegregate',
#   'immix',
#   'mix',
#   'mix_in',
#   'combine',
#   'commingle',
#   'mixing',
#   'shuffle',
#   'commixture',
#   'blend',
#   'coalesce',
#   'commix',
#   'fuse',
#   'amalgamate',
#   'merge'),
#  'bull': ('shit',
#   "talk_through_one's_hat",
#   'strapper',
#   'pig',
#   'fuzz',
#   'bullshit',
#   'bull',
#   'bruiser',
#   'bull_through',
#   'dogshit',
#   'samson',
#   'horseshit',
#   'cop',
#   'taurus_the_bull',
#   'copper',
#   'papal_bull',
#   "bull's_eye",
#   'fake',
#   'taurus',
#   'irish_bull',
#   'crap'),
#  'bedtime': ('bedtime',),
#  'fed': ('eat',
#   'feed_in',
#   'feast',
#   'course',
#   'federal',
#   'frs',
#   'prey',
#   'fertilise',
#   'federal_reserve',
#   'fed',
#   'federal_official',
#   'federal_reserve_system',
#   'give',
#   'run',
#   'fertilize',
#   'feed',
#   'flow'),
#  'bd': ('bd', 'bachelor_of_divinity'),
#  'bummed': ('bum_around',
#   'lounge_around',
#   'loll',
#   'cadge',
#   "waste_one's_time",
#   'mooch',
#   'loaf',
#   'loll_around',
#   'fuck_off',
#   'grub',
#   'bum',
#   'bum_about',
#   'lounge_about',
#   'sponge',
#   'arse_around',
#   'frig_around',
#   'arse_about'),
#  'together': ('together', 'unitedly', 'in_concert'),
#  'near': ('go_up',
#   'virtually',
#   'approach',
#   'approximate',
#   'cheeseparing',
#   'good',
#   'dear',
#   'near',
#   'nigh',
#   'close',
#   'nearly',
#   'come_on',
#   'about',
#   'draw_close',
#   'come_near',
#   'draw_near',
#   'almost',
#   'penny-pinching',
#   'well-nigh',
#   'most',
#   'skinny'),
#  'future': ('futurity',
#   'time_to_come',
#   'future_tense',
#   'next',
#   'succeeding',
#   'hereafter',
#   'future'),
#  'impossible': ('unsufferable',
#   'out_of_the_question',
#   'impossible',
#   'insufferable',
#   'unacceptable',
#   'inconceivable',
#   'unimaginable'),
#  'cheer': ('pep_up',
#   'jolly_along',
#   'urge_on',
#   'cheer',
#   'exhort',
#   'embolden',
#   'sunniness',
#   'urge',
#   'cheerfulness',
#   'recreate',
#   'cheer_up',
#   'inspire',
#   'jolly_up',
#   'root_on',
#   'barrack',
#   'hearten',
#   'chirk_up',
#   'sunshine'),
#  'clarifying': ('clear_up',
#   'elucidative',
#   'clarifying',
#   'elucidate',
#   'clarify'),
#  'meant': ('stand_for',
#   'have_in_mind',
#   'think_of',
#   'entail',
#   'intend',
#   'imply',
#   'think',
#   'signify',
#   'mean'),
#  'examination': ('test',
#   'interrogation',
#   'interrogatory',
#   'examination',
#   'scrutiny',
#   'examen',
#   'exam',
#   'testing'),
#  'referring': ('consult',
#   'advert',
#   'concern',
#   'mention',
#   'bear_on',
#   'have-to_doe_with',
#   'denote',
#   'relate',
#   'name',
#   'touch_on',
#   'cite',
#   'pertain',
#   'come_to',
#   'refer',
#   'look_up',
#   'bring_up',
#   'touch'),
#  'buddy': ('chum', 'brother', 'crony', 'buddy', 'pal', 'sidekick'),
#  'lover': ('fan', 'lover', 'devotee', 'buff'),
#  'chicago': ('newmarket',
#   'stops',
#   'boodle',
#   'michigan',
#   'windy_city',
#   'chicago'),
#  'silence': ('hush',
#   'silence',
#   'shut_up',
#   'still',
#   'hush_up',
#   'muteness',
#   'secretiveness',
#   'quieten',
#   'quiet',
#   'secrecy'),
#  'verona': ('verona',),
#  'wanting': ('lacking',
#   'deficient',
#   'wanting',
#   'want',
#   'absent',
#   'need',
#   'require',
#   'desire',
#   'missing'),
#  'star': ('starring',
#   'prima',
#   'star',
#   'virtuoso',
#   'adept',
#   'mavin',
#   'whizz',
#   'wiz',
#   'sensation',
#   'genius',
#   'headliner',
#   'stellar',
#   'asterisk',
#   'superstar',
#   'leading',
#   'wizard',
#   'ace',
#   'whiz',
#   'principal',
#   'lead',
#   'star_topology',
#   'hotshot',
#   'maven',
#   'champion'),
#  'trek': ('trek',),
#  'killed': ('drink_down',
#   'pour_down',
#   'toss_off',
#   'shoot_down',
#   'down',
#   'vote_down',
#   'kill',
#   'bolt_down',
#   'belt_down',
#   'wipe_out',
#   'vote_out',
#   'obliterate',
#   'pop',
#   'stamp_out',
#   'defeat'),
#  'memorial': ('remembrance', 'commemoration', 'monument', 'memorial'),
#  'raid': ('bust', 'raid', 'foray_into', 'maraud', 'foray'),
#  'planning': ('contrive',
#   'provision',
#   'project',
#   'plan',
#   'design',
#   'planning',
#   'be_after',
#   'preparation'),
#  'tv': ('video',
#   'idiot_box',
#   'tv_set',
#   'telly',
#   'goggle_box',
#   'television_receiver',
#   'boob_tube',
#   'tv',
#   'telecasting',
#   'television',
#   'television_set'),
#  'clock': ('clock', 'time'),
#  'blip': ('pip', 'blip', 'radar_target'),
#  'unavailable': ('unavailable',),
#  'official': ('functionary', 'prescribed', 'official'),
#  'fellowship': ('fellowship', 'family', 'company', 'society', 'companionship'),
#  'demoed': ('demo', 'demonstrate', 'present', 'show', 'exhibit'),
#  'gold': ('gold',
#   'amber',
#   'golden',
#   'au',
#   'gilt',
#   'aureate',
#   'atomic_number_79',
#   'gilded'),
#  'digger': ('power_shovel', 'shovel', 'digger', 'excavator'),
#  'afford': ('yield', 'open', 'give', 'afford'),
#  'shift': ('duty_period',
#   'break',
#   'dislodge',
#   'wobble',
#   'lurch',
#   'slip',
#   'budge',
#   'fracture',
#   'teddy',
#   'careen',
#   'transformation',
#   'change',
#   'chemise',
#   'pitch',
#   'faulting',
#   'change_over',
#   'switching',
#   'sack',
#   'transfer',
#   'stir',
#   'switch',
#   'fault',
#   'transmutation',
#   'shift',
#   'displacement',
#   'geological_fault',
#   'tilt',
#   'agitate',
#   'shift_key',
#   'work_shift',
#   'shifting',
#   'shimmy',
#   'reposition'),
#  'ben': ('ben',),
#  'lost': ('recede',
#   'miss',
#   'mixed-up',
#   'doomed',
#   'bewildered',
#   'preoccupied',
#   'befuddled',
#   'baffled',
#   'mislay',
#   'helpless',
#   'lose',
#   'mazed',
#   'confounded',
#   'disoriented',
#   'suffer',
#   'turn_a_loss',
#   'at_sea',
#   'confused',
#   'lost',
#   'fall_back',
#   'deep_in_thought',
#   'misplace',
#   'drop_off',
#   'bemused',
#   'fall_behind',
#   'missed'),
#  'stung': ('prick',
#   'annoyed',
#   'nettled',
#   'sting',
#   'riled',
#   'stung',
#   'irritated',
#   'pissed_off',
#   'burn',
#   'bite',
#   'miffed',
#   'roiled',
#   'steamed',
#   'pissed',
#   'peeved',
#   'twinge',
#   'stick'),
#  'nettle': ('rag',
#   'chafe',
#   'nettle',
#   'get_at',
#   'get_to',
#   'gravel',
#   'annoy',
#   'devil',
#   'urticate',
#   'rile',
#   'vex',
#   'irritate',
#   'nark',
#   'bother'),
#  'dying': ('die',
#   'become_flat',
#   'croak',
#   'break',
#   'give-up_the_ghost',
#   'buy_the_farm',
#   'give_out',
#   'kick_the_bucket',
#   'perish',
#   'conk_out',
#   'go',
#   'conk',
#   'death',
#   'break_down',
#   'decease',
#   'drop_dead',
#   'die_out',
#   'go_bad',
#   'anxious',
#   'pass',
#   'pop_off',
#   'pall',
#   'dying',
#   'choke',
#   'pass_away',
#   "cash_in_one's_chips",
#   'demise',
#   'exit',
#   'fail',
#   'snuff_it',
#   'give_way',
#   'expire'),
#  'somewhere': ('somewhere', 'someplace'),
#  'cry': ('rallying_cry',
#   'shout',
#   'blazon_out',
#   'squall',
#   'holler',
#   'exclaim',
#   'hollo',
#   'scream',
#   'weep',
#   'outcry',
#   'call_out',
#   'cry',
#   'war_cry',
#   'cry_out',
#   'vociferation',
#   'watchword',
#   'call',
#   'battle_cry',
#   'shout_out',
#   'yell'),
#  'franchise': ('dealership', 'franchise', 'enfranchisement'),
#  'mode': ('fashion',
#   'manner',
#   'way',
#   'style',
#   'mood',
#   'modality',
#   'mode',
#   'musical_mode',
#   'modal_value'),
#  'dynasty': ('dynasty',),
#  ...}

# %%
#Function for augmenting data by replacing words with synonym using spaCy

# %%
import re
import random
sr = random.SystemRandom()
split_pattern = re.compile(r'\s+')
def data_augmentation(message, aug_range=1) :
    augmented_messages = []
    for j in range(0,aug_range) :
        new_message = ""
        for i in filter(None, split_pattern.split(message)) :
            new_message = new_message + " " + sr.choice(filtered_synonym.get(i,[i]))
        augmented_messages.append(new_message)
    return augmented_messages

# %%
tweet_count = df.sentiment.value_counts().to_dict()

# %%
## Get max intent count to match other minority classes through data augmentation
import operator
max_intent_count = max(tweet_count.items(), key=operator.itemgetter(1))[1]

# %% [markdown]
# Balancing Data Because sentiment data is very far apart, for example neutral contains 8638 data, while anger contains 110 data. We decided to balance the data to make the data fairer in terms of accuracy learning later. We use the Oversampling method, which means adding synthetic data that refers to the largest amount of data in the dataset.

# %%
import numpy as np
import math
import tqdm
newdf = pd.DataFrame()
for intent, count in tweet_count.items() :
    count_diff = max_intent_count - count    ## Difference to fill
    multiplication_count = math.ceil((count_diff)/count)  ## Multiplying a minority classes for multiplication_count times
    if (multiplication_count) :
        old_message_df = pd.DataFrame()
        new_message_df = pd.DataFrame()
        for message in tqdm.tqdm(df[df["sentiment"] == intent]['content'].values) :
            ## Extracting existing minority class batch
            dummy1 = pd.DataFrame([message], columns=['content'])
            dummy1["sentiment"] = intent
            # concat existing minority class batch
            old_message_df = pd.concat([old_message_df, dummy1])

            ## Creating new augmented batch from existing minority class
            new_messages = data_augmentation(message,  multiplication_count)
            dummy2 = pd.DataFrame(new_messages, columns=['content'])
            dummy2["sentiment"] = intent
            # concat new augmented batch
            new_message_df = pd.concat([new_message_df, dummy2])

        ## Select random data points from augmented data
        new_message_df=new_message_df.take(np.random.permutation(len(new_message_df))[:count_diff])
        
        ## Merge existing and augmented data points using concat
        newdf = pd.concat([newdf, old_message_df, new_message_df])
        # newdf = newdf.append([old_message_df,new_message_df])
    else :
        newdf = pd.concat([newdf, df[df["sentiment"] == intent]])
        # newdf = newdf.append(df[df["Intent"] == intent])

# %%
newdf.head(5)
# Out:
#        tweet_id  sentiment                                            content  \
# 40   1956977084  happiness  mmm much better day... so far! it's still quit...
# 69   1956983874  happiness  So great to see Oin &amp; Cynthia.  So happy. ...
# 77   1956985535  happiness  @havingmysay  dude, that is my favorite sandwi...
# 126  1956996765  happiness  Need to pack for CALI CALI! Cannot waittt! Thi...
# 233  1957017522  happiness  took a math test today. The day before the tes...
#
#                                          content_token  \
# 40   [mmm, much, better, far, still, quite, early, ...
# 69   [great, see, oin, cynthia, happy, dinner, grea...
# 77   [dude, favorite, sandwich, place, ever, ummm, ...
# 126  [need, pack, cali, cali, can, not, waittt, thi...
# 233  [took, math, test, today, test, teacher, say, ...
#
#                                                synonym
# 40   [[], [much, much, much, much, a_lot, lots, a_g...
# 69   [[great, great, great, outstanding, great, ban...
# 77   [[fellow, dude, buster, dandy, dude, fop, gall...
# 126  [[need, demand, need, want, motivation, motive...
# 233  [[take, take, occupy, use_up, lead, take, dire...

# %%
newdf.value_counts('sentiment')
# Out:
# sentiment
# happiness    5085
# dtype: int64

# %%
## Save newdf to csv file
newdf.to_csv('augmented_data.csv', index=False)

# %%
clean_df = pd.read_csv('https://raw.githubusercontent.com/fatmaaerr/Text-Mining-and-Sentiment-Analysis-P8/main/Data/augmented_data.csv')
clean_df.head()
# Out:
#        tweet_id sentiment                                            content  \
# 0  1.956968e+09   neutral  @dannycastillo We want to trade with someone w...
# 1  1.956969e+09   neutral                                   cant fall asleep
# 2  1.956972e+09   neutral  No Topic Maps talks at the Balisage Markup Con...
# 3  1.956975e+09   neutral                          @cynthia_123 i cant sleep
# 4  1.956976e+09   neutral                    I missed the bl***y bus!!!!!!!!
#
#                                        content_token  \
# 0  ['want', 'trade', 'someone', 'houston', 'ticke...
# 1                         ['cant', 'fall', 'asleep']
# 2  ['topic', 'map', 'talk', 'balisage', 'markup',...
# 3                                  ['cant', 'sleep']
# 4                           ['missed', 'bly', 'bus']
#
#                                              synonym
# 0  [['privation', 'want', 'deprivation', 'needine...
# 1  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 2  [['subject', 'topic', 'theme', 'topic', 'subje...
# 3  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 4  [['miss', 'lose', 'miss', 'miss', 'neglect', '...

# %%
clean_df.value_counts('sentiment')
# Out:
# sentiment
# anger         8356
# boredom       8356
# empty         8356
# enthusiasm    8356
# fun           8356
# happiness     8356
# hate          8356
# love          8356
# neutral       8356
# relief        8356
# sadness       8356
# surprise      8356
# worry         8356
# dtype: int64

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='sentiment', data=clean_df);

# %%
# cleaning the tweets using clean_tweet function

clean_df['clean_tweet'] = clean_df['content'].apply(lambda x: cleanTxt(x))

# %%
# lower casing clean_tweet column

clean_df['clean_tweet'] = clean_df['clean_tweet'].apply(lambda x: x.lower())

clean_df.head(5)
# Out:
#        tweet_id sentiment                                            content  \
# 0  1.956968e+09   neutral  @dannycastillo We want to trade with someone w...
# 1  1.956969e+09   neutral                                   cant fall asleep
# 2  1.956972e+09   neutral  No Topic Maps talks at the Balisage Markup Con...
# 3  1.956975e+09   neutral                          @cynthia_123 i cant sleep
# 4  1.956976e+09   neutral                    I missed the bl***y bus!!!!!!!!
#
#                                        content_token  \
# 0  ['want', 'trade', 'someone', 'houston', 'ticke...
# 1                         ['cant', 'fall', 'asleep']
# 2  ['topic', 'map', 'talk', 'balisage', 'markup',...
# 3                                  ['cant', 'sleep']
# 4                           ['missed', 'bly', 'bus']
#
#                                              synonym  \
# 0  [['privation', 'want', 'deprivation', 'needine...
# 1  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 2  [['subject', 'topic', 'theme', 'topic', 'subje...
# 3  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 4  [['miss', 'lose', 'miss', 'miss', 'neglect', '...
#
#                                          clean_tweet
# 0   we want to trade with someone who has houston...
# 1                                   cant fall asleep
# 2  no topic maps talks at the balisage markup con...
# 3                                       i cant sleep
# 4                    i missed the bl   y bus

# %%
# function to remove stop words from clean_tweet column

def remove_stopwords(text):
    text = [word for word in text.split() if word not in stop]
    return " ".join(text)

# %%
# stopword removal
clean_df['clean_tweet'] = clean_df['clean_tweet'].apply(lambda x: remove_stopwords(x))

# %%
# function to lemmitize clean_tweet column

def lemmatization(text):
    text = [lemmatizer.lemmatize(word) for word in text.split()]
    return " ".join(text)

# %%
# lemmitization
clean_df['clean_tweet'] = clean_df['clean_tweet'].apply(lambda x: lemmatization(x))

# %%
# tokenization using word_tokenize
clean_df['clean_tweet_token'] = clean_df['clean_tweet'].apply(lambda x: word_tokenize(x))
clean_df.head()
# Out:
#        tweet_id sentiment                                            content  \
# 0  1.956968e+09   neutral  @dannycastillo We want to trade with someone w...
# 1  1.956969e+09   neutral                                   cant fall asleep
# 2  1.956972e+09   neutral  No Topic Maps talks at the Balisage Markup Con...
# 3  1.956975e+09   neutral                          @cynthia_123 i cant sleep
# 4  1.956976e+09   neutral                    I missed the bl***y bus!!!!!!!!
#
#                                        content_token  \
# 0  ['want', 'trade', 'someone', 'houston', 'ticke...
# 1                         ['cant', 'fall', 'asleep']
# 2  ['topic', 'map', 'talk', 'balisage', 'markup',...
# 3                                  ['cant', 'sleep']
# 4                           ['missed', 'bly', 'bus']
#
#                                              synonym  \
# 0  [['privation', 'want', 'deprivation', 'needine...
# 1  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 2  [['subject', 'topic', 'theme', 'topic', 'subje...
# 3  [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 4  [['miss', 'lose', 'miss', 'miss', 'neglect', '...
#
#                                          clean_tweet  \
# 0                  want trade someone houston ticket
# 1                                   cant fall asleep
# 2  topic map talk balisage markup conference prog...
# 3                                         cant sleep
# 4                                      missed bl bus
#
#                                    clean_tweet_token
# 0            [want, trade, someone, houston, ticket]
# 1                               [cant, fall, asleep]
# 2  [topic, map, talk, balisage, markup, conferenc...
# 3                                      [cant, sleep]
# 4                                  [missed, bl, bus]

# %%
## Save clean_df to csv file.
##clean_df.to_csv('Model_data.csv', index=False)

# %%
##clean_df = pd.read_csv('Model_data.csv')

# %%
clean_df
# Out:
#             tweet_id sentiment  \
# 0       1.956968e+09   neutral
# 1       1.956969e+09   neutral
# 2       1.956972e+09   neutral
# 3       1.956975e+09   neutral
# 4       1.956976e+09   neutral
# ...              ...       ...
# 108623           NaN     anger
# 108624           NaN     anger
# 108625           NaN     anger
# 108626           NaN     anger
# 108627           NaN     anger
#
#                                                   content  \
# 0       @dannycastillo We want to trade with someone w...
# 1                                        cant fall asleep
# 2       No Topic Maps talks at the Balisage Markup Con...
# 3                               @cynthia_123 i cant sleep
# 4                         I missed the bl***y bus!!!!!!!!
# ...                                                   ...
# 108623   Did a historic Jesus of_all_time exist? Im wi...
# 108624   @mikeavila ack! I just interpret about your t...
# 108625   ne'er does anything dear cultivate and lapin ...
# 108626   @mashable Link to ff &quot;how it works&quot;...
# 108627   I live begin to retrieve solarise blcok is a ...
#
#                                             content_token  \
# 0       ['want', 'trade', 'someone', 'houston', 'ticke...
# 1                              ['cant', 'fall', 'asleep']
# 2       ['topic', 'map', 'talk', 'balisage', 'markup',...
# 3                                       ['cant', 'sleep']
# 4                                ['missed', 'bly', 'bus']
# ...                                                   ...
# 108623                                                NaN
# 108624                                                NaN
# 108625                                                NaN
# 108626                                                NaN
# 108627                                                NaN
#
#                                                   synonym  \
# 0       [['privation', 'want', 'deprivation', 'needine...
# 1       [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 2       [['subject', 'topic', 'theme', 'topic', 'subje...
# 3       [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 4       [['miss', 'lose', 'miss', 'miss', 'neglect', '...
# ...                                                   ...
# 108623                                                NaN
# 108624                                                NaN
# 108625                                                NaN
# 108626                                                NaN
# 108627                                                NaN
#
#                                               clean_tweet  \
# 0                       want trade someone houston ticket
# 1                                        cant fall asleep
# 2       topic map talk balisage markup conference prog...
# 3                                              cant sleep
# 4                                           missed bl bus
# ...                                                   ...
# 108623  historic jesus time exist im witness hard prov...
# 108624    ack interpret testify horrible accounting taste
# 108625  ne er anything dear cultivate lapin life histo...
# 108626                       link ff quot work quot broke
# 108627            live begin retrieve solarise blcok haox
#
#                                         clean_tweet_token
# 0                 [want, trade, someone, houston, ticket]
# 1                                    [cant, fall, asleep]
# 2       [topic, map, talk, balisage, markup, conferenc...
# 3                                           [cant, sleep]
# 4                                       [missed, bl, bus]
# ...                                                   ...
# 108623  [historic, jesus, time, exist, im, witness, ha...
# 108624  [ack, interpret, testify, horrible, accounting...
# 108625  [ne, er, anything, dear, cultivate, lapin, lif...
# 108626                [link, ff, quot, work, quot, broke]
# 108627     [live, begin, retrieve, solarise, blcok, haox]
#
# [108628 rows x 7 columns]

# %%
sent_to_id  = {"empty":0, "sadness":1,"enthusiasm":2,"neutral":3,"worry":4,
                        "surprise":5,"love":6,"fun":7,"hate":8,"happiness":9,"boredom":10,"relief":11,"anger":12}

# %%
clean_df["sentiment_id"] = clean_df['sentiment'].map(sent_to_id)

# %%
clean_df
# Out:
#             tweet_id sentiment  \
# 0       1.956968e+09   neutral
# 1       1.956969e+09   neutral
# 2       1.956972e+09   neutral
# 3       1.956975e+09   neutral
# 4       1.956976e+09   neutral
# ...              ...       ...
# 108623           NaN     anger
# 108624           NaN     anger
# 108625           NaN     anger
# 108626           NaN     anger
# 108627           NaN     anger
#
#                                                   content  \
# 0       @dannycastillo We want to trade with someone w...
# 1                                        cant fall asleep
# 2       No Topic Maps talks at the Balisage Markup Con...
# 3                               @cynthia_123 i cant sleep
# 4                         I missed the bl***y bus!!!!!!!!
# ...                                                   ...
# 108623   Did a historic Jesus of_all_time exist? Im wi...
# 108624   @mikeavila ack! I just interpret about your t...
# 108625   ne'er does anything dear cultivate and lapin ...
# 108626   @mashable Link to ff &quot;how it works&quot;...
# 108627   I live begin to retrieve solarise blcok is a ...
#
#                                             content_token  \
# 0       ['want', 'trade', 'someone', 'houston', 'ticke...
# 1                              ['cant', 'fall', 'asleep']
# 2       ['topic', 'map', 'talk', 'balisage', 'markup',...
# 3                                       ['cant', 'sleep']
# 4                                ['missed', 'bly', 'bus']
# ...                                                   ...
# 108623                                                NaN
# 108624                                                NaN
# 108625                                                NaN
# 108626                                                NaN
# 108627                                                NaN
#
#                                                   synonym  \
# 0       [['privation', 'want', 'deprivation', 'needine...
# 1       [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 2       [['subject', 'topic', 'theme', 'topic', 'subje...
# 3       [['buzzword', 'cant', 'bank', 'cant', 'camber'...
# 4       [['miss', 'lose', 'miss', 'miss', 'neglect', '...
# ...                                                   ...
# 108623                                                NaN
# 108624                                                NaN
# 108625                                                NaN
# 108626                                                NaN
# 108627                                                NaN
#
#                                               clean_tweet  \
# 0                       want trade someone houston ticket
# 1                                        cant fall asleep
# 2       topic map talk balisage markup conference prog...
# 3                                              cant sleep
# 4                                           missed bl bus
# ...                                                   ...
# 108623  historic jesus time exist im witness hard prov...
# 108624    ack interpret testify horrible accounting taste
# 108625  ne er anything dear cultivate lapin life histo...
# 108626                       link ff quot work quot broke
# 108627            live begin retrieve solarise blcok haox
#
#                                         clean_tweet_token  sentiment_id
# 0                 [want, trade, someone, houston, ticket]             3
# 1                                    [cant, fall, asleep]             3
# 2       [topic, map, talk, balisage, markup, conferenc...             3
# 3                                           [cant, sleep]             3
# 4                                       [missed, bl, bus]             3
# ...                                                   ...           ...
# 108623  [historic, jesus, time, exist, im, witness, ha...            12
# 108624  [ack, interpret, testify, horrible, accounting...            12
# 108625  [ne, er, anything, dear, cultivate, lapin, lif...            12
# 108626                [link, ff, quot, work, quot, broke]            12
# 108627     [live, begin, retrieve, solarise, blcok, haox]            12
#
# [108628 rows x 8 columns]

# %%
## Save clean_df to csv file.
clean_df.to_csv('Model_data.csv', index=False)

# %%
clean_df = pd.read_csv('Model_data.csv')
# Out:
# C:\Users\fatma.er\AppData\Local\Temp\ipykernel_14220\361403307.py:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   clean_df = pd.read_csv('Model_data.csv')

# %%
love = [r for r in clean_df['clean_tweet_token'][clean_df['sentiment_id']==6]]
pos = ''.join(love)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
   ).generate(pos)
plt.figure(figsize=(10,9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
anger = [r for r in clean_df['clean_tweet_token'][clean_df['sentiment_id']==12]]
pos = ''.join(anger)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
   ).generate(pos)
plt.figure(figsize=(10,9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
worry = [r for r in clean_df['clean_tweet_token'][clean_df['sentiment_id']==4]]
pos = ''.join(worry)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
   ).generate(pos)
plt.figure(figsize=(10,9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sadness = [r for r in clean_df['clean_tweet_token'][clean_df['sentiment_id']==1]]
pos = ''.join(sadness)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
   ).generate(pos)
plt.figure(figsize=(10,9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
